# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os.path

# %%
# Ensure the file exists
if not os.path.exists( "Test/Uganda.csv" ):
    print("Missing dataset file")

# %%
df = pd.read_csv( "Test/Uganda.csv", skiprows=3 )

# %%
del df['Country Name']

# %%
del df['']
# Out:
#      Country Code                                     Indicator Name  \
# 0             UGA                                      Net migration
# 1             UGA  Children in employment, wage workers (% of chi...
# 2             UGA  Children in employment, wage workers, male (% ...
# 3             UGA  Children in employment, wage workers, female (...
# 4             UGA  Unemployment, total (% of total labor force) (...
# 5             UGA  Unemployment, total (% of total labor force) (...
# 6             UGA  Unemployment, male (% of male labor force) (mo...
# 7             UGA  Unemployment, male (% of male labor force) (na...
# 8             UGA  Unemployment, female (% of female labor force)...
# 9             UGA  Unemployment, female (% of female labor force)...
# 10            UGA  Share of youth not in education, employment or...
# 11            UGA  Share of youth not in education, employment or...
# 12            UGA  Share of youth not in education, employment or...
# ...
