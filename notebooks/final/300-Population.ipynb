# %% [markdown]
# # Population
# ## Purpose
# Takes in the .csv file created in the popualtion analysis notebook and examines the realtionship between poplation and medals won
#
# ## Datasets

# %% [markdown]
# Import Necessary Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import math
import os.path
from sklearn.linear_model import LinearRegression 
from glob import glob

# %% [markdown]
# ## Loading in Dataset

# %%
filepath = '../../data/final/population.csv'

# %% [markdown]
# Reads the .csv file into a dataframe

# %%
if not os.path.exists( filepath ):
    print("Missing dataset file")
else:
    df = pd.read_csv(filepath , encoding = "ISO-8859-1")
    print("File Read")
# Out:
# File Read

# %% [markdown]
# Print the first five liens of the dataframe

# %%
df.head()
# Out:
#        Country  Host_City  Year Gender  Gold  Silver  Bronze  Total_Medals  \
# 0  Afghanistan    Beijing  2008    Men     0       0       1             1
# 1  Afghanistan     London  2012    Men     0       0       1             1
# 2      Algeria    Atlanta  1996    Men     2       0       1             3
# 3      Algeria  Barcelone  1992    Men     0       0       1             1
# 4      Algeria  Barcelone  1992  Women     1       0       0             1
#
#    Ath_Rating  Gold_Share      ...       norm_Gold_Share  norm_Medal_Share  \
# 0           1    0.000000      ...              0.000000          0.000000
# 1           1    0.000000      ...              0.000000          0.000101
# 2           7    0.003252      ...              0.007588          0.004735
# 3           1    0.000000      ...              0.000000          0.000394
# 4           3    0.001779      ...              0.004152          0.000394
#
#    norm_Rating_Share  norm_Population  norm_Population_Density  \
# 0           0.000000         0.019780                 0.005080
# 1           0.000048         0.022249                 0.005726
# 2           0.006418         0.021316                 0.001466
# 3           0.000184         0.019699                 0.001347
# 4           0.002484         0.019699                 0.001347
#
#    norm_Male_Representation  norm_Female_Representation  \
# 0                  0.000246                    0.000315
# 1                  0.000372                    0.000280
# 2                  0.003090                    0.001726
# 3                  0.002904                    0.000622
# 4                  0.002904                    0.000622
#
#    norm_Population_Representation  norm_Males  norm_Females
# 0                        0.000273    0.019769      0.019792
# 1                        0.000379    0.022204      0.022296
# 2                        0.003190    0.020957      0.021698
# 3                        0.002739    0.019361      0.020057
# 4                        0.002739    0.019361      0.020057
#
# [5 rows x 34 columns]

# %% [markdown]
# # Sets Figure settings

# %%
plt.rc('font', size=12)          # controls default text sizes
plt.rc('axes', titlesize=15)     # fontsize of the axes title
plt.rc('axes', labelsize=15)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=15)    # fontsize of the tick labels
plt.rc('ytick', labelsize=15)    # fontsize of the tick labels
plt.rc('legend', fontsize=15)    # legend fontsize
plt.rc('figure', titlesize=20, figsize=(15, 7.5))

# %% [markdown]
# # Basic Analysis

# %%
df.columns
# Out:
# Index(['Country', 'Host_City', 'Year', 'Gender', 'Gold', 'Silver', 'Bronze',
#        'Total_Medals', 'Ath_Rating', 'Gold_Share', 'Medal_Share',
#        'Rating_Share', 'Males', 'Females', 'Summer', 'Winter',
#        'Population_Density', 'Population', 'NOC_Males_Sent',
#        'NOC_Females_Sent', 'NOC_Total_Sent', 'Female_Representation',
#        'Male_Representation', 'Population_Representation', 'norm_Gold_Share',
#        'norm_Medal_Share', 'norm_Rating_Share', 'norm_Population',
#        'norm_Population_Density', 'norm_Male_Representation',
#        'norm_Female_Representation', 'norm_Population_Representation',
#        'norm_Males', 'norm_Females'],
#       dtype='object')

# %%
df[['Rating_Share', 'Males', 'Females', 'Summer', 'Winter',
       'Population_Density', 'Population', 'NOC_Males_Sent',
       'NOC_Females_Sent', 'NOC_Total_Sent', 'Female_Representation',
       'Male_Representation', 'Population_Representation']].describe()
# Out:
#        Rating_Share         Males       Females  Population_Density  \
# count   1898.000000  1.898000e+03  1.898000e+03         1898.000000
# mean       0.016728  3.415993e+07  3.439341e+07          147.421087
# std        0.029546  9.153397e+07  8.712660e+07          414.760823
# min        0.000248  1.140400e+04  1.252200e+04            0.774571
# 25%        0.001280  3.733198e+06  3.961458e+06           23.193431
# 50%        0.005008  9.725721e+06  9.934960e+06           91.584983
# 75%        0.018603  2.803873e+07  2.931480e+07          169.520618
# max        0.256757  7.103734e+08  6.682916e+08         8161.983988
#
#          Population  NOC_Males_Sent  NOC_Females_Sent  NOC_Total_Sent  \
# count  1.898000e+03     1898.000000       1898.000000     1898.000000
# mean   6.855334e+07       80.846154         41.342993      122.189146
# std    1.786134e+08       70.471591         49.824932      113.531951
# min    2.392600e+04        1.000000          0.000000        1.000000
# 25%    7.570473e+06       31.000000         10.000000       45.000000
# 50%    1.967835e+07       58.000000         23.000000       82.000000
# 75%    5.758040e+07      107.000000         51.750000      158.750000
# max    1.378665e+09      379.000000        292.000000      649.000000
#
#        Female_Representation  Male_Representation  Population_Representation
# count           1.898000e+03         1.898000e+03               1.898000e+03
# mean            5.604750e-06         1.372722e-05               9.579786e-06
# std             1.457438e-05         3.780611e-05               2.488503e-05
# min             0.000000e+00         1.144086e-08               2.013702e-08
# 25%             7.213287e-07         2.025303e-06               1.509191e-06
# 50%             2.443268e-06         6.749397e-06               4.948979e-06
# 75%             6.005773e-06         1.683685e-05               1.160402e-05
# max             2.395783e-04         8.216313e-04               4.627158e-04

# %%
df.sample(5)
# Out:
#        Country  Host_City  Year Gender  Gold  Silver  Bronze  Total_Medals  \
# 377       Cuba  Barcelone  1992  Women    14       1       4            19
# 848      Italy   Montréal  1976    Men     2      23       4            29
# 615     France      Turin  2006      F     1       0       5             6
# 1336    Poland      Turin  2006      M     0       1       0             1
# 498   Ethiopia    Atlanta  1996    Men     1       0       0             1
#
#       Ath_Rating  Gold_Share      ...       norm_Gold_Share  norm_Medal_Share  \
# 377           48    0.024911      ...              0.058126          0.044644
# 848           56    0.004662      ...              0.010878          0.091534
# 615            8    0.005682      ...              0.013258          0.045491
# 1336           2    0.000000      ...              0.000000          0.005862
# 498            3    0.001626      ...              0.003794          0.000202
#
#       norm_Rating_Share  norm_Population  norm_Population_Density  \
# 377            0.054234         0.007768                 0.013001
# 848            0.083293         0.040398                 0.022960
# 615            0.028429         0.046131                 0.014059
# 1336           0.006383         0.027648                 0.015194
# 498            0.002198         0.042891                 0.006287
#
#       norm_Male_Representation  norm_Female_Representation  \
# 377                   0.028122                    0.039185
# 848                   0.008238                    0.003943
# 615                   0.001936                    0.004122
# 1336                  0.001898                    0.003393
# 498                   0.000399                    0.001126
#
#       norm_Population_Representation  norm_Males  norm_Females
# 377                         0.035194    0.007596      0.007951
# 848                         0.008141    0.038189      0.042747
# 615                         0.002742    0.043925      0.048475
# 1336                        0.002506    0.025970      0.029432
# 498                         0.000614    0.041501      0.044369
#
# [5 rows x 34 columns]

# %%
temp = df.groupby(['Country','Host_City','Year'])['Gold_Share', 'Medal_Share','Rating_Share'].sum().reset_index()
tmp = df.groupby(['Country','Host_City','Year']).last().reset_index()[['Country','Host_City','Year','Males', 'Females', 'Summer', 'Winter',
       'Population_Density', 'Population', 'NOC_Males_Sent',
       'NOC_Females_Sent', 'NOC_Total_Sent', 'Female_Representation',
       'Male_Representation', 'Population_Representation','norm_Gold_Share',
       'norm_Medal_Share', 'norm_Rating_Share', 'norm_Population',
       'norm_Population_Density', 'norm_Male_Representation',
       'norm_Female_Representation', 'norm_Population_Representation',
       'norm_Males', 'norm_Females','Ath_Rating']]
df = pd.merge(temp, tmp,  how='left', left_on=['Country','Host_City','Year'], 
                    right_on = ['Country','Host_City','Year'])
df.head()
# Out:
#        Country  Host_City  Year  Gold_Share  Medal_Share  Rating_Share  \
# 0  Afghanistan    Beijing  2008    0.000000     0.000490      0.000248
# 1  Afghanistan     London  2012    0.000000     0.000514      0.000260
# 2      Algeria    Atlanta  1996    0.003252     0.001616      0.001894
# 3      Algeria  Barcelone  1992    0.001779     0.001168      0.001180
# 4      Algeria    Beijing  2008    0.000000     0.000981      0.000743
#
#         Males     Females  Summer  Winter     ...      norm_Medal_Share  \
# 0  14054874.0  13239157.0    True   False     ...              0.000000
# 1  15784301.0  14912657.0    True   False     ...              0.000101
# 2  14898762.0  14512653.0    True   False     ...              0.004735
# 3  13764639.0  13416455.0    True   False     ...              0.000394
# 4  17605574.0  17255141.0    True   False     ...              0.000000
#
#    norm_Rating_Share  norm_Population  norm_Population_Density  \
# 0           0.000000         0.019780                 0.005080
# 1           0.000048         0.022249                 0.005726
# 2           0.006418         0.021316                 0.001466
# 3           0.002484         0.019699                 0.001347
# 4           0.000000         0.025269                 0.001755
#
#    norm_Male_Representation  norm_Female_Representation  \
# 0                  0.000246                    0.000315
# 1                  0.000372                    0.000280
# 2                  0.003090                    0.001726
# 3                  0.002904                    0.000622
# 4                  0.002337                    0.005806
#
#    norm_Population_Representation  norm_Males  norm_Females  Ath_Rating
# 0                        0.000273    0.019769      0.019792           1
# 1                        0.000379    0.022204      0.022296           1
# 2                        0.003190    0.020957      0.021698           7
# 3                        0.002739    0.019361      0.020057           3
# 4                        0.003552    0.024768      0.025802           1
#
# [5 rows x 29 columns]

# %% [markdown]
# # Examining Population

# %% [markdown]
# ### Range
# Looking at the range of populations that exist and

# %%
range = df.sort_values('Population').reset_index().iloc[[0,-1]].set_index('Country').Population
range['Mean'] = df.Population.mean()
range
# Out:
# Country
# Liechtenstein    2.392600e+04
# China            1.378665e+09
# Mean             6.314859e+07
# Name: Population, dtype: float64

# %%
fig, ax = plt.subplots(facecolor='#fafaff')
range.sort_values().plot(kind='barh',color='#ff8800')

plt.grid()
plt.ylabel('',fontsize=20)
plt.xlabel('Population (Billions)',fontsize=20)
fig.suptitle('Populations', fontsize=25)
ax.set_axisbelow(True)


plt.show()
fig.savefig('../../data/final/Graphs/PopRange.png')

# %%
popVals = df.sort_values('Population').reset_index().iloc[[0,-1]].set_index('Country').Population
rangePop = popVals[popVals.index[1]]-popVals[popVals.index[0]]
print('The range of populations range is '+str(rangePop))
# Out:
# The range of populations range is 1378641074.0

# %% [markdown]
# # Distribution

# %%
fig, ax = plt.subplots(facecolor='#fafaff')
df.Population.hist(color='#ff8800')
plt.axvline(x=df.Population.mean(),color='k',label='Mean Population',linestyle='--')

fig.suptitle('Distribution of Population', fontsize=25)
plt.ylabel('')
plt.xlabel('Population (Billions)')
ax.set_axisbelow(True)
plt.legend()
plt.show()

fig.savefig('../../data/final/Graphs/PopDist.png')

# %%
fig, ax = plt.subplots(facecolor='#fafaff')

rangeArr.sort_values().plot(kind='barh',color='Green')

plt.grid()
plt.xlabel('GDP (Trillions)')
plt.ylabel('')
fig.suptitle('GDP Range', fontsize=25)
ax.set_axisbelow(True)


plt.show()
fig.savefig('../../data/final/Graphs/GDPRange.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-424-033d68f20a7f> in <module>()
#       1 fig, ax = plt.subplots(facecolor='#fafaff')
#       2
# ----> 3 rangeArr.sort_values().plot(kind='barh',color='Green')
#       4
#       5 plt.grid()
#
# NameError: name 'rangeArr' is not defined

# %% [markdown]
# # Populations

# %%
fig, ax = plt.subplots(facecolor='#fafaff')
df.sort_values('Population').Population.plot(kind='bar',color='#228B22')
plt.tick_params(
    axis='x',   
    which='both',      
    bottom='off',      
    top='off',         
    labelbottom='off') 
plt.rcParams.update({'font.size': 18})
plt.rcParams.update({'axes.titlepad': 30})
plt.ylabel('Population (Billions)',fontsize=20)
plt.xlabel('',fontsize=20)
fig.suptitle('Populations', fontsize=30)
fig.tight_layout()
fig.subplots_adjust(top=0.88)
plt.show()

# %%
fig, ax = plt.subplots(facecolor='#fafaff')
df.sort_values('Population').Population.apply(math.log).plot(kind='bar',color='#228B22')
plt.tick_params(
    axis='x',   
    which='both',      
    bottom='off',      
    top='off',         
    labelbottom='off') 
plt.rcParams.update({'font.size': 18})
plt.rcParams.update({'axes.titlepad': 30})
plt.ylabel('Log(Population)',fontsize=20)
plt.xlabel('',fontsize=20)
fig.suptitle('Natural Log of Population', fontsize=30)
fig.tight_layout()
fig.subplots_adjust(top=0.88)
plt.show()

# %%
df['Log_Pop'] = df.Population.apply(math.log)
df.head()
# Out:
#        Country  Host_City  Year  Gold_Share  Medal_Share  Rating_Share  \
# 0  Afghanistan    Beijing  2008    0.000000     0.000490      0.000248
# 1  Afghanistan     London  2012    0.000000     0.000514      0.000260
# 2      Algeria    Atlanta  1996    0.003252     0.001616      0.001894
# 3      Algeria  Barcelone  1992    0.001779     0.001168      0.001180
# 4      Algeria    Beijing  2008    0.000000     0.000981      0.000743
#
#         Males     Females  Summer  Winter    ...      norm_Rating_Share  \
# 0  14054874.0  13239157.0    True   False    ...               0.000000
# 1  15784301.0  14912657.0    True   False    ...               0.000048
# 2  14898762.0  14512653.0    True   False    ...               0.006418
# 3  13764639.0  13416455.0    True   False    ...               0.002484
# 4  17605574.0  17255141.0    True   False    ...               0.000000
#
#    norm_Population  norm_Population_Density  norm_Male_Representation  \
# 0         0.019780                 0.005080                  0.000246
# 1         0.022249                 0.005726                  0.000372
# 2         0.021316                 0.001466                  0.003090
# 3         0.019699                 0.001347                  0.002904
# 4         0.025269                 0.001755                  0.002337
#
#    norm_Female_Representation  norm_Population_Representation  norm_Males  \
# 0                    0.000315                        0.000273    0.019769
# 1                    0.000280                        0.000379    0.022204
# 2                    0.001726                        0.003190    0.020957
# 3                    0.000622                        0.002739    0.019361
# 4                    0.005806                        0.003552    0.024768
#
#    norm_Females  Ath_Rating    Log_Pop
# 0      0.019792           1  17.122179
# 1      0.022296           1  17.239674
# 2      0.021698           7  17.196893
# 3      0.020057           3  17.118032
# 4      0.025802           1  17.366871
#
# [5 rows x 30 columns]

# %%
mx = df.Log_Pop.max()
mn = df.Log_Pop.min()

# %%
df['norm_Log_Pop'] = df.Log_Pop.apply(lambda x : (x-mn)/(mx-mn))
df.head()
# Out:
#        Country  Host_City  Year  Gold_Share  Medal_Share  Rating_Share  \
# 0  Afghanistan    Beijing  2008    0.000000     0.000490      0.000248
# 1  Afghanistan     London  2012    0.000000     0.000514      0.000260
# 2      Algeria    Atlanta  1996    0.003252     0.001616      0.001894
# 3      Algeria  Barcelone  1992    0.001779     0.001168      0.001180
# 4      Algeria    Beijing  2008    0.000000     0.000981      0.000743
#
#         Males     Females  Summer  Winter      ...       norm_Population  \
# 0  14054874.0  13239157.0    True   False      ...              0.019780
# 1  15784301.0  14912657.0    True   False      ...              0.022249
# 2  14898762.0  14512653.0    True   False      ...              0.021316
# 3  13764639.0  13416455.0    True   False      ...              0.019699
# 4  17605574.0  17255141.0    True   False      ...              0.025269
#
#    norm_Population_Density  norm_Male_Representation  \
# 0                 0.005080                  0.000246
# 1                 0.005726                  0.000372
# 2                 0.001466                  0.003090
# 3                 0.001347                  0.002904
# 4                 0.001755                  0.002337
#
#    norm_Female_Representation  norm_Population_Representation  norm_Males  \
# 0                    0.000315                        0.000273    0.019769
# 1                    0.000280                        0.000379    0.022204
# 2                    0.001726                        0.003190    0.020957
# 3                    0.000622                        0.002739    0.019361
# 4                    0.005806                        0.003552    0.024768
#
#    norm_Females  Ath_Rating    Log_Pop  norm_Log_Pop
# 0      0.019792           1  17.122179      0.642189
# 1      0.022296           1  17.239674      0.652908
# 2      0.021698           7  17.196893      0.649005
# 3      0.020057           3  17.118032      0.641811
# 4      0.025802           1  17.366871      0.664512
#
# [5 rows x 31 columns]

# %% [markdown]
# ## Outliers

# %%
df[['Population']].boxplot()
plt.grid()
plt.rcParams.update({'font.size': 18})
plt.rcParams.update({'axes.titlepad': 30})
plt.ylabel('Poplualtion (Billions)',fontsize=20)
plt.xlabel('',fontsize=20)
ax.set_axisbelow(True)
fig.suptitle('', fontsize=30)
fig.tight_layout()
fig.subplots_adjust(top=0.88)
plt.show()

# %%
def outliers_iqr(ys):
    quartile_1, quartile_3 = np.percentile(ys, [25, 75])
    iqr = quartile_3 - quartile_1
    lower_bound = quartile_1 - (iqr * 1.5)
    upper_bound = quartile_3 + (iqr * 1.5)
    return np.where((ys > upper_bound) | (ys < lower_bound))

# %%
outliers = df.iloc[outliers_iqr(df.Population)][['Country','Host_City','Year','Population']].drop_duplicates()

# %%
outliers.Country.unique()
# Out:
# array(['Brazil', 'China', 'India', 'Indonesia', 'Japan', 'Mexico',
#        'Nigeria', 'Russian Federation', 'Soviet Union', 'Unified Team',
#        'United States'], dtype=object)

# %%
outliers.Population.min()
# Out:
# 124961000.0

# %% [markdown]
# # Ratings Per Captia

# %%
df['Rating_Capita'] = df.Ath_Rating/df.Population
df.head()
# Out:
#        Country  Host_City  Year  Gold_Share  Medal_Share  Rating_Share  \
# 0  Afghanistan    Beijing  2008    0.000000     0.000490      0.000248
# 1  Afghanistan     London  2012    0.000000     0.000514      0.000260
# 2      Algeria    Atlanta  1996    0.003252     0.001616      0.001894
# 3      Algeria  Barcelone  1992    0.001779     0.001168      0.001180
# 4      Algeria    Beijing  2008    0.000000     0.000981      0.000743
#
#         Males     Females  Summer  Winter      ...        \
# 0  14054874.0  13239157.0    True   False      ...
# 1  15784301.0  14912657.0    True   False      ...
# 2  14898762.0  14512653.0    True   False      ...
# 3  13764639.0  13416455.0    True   False      ...
# 4  17605574.0  17255141.0    True   False      ...
#
#    norm_Population_Density  norm_Male_Representation  \
# 0                 0.005080                  0.000246
# 1                 0.005726                  0.000372
# 2                 0.001466                  0.003090
# 3                 0.001347                  0.002904
# 4                 0.001755                  0.002337
#
#    norm_Female_Representation  norm_Population_Representation  norm_Males  \
# 0                    0.000315                        0.000273    0.019769
# 1                    0.000280                        0.000379    0.022204
# 2                    0.001726                        0.003190    0.020957
# 3                    0.000622                        0.002739    0.019361
# 4                    0.005806                        0.003552    0.024768
#
#    norm_Females  Ath_Rating    Log_Pop  norm_Log_Pop  Rating_Capita
# 0      0.019792           1  17.122179      0.642189   3.663805e-08
# 1      0.022296           1  17.239674      0.652908   3.257652e-08
# 2      0.021698           7  17.196893      0.649005   2.380028e-07
# 3      0.020057           3  17.118032      0.641811   1.103708e-07
# 4      0.025802           1  17.366871      0.664512   2.868558e-08
#
# [5 rows x 32 columns]

# %%
df['Rating_Share_Capita'] = df.Rating_Share/df.Population
df.head()
# Out:
#        Country  Host_City  Year  Gold_Share  Medal_Share  Rating_Share  \
# 0  Afghanistan    Beijing  2008    0.000000     0.000490      0.000248
# 1  Afghanistan     London  2012    0.000000     0.000514      0.000260
# 2      Algeria    Atlanta  1996    0.003252     0.001616      0.001894
# 3      Algeria  Barcelone  1992    0.001779     0.001168      0.001180
# 4      Algeria    Beijing  2008    0.000000     0.000981      0.000743
#
#         Males     Females  Summer  Winter         ...           \
# 0  14054874.0  13239157.0    True   False         ...
# 1  15784301.0  14912657.0    True   False         ...
# 2  14898762.0  14512653.0    True   False         ...
# 3  13764639.0  13416455.0    True   False         ...
# 4  17605574.0  17255141.0    True   False         ...
#
#    norm_Male_Representation  norm_Female_Representation  \
# 0                  0.000246                    0.000315
# 1                  0.000372                    0.000280
# 2                  0.003090                    0.001726
# 3                  0.002904                    0.000622
# 4                  0.002337                    0.005806
#
#    norm_Population_Representation  norm_Males  norm_Females  Ath_Rating  \
# 0                        0.000273    0.019769      0.019792           1
# 1                        0.000379    0.022204      0.022296           1
# 2                        0.003190    0.020957      0.021698           7
# 3                        0.002739    0.019361      0.020057           3
# 4                        0.003552    0.024768      0.025802           1
#
#      Log_Pop  norm_Log_Pop  Rating_Capita  Rating_Share_Capita
# 0  17.122179      0.642189   3.663805e-08         9.077812e-12
# 1  17.239674      0.652908   3.257652e-08         8.472436e-12
# 2  17.196893      0.649005   2.380028e-07         6.439471e-11
# 3  17.118032      0.641811   1.103708e-07         4.341036e-11
# 4  17.366871      0.664512   2.868558e-08         2.132229e-11
#
# [5 rows x 33 columns]

# %%
fig, ax = plt.subplots(facecolor='#fafaff')
temp = df.groupby(['Country'])['Rating_Capita'].mean().sort_values()
ten = df.groupby(['Country'])['Rating_Capita'].mean().sort_values().tail(10)
ten['United States'] = temp.loc['United States']
ten['Soviet Union'] = temp.loc['Soviet Union']
ten.sort_values().plot(kind='barh',ax=ax,color='#ff8800')


plt.grid()
plt.ylabel('')
plt.xlabel('Population (Billions)')
ax.set_axisbelow(True)
fig.suptitle('Ratings Relative to Population', fontsize=25)
plt.show()

fig.savefig('../../data/final/Graphs/AveRatingPerCaptia.png')

# %%
df[df.Country == 'Liechtenstein']
# Out:
#            Country    Host_City  Year  Gold_Share  Medal_Share  Rating_Share  \
# 652  Liechtenstein      Calgary  1988    0.000000     0.003788      0.001894
# 653  Liechtenstein    Innsbruck  1976    0.000000     0.009524      0.004762
# 654  Liechtenstein  Lake Placid  1980    0.027778     0.018349      0.022936
# 655  Liechtenstein     Sarajevo  1984    0.000000     0.009009      0.004505
#
#        Males  Females  Summer  Winter         ...           \
# 652  13388.0  14707.0   False    True         ...
# 653  11404.0  12522.0   False    True         ...
# 654  12328.0  13538.0   False    True         ...
# 655  12868.0  14143.0   False    True         ...
#
#      norm_Male_Representation  norm_Female_Representation  \
# 652                  1.000000                    0.567621
# 653                  0.640344                    1.000000
# 654                  0.394895                    0.924952
# 655                  0.662075                    0.885385
#
#      norm_Population_Representation  norm_Males  norm_Females  Ath_Rating  \
# 652                        1.000000    0.000003      0.000003           1
# 653                        0.812931    0.000000      0.000000           1
# 654                        0.584845    0.000001      0.000002           2
# 655                        0.800093    0.000002      0.000002           1
#
#        Log_Pop  norm_Log_Pop  Rating_Capita  Rating_Share_Capita
# 652  10.243347      0.014653       0.000036         6.741197e-08
# 653  10.082721      0.000000       0.000042         1.990264e-07
# 654  10.160685      0.007112       0.000077         8.867154e-07
# 655  10.203999      0.011064       0.000037         1.667656e-07
#
# [4 rows x 33 columns]

# %% [markdown]
# # Countries whos Populations have changed

# %%
countryDict = dict()
for country in df.Country.unique():
    temp = df[df.Country == country].sort_values('Year').reset_index()
    prev = temp.loc[0].Population
    last = temp.loc[len(temp)-1].Population
    diff = last-prev
    countryDict[country] = (diff/prev)*100
    print(country+" - "+str((diff/prev)*100)+"%")
# Out:
# Afghanistan - 12.4676600536%
# Algeria - 85.4678205796%
# Argentina - 112.654689893%
# Armenia - -7.68252785875%
# Australia - 134.780450538%
# Austria - 24.1193273283%
# Azerbaijan - 25.7538838078%
# Bahamas, The - 192.623674251%
# Bahrain - 9.61024198268%
# Barbados - 0.0%
# Belarus - -7.03901437372%
# Belgium - 23.9763220341%
# Bermuda - 0.0%
# Botswana - 0.0%
# Brazil - 187.577758139%
# Brtitsh West Indies - 0.0%
# Bulgaria - -9.40023952084%
# Burundi - 74.2082749004%
# Cameroon - 239.584815896%
# Canada - 102.615482521%
# Chile - 30.0797055201%
# China - 32.9698840209%
# Colombia - 110.194984595%
# Costa Rica - 33.3118360419%
# Cote d'Ivoire - 141.153942248%
# Croatia - -6.69798657718%
# Cuba - 47.3708339358%
# Cyprus - 0.0%
# Czech Republic - 2.38862087662%
# Czechoslovakia - 14.2942469847%
# Denmark - 25.1444284581%
# Djibouti - 0.0%
# Dominican Republic - 67.6559913042%
# Ecuador - 23.6580474018%
# Egypt, Arab Rep. - 254.448035976%
# Eritrea - 0.0%
# Estonia - -14.1289721223%
# Ethiopia - 362.290238965%
# Fiji - 0.0%
# Finland - 24.0530481751%
# France - 42.8969332556%
# Gabon - 0.0%
# Georgia - -19.4276553801%
# Germany - 2.53407403036%
# Germany (Split) - 1.10008738806%
# Ghana - 132.459212899%
# Greece - 28.9857742544%
# Grenada - 1.74059783279%
# Guatemala - 0.0%
# Guyana - 0.0%
# Hong Kong SAR, China - 11.1739569575%
# Hungary - -1.66275589653%
# Iceland - 32.5258547624%
# India - 194.600329899%
# Indonesia - 49.2080510024%
# Iran, Islamic Rep. - 266.448091727%
# Iraq - 0.0%
# Ireland - 66.5100905269%
# Israel - 66.8377903572%
# Italy - 20.7190282014%
# Jamaica - 57.8277233157%
# Japan - 37.2905142684%
# Jordan - 0.0%
# Kazakhstan - 10.5735443221%
# Kenya - 426.747173988%
# Korea, Dem. People?s Rep. - 106.54416691%
# Korea, Rep. - 83.1240107125%
# Kosovo - 0.0%
# Kuwait - 65.5770280109%
# Kyrgyz Republic - 8.58035276825%
# Latvia - -23.7366400213%
# Liechtenstein - 17.4245590571%
# Lithuania - -22.3727160839%
# Luxembourg - 0.0%
# Macedonia, FYR - 0.0%
# Malaysia - 64.0336492551%
# Mauritius - 0.0%
# Mexico - 234.101872494%
# Moldova - -3.15583295254%
# Mongolia - 150.798439902%
# Montenegro - 0.0%
# Morocco - 186.139387885%
# Mozambique - 11.1978644815%
# Namibia - 12.7347113504%
# Netherlands - 48.1583938755%
# New Zealand - 97.8539505861%
# Niger - 333.570654675%
# Nigeria - 279.059667295%
# Norway - 46.1206303182%
# Pakistan - 153.287594343%
# Panama - 0.0%
# Paraguay - 0.0%
# Peru - 19.044770818%
# Philippines - 244.827452478%
# Poland - 28.0407592421%
# Portugal - 16.5606461079%
# Puerto Rico - 12.0719653439%
# Qatar - 418.610663206%
# Romania - 7.05385288836%
# Russian Federation - -2.69226890303%
# Samoa - 0.0%
# Saudi Arabia - 40.0785973549%
# Senegal - 0.0%
# Serbia - -3.98368920014%
# Serbia and Montenegro - 0.0%
# Singapore - 240.578413508%
# Slovak Republic - 1.02995127258%
# Slovenia - 3.42334427583%
# South Africa - 221.382418525%
# Soviet Union - 33.1514482398%
# Spain - 52.5002758168%
# Sri Lanka - 0.0%
# Sudan - 0.0%
# Suriname - 8.01551389787%
# Sweden - 32.3123200318%
# Switzerland - 57.1390737725%
# Syrian Arab Republic - 72.9967281803%
# Taiwan - 120.120890927%
# Tajikistan - 19.4976201577%
# Tanzania - 0.0%
# Thailand - 58.7198155312%
# Togo - 0.0%
# Tonga - 0.0%
# Trinidad and Tobago - 51.1125626194%
# Tunisia - 155.757858221%
# Turkey - 189.427300508%
# Uganda - 309.186558653%
# Ukraine - -13.3209886913%
# Unified Team - 42.272300265%
# United Arab Emirates - 126.755588585%
# United Kingdom - 25.2619064885%
# United States - 78.8485772481%
# United Team of Germany - 3.43808341425%
# Uruguay - 24.6063427866%
# Uzbekistan - 42.3256021808%
# Venezuela, RB - 287.489528157%
# Vietnam - 19.4126307952%
# Virgin Islands (U.S.) - 0.0%
# Yugoslavia - 13.4600148203%
# Zambia - 39.4069091295%
# Zimbabwe - 89.2538174684%

# %%
sortedDict = [(k, countryDict[k]) for k in sorted(countryDict, key=countryDict.get, reverse=True)]
sortedDict
# Out:
# [('Kenya', 426.74717398844388),
#  ('Qatar', 418.61066320630778),
#  ('Ethiopia', 362.29023896499336),
#  ('Niger', 333.57065467469283),
#  ('Uganda', 309.1865586526194),
#  ('Venezuela, RB', 287.48952815733497),
#  ('Nigeria', 279.05966729465678),
#  ('Iran, Islamic Rep.', 266.44809172706886),
#  ('Egypt, Arab Rep.', 254.44803597558248),
#  ('Philippines', 244.82745247819335),
#  ('Singapore', 240.57841350826044),
#  ('Cameroon', 239.58481589592742),
#  ('Mexico', 234.10187249411331),
#  ('South Africa', 221.38241852451145),
#  ('India', 194.6003298989931),
#  ('Bahamas, The', 192.62367425092373),
#  ('Turkey', 189.42730050828231),
#  ('Brazil', 187.57775813871217),
#  ('Morocco', 186.13938788494849),
#  ('Tunisia', 155.75785822086746),
#  ('Pakistan', 153.28759434254158),
#  ('Mongolia', 150.79843990244419),
#  ("Cote d'Ivoire", 141.1539422484405),
#  ('Australia', 134.78045053766968),
#  ('Ghana', 132.45921289926306),
#  ('United Arab Emirates', 126.75558858503237),
#  ('Taiwan', 120.12089092652741),
#  ('Argentina', 112.65468989273282),
#  ('Colombia', 110.1949845946328),
#  ('Korea, Dem. People?s Rep.', 106.54416691044328),
#  ('Canada', 102.61548252055712),
#  ('New Zealand', 97.85395058605279),
#  ('Zimbabwe', 89.253817468368993),
#  ('Algeria', 85.467820579593734),
#  ('Korea, Rep.', 83.124010712490687),
#  ('United States', 78.848577248147194),
#  ('Burundi', 74.208274900382577),
#  ('Syrian Arab Republic', 72.996728180347731),
#  ('Dominican Republic', 67.655991304199972),
#  ('Israel', 66.837790357212569),
#  ('Ireland', 66.510090526940047),
#  ('Kuwait', 65.577028010850711),
#  ('Malaysia', 64.033649255098851),
#  ('Thailand', 58.71981553116531),
#  ('Jamaica', 57.827723315693788),
#  ('Switzerland', 57.139073772477978),
#  ('Spain', 52.500275816778853),
#  ('Trinidad and Tobago', 51.112562619357341),
#  ('Indonesia', 49.208051002430182),
#  ('Netherlands', 48.158393875453996),
#  ('Cuba', 47.370833935821935),
#  ('Norway', 46.12063031816642),
#  ('France', 42.896933255582056),
#  ('Uzbekistan', 42.325602180810655),
#  ('Unified Team', 42.272300265029891),
#  ('Saudi Arabia', 40.078597354923197),
#  ('Zambia', 39.406909129491829),
#  ('Japan', 37.29051426838744),
#  ('Costa Rica', 33.311836041890174),
#  ('Soviet Union', 33.151448239823793),
#  ('China', 32.969884020929278),
#  ('Iceland', 32.525854762411747),
#  ('Sweden', 32.31232003180908),
#  ('Chile', 30.079705520131313),
#  ('Greece', 28.985774254431107),
#  ('Poland', 28.040759242107537),
#  ('Azerbaijan', 25.753883807806261),
#  ('United Kingdom', 25.261906488549617),
#  ('Denmark', 25.14442845809997),
#  ('Uruguay', 24.60634278660909),
#  ('Austria', 24.119327328305669),
#  ('Finland', 24.053048175086246),
#  ('Belgium', 23.976322034144577),
#  ('Ecuador', 23.658047401805575),
#  ('Italy', 20.719028201363756),
#  ('Tajikistan', 19.497620157685759),
#  ('Vietnam', 19.412630795211701),
#  ('Peru', 19.044770818045041),
#  ('Liechtenstein', 17.424559057092704),
#  ('Portugal', 16.560646107867989),
#  ('Czechoslovakia', 14.294246984715036),
#  ('Yugoslavia', 13.460014820299621),
#  ('Namibia', 12.734711350374342),
#  ('Afghanistan', 12.467660053584611),
#  ('Puerto Rico', 12.07196534393568),
#  ('Mozambique', 11.197864481501743),
#  ('Hong Kong SAR, China', 11.17395695750136),
#  ('Kazakhstan', 10.573544322129848),
#  ('Bahrain', 9.6102419826844283),
#  ('Kyrgyz Republic', 8.5803527682508562),
#  ('Suriname', 8.015513897866839),
#  ('Romania', 7.0538528883590148),
#  ('United Team of Germany', 3.4380834142462602),
#  ('Slovenia', 3.423344275826973),
#  ('Germany', 2.5340740303598164),
#  ('Czech Republic', 2.3886208766232415),
#  ('Grenada', 1.7405978327850513),
#  ('Germany (Split)', 1.1000873880580659),
#  ('Slovak Republic', 1.0299512725833979),
#  ('Barbados', 0.0),
#  ('Bermuda', 0.0),
#  ('Botswana', 0.0),
#  ('Brtitsh West Indies', 0.0),
#  ('Cyprus', 0.0),
#  ('Djibouti', 0.0),
#  ('Eritrea', 0.0),
#  ('Fiji', 0.0),
#  ('Gabon', 0.0),
#  ('Guatemala', 0.0),
#  ('Guyana', 0.0),
#  ('Iraq', 0.0),
#  ('Jordan', 0.0),
#  ('Kosovo', 0.0),
#  ('Luxembourg', 0.0),
#  ('Macedonia, FYR', 0.0),
#  ('Mauritius', 0.0),
#  ('Montenegro', 0.0),
#  ('Panama', 0.0),
#  ('Paraguay', 0.0),
#  ('Samoa', 0.0),
#  ('Senegal', 0.0),
#  ('Serbia and Montenegro', 0.0),
#  ('Sri Lanka', 0.0),
#  ('Sudan', 0.0),
#  ('Tanzania', 0.0),
#  ('Togo', 0.0),
#  ('Tonga', 0.0),
#  ('Virgin Islands (U.S.)', 0.0),
#  ('Hungary', -1.6627558965289047),
#  ('Russian Federation', -2.6922689030309566),
#  ('Moldova', -3.1558329525365427),
#  ('Serbia', -3.983689200135724),
#  ('Croatia', -6.6979865771812088),
#  ('Belarus', -7.0390143737166326),
#  ('Armenia', -7.6825278587469601),
#  ('Bulgaria', -9.4002395208363048),
#  ('Ukraine', -13.320988691270655),
#  ('Estonia', -14.128972122333247),
#  ('Georgia', -19.427655380082754),
#  ('Lithuania', -22.372716083882821),
#  ('Latvia', -23.736640021297934)]

# %%
sortedDict[0:3]
# Out:
# [('Kenya', 426.74717398844388),
#  ('Qatar', 418.61066320630778),
#  ('Ethiopia', 362.29023896499336)]

# %%
fig, ax = plt.subplots(facecolor='#fafaff')
df[df.Country == 'Kenya' ][['Country','Year','Host_City','Population']].drop_duplicates().sort_values('Year').set_index('Year').Population.plot(label='Kenya')
df[df.Country == 'Qatar' ][['Country','Year','Host_City','Population']].drop_duplicates().sort_values('Year').set_index('Year').Population.plot(label='Qatar')
df[df.Country == 'Ethiopia' ][['Country','Year','Host_City','Population']].drop_duplicates().sort_values('Year').set_index('Year').Population.plot(label='Ethiopia')
plt.legend()
plt.grid()
plt.rcParams.update({'font.size': 18})
plt.rcParams.update({'axes.titlepad': 30})
plt.ylabel('',fontsize=20)
plt.xlabel('',fontsize=20)
ax.set_axisbelow(True)
fig.suptitle('Populations Growth', fontsize=30)
fig.tight_layout()
fig.subplots_adjust(top=0.88)
plt.show()

# %%
df[df.Country == 'Qatar' ][['Year','Population']]
# Out:
#      Year  Population
# 853  1992    495517.0
# 854  2012   2109568.0
# 855  2016   2569804.0
# 856  2000    592267.0

# %%
df.columns
# Out:
# Index(['Country', 'Host_City', 'Year', 'Gold_Share', 'Medal_Share',
#        'Rating_Share', 'Males', 'Females', 'Summer', 'Winter',
#        'Population_Density', 'Population', 'NOC_Males_Sent',
#        'NOC_Females_Sent', 'NOC_Total_Sent', 'Female_Representation',
#        'Male_Representation', 'Population_Representation', 'norm_Gold_Share',
#        'norm_Medal_Share', 'norm_Rating_Share', 'norm_Population',
#        'norm_Population_Density', 'norm_Male_Representation',
#        'norm_Female_Representation', 'norm_Population_Representation',
#        'norm_Males', 'norm_Females', 'Ath_Rating', 'Log_Pop', 'norm_Log_Pop',
#        'Rating_Capita', 'Rating_Share_Capita'],
#       dtype='object')

# %% [markdown]
# # Examination of Atheletes Sent

# %%
repDF = df.set_index(['Country','Host_City','Summer','Year'])[['Male_Representation','Female_Representation']].reset_index()#.tail(10).plot(kind='bar')
aveRep = repDF.groupby(['Year','Summer'])[['Male_Representation','Female_Representation']].mean().reset_index('Summer')
repDF.head()
# Out:
#        Country  Host_City  Summer  Year  Male_Representation  \
# 0  Afghanistan    Beijing    True  2008         2.134491e-07
# 1  Afghanistan     London    True  2012         3.167704e-07
# 2      Algeria    Atlanta    True  1996         2.550547e-06
# 3      Algeria  Barcelone    True  1992         2.397448e-06
# 4      Algeria    Beijing    True  2008         1.931207e-06
#
#    Female_Representation
# 0           7.553351e-08
# 1           6.705713e-08
# 2           4.134323e-07
# 3           1.490707e-07
# 4           1.390890e-06

# %%
Max_Male = [] 
Min_Male = []

Max_Female = [] 
Min_Female = []

for i in aveRep.reset_index().index:
    year = aveRep.reset_index().loc[i].Year
    summer = aveRep.reset_index().loc[i].Summer
    Max_Male.append(repDF.set_index(['Year','Summer']).loc[year].loc[summer]['Male_Representation'].max())
    Min_Male.append(repDF.set_index(['Year','Summer']).loc[year].loc[summer]['Male_Representation'].min())
    Max_Female.append(repDF.set_index(['Year','Summer']).loc[year].loc[summer]['Female_Representation'].max())
    Min_Female.append(repDF.set_index(['Year','Summer']).loc[year].loc[summer]['Female_Representation'].min())
    
aveRep['Max_Male_Representation'] = Max_Male
aveRep['Min_Male_Representation'] = Min_Male
aveRep['Max_Female_Representation'] = Max_Female
aveRep['Min_Female_Representation'] = Min_Female
aveRep.head()
# Out:
#       Summer  Male_Representation  Female_Representation  \
# Year
# 1960   False             0.000005               0.000001
# 1960    True             0.000013               0.000001
# 1964   False             0.000007               0.000001
# 1964    True             0.000015               0.000001
# 1968   False             0.000008               0.000002
#
#       Max_Male_Representation  Min_Male_Representation  \
# Year
# 1960                 0.000020             4.883051e-07
# 1960                 0.000057             1.940249e-07
# 1964                 0.000028             5.127116e-07
# 1964                 0.000154             2.063633e-07
# 1968                 0.000029             4.865897e-07
#
#       Max_Female_Representation  Min_Female_Representation
# Year
# 1960                   0.000003               1.201737e-07
# 1960                   0.000006               0.000000e+00
# 1964                   0.000004               1.303169e-07
# 1964                   0.000007               0.000000e+00
# 1968                   0.000006               9.915909e-08

# %%
athSent = df.groupby(['Year','Summer'])[['NOC_Males_Sent','NOC_Females_Sent', 'NOC_Total_Sent']].sum().reset_index('Summer')
athSent[athSent.Summer][['NOC_Males_Sent','NOC_Females_Sent', 'NOC_Total_Sent']].plot(kind='bar', color=['blue','#FF69B4','red'])
plt.title('Athletes sent to the Summer Games')

athSent[~athSent.Summer][['NOC_Males_Sent','NOC_Females_Sent', 'NOC_Total_Sent']].plot(kind = 'bar',color=['blue','#FF69B4','red'])
plt.title('Athletes sent to the Winter Games')
plt.show()
plt.show()

# %%
sumAve= aveRep[aveRep.Summer]
sumAve.Male_Representation.plot(label='Average Male Representation')
plt.fill_between(sumAve.index,sumAve.Min_Male_Representation,sumAve.Max_Male_Representation,facecolor='blue', alpha=0.15,
                label='Male Representations')

sumAve.Female_Representation.plot(label='Average Female Representation')
plt.fill_between(sumAve.index,sumAve.Min_Female_Representation,sumAve.Max_Female_Representation,facecolor='orange', alpha=0.15,
                label='Female Representations')

plt.title('Gender Representation at the Summer Olympics')
plt.ylabel('Fraction of Population Sent')
plt.legend(loc='upper right')



plt.show()

# %%
winAve = aveRep[~aveRep.Summer]
winAve.Male_Representation.plot(label='Average Male Representation')
plt.fill_between(winAve.index,winAve.Min_Male_Representation,winAve.Max_Male_Representation,facecolor='blue', alpha=0.15,
                label='Male Representations')

winAve.Female_Representation.plot(label='Average Female Representation')
plt.fill_between(winAve.index,winAve.Min_Female_Representation,winAve.Max_Female_Representation,facecolor='orange', alpha=0.15,
                label='Female Representations')

plt.title('Gender Representation at the Winter Olympics')
plt.ylabel('Fraction of Population Sent')
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# ### Best and Worst Countries for Gender Participation

# %%
df.set_index(['Country','Host_City','Year']).sort_values('Female_Representation').tail(50).reset_index().Country.unique()
# Out:
# array(['Estonia', 'Slovenia', 'Australia', 'Jamaica', 'Croatia',
#        'New Zealand', 'Bulgaria', 'Tonga', 'Norway', 'Samoa', 'Bahrain',
#        'Denmark', 'Iceland', 'Grenada', 'Bermuda', 'Greece', 'Fiji',
#        'Barbados', 'Bahamas, The', 'Montenegro', 'Virgin Islands (U.S.)',
#        'Liechtenstein'], dtype=object)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax2 = ax.twinx() 

width = 0.3

df.set_index(['Country','Host_City','Year']).sort_values('Female_Representation').tail(50)['Female_Representation'].plot(kind='bar', color='#228B22',width=width, ax=ax, position=1,label='Female Participation')
df.set_index(['Country','Host_City','Year']).sort_values('Female_Representation').tail(50)['Population'].plot(kind='bar', color='grey', ax=ax2, width=width, position=0)
plt.title('Countries with the highest levels of Female Participation')
ax2.set_ylabel("Popualtion")
ax.set_ylabel("Female Representation")
plt.legend()
plt.show()

# %%
temp[temp.Female_Representation == 0].Country.unique()
# Out:
# array([], dtype=object)

# %% [markdown]
# The above countries have sent 0 female atheletes to games

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax2 = ax.twinx() 

width = 0.3

df.set_index(['Country','Host_City','Year']).sort_values('Male_Representation').tail(50)['Male_Representation'].plot(kind='bar', color='#228B22',width=width, ax=ax, position=1)
df.set_index(['Country','Host_City','Year']).sort_values('Male_Representation').tail(50)['Population'].plot(kind='bar', color='grey', ax=ax2, width=width, position=0)
plt.title('Countries with the highest levels of Male Participation')
ax2.set_ylabel("Popualtion")
ax.set_ylabel("Male Representation")
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax2 = ax.twinx() 

width = 0.3

df.set_index(['Country','Host_City','Year']).sort_values('Male_Representation').head(50)['Male_Representation'].plot(kind='bar', color='#228B22',width=width, ax=ax, position=1)
df.set_index(['Country','Host_City','Year']).sort_values('Male_Representation').head(50)['Population'].plot(kind='bar', color='grey', ax=ax2, width=width, position=0)
plt.title('Countries with the highest levels of Male Participation')
ax2.set_ylabel("Popualtion")
ax.set_ylabel("Male Representation")
plt.legend()
plt.show()

# %% [markdown]
# # Population as a factor of Olympic Success

# %%
df.columns
# Out:
# Index(['Country', 'Host_City', 'Year', 'Gold_Share', 'Medal_Share',
#        'Rating_Share', 'Males', 'Females', 'Summer', 'Winter',
#        'Population_Density', 'Population', 'NOC_Males_Sent',
#        'NOC_Females_Sent', 'NOC_Total_Sent', 'Female_Representation',
#        'Male_Representation', 'Population_Representation', 'norm_Gold_Share',
#        'norm_Medal_Share', 'norm_Rating_Share', 'norm_Population',
#        'norm_Population_Density', 'norm_Male_Representation',
#        'norm_Female_Representation', 'norm_Population_Representation',
#        'norm_Males', 'norm_Females', 'Ath_Rating', 'Log_Pop', 'norm_Log_Pop',
#        'Rating_Capita', 'Rating_Share_Capita'],
#       dtype='object')

# %%
def standardScatter(x,y,ytitle,xtitle,title):
    fig_size[0] = 12
    fig_size[1] = 12
    fig, ax = plt.subplots()
    ax.scatter(x,
                y,
                s=50,
                marker='o',
                facecolors='#228B22', 
                edgecolors='#228B22',
                )
    
    ax.set_ylabel(ytitle,fontsize=17)
    ax.set_xlabel(xtitle,fontsize=17)
    ax.set_title("\n"+title+"\n",fontsize=24)
    ax.locator_params(nbins=4)
    plt.tight_layout()
    plt.show()

# %%
def standardScatterWithRect(x,y,ytitle,xtitle,title,text,Rcorner,Rwidth,Rheight):
    fig_size[0] = 12
    fig_size[1] = 12
    plt.rcParams["figure.figsize"] = fig_size
    fig, ax = plt.subplots()
    ax.scatter(x,
                y,
                s=50,
                marker='o',
                facecolors='#228B22', 
                edgecolors='#228B22',
                )
    ax.add_patch(
        patches.Rectangle(
            Rcorner,
            Rwidth,
            Rheight,
            fill=False
        )
    )
    ax.text(Rcorner[0]+Rwidth+.01, Rcorner[1]+(Rheight/2),text, color='Black', fontsize=20)
    
    ax.set_ylabel(ytitle,fontsize=17)
    ax.set_xlabel(xtitle,fontsize=17)
    ax.set_title("\n"+title+"\n",fontsize=24)
    ax.locator_params(nbins=4)
    plt.tight_layout()
    plt.show()

# %%
def standardScatterLine(x,y,ytitle,xtitle,title):
    fig_size[0] = 12
    fig_size[1] = 12
    plt.rcParams["figure.figsize"] = fig_size
    fig, ax = plt.subplots(facecolor='#fafaff')
    x_nparray = (x.values).reshape(len(x), 1)
    y_nparray = (y.values).reshape(len(y), 1)
    
    regr = LinearRegression()
    regr.fit(x_nparray, y_nparray)
    
    fig, ax = plt.subplots()
    
    ax.plot(x_nparray, regr.predict(x_nparray), color='k', linewidth=4)
    ax.scatter(x,
                y,
                marker='o',
                facecolors='#228B22', 
                edgecolors='#228B22',
                )
    
    ax.set_ylabel(ytitle,fontsize=17)
    ax.set_xlabel(xtitle,fontsize=17)
    ax.set_title("\n"+title+"\n",fontsize=24)
    ax.locator_params(nbins=4)
    plt.tight_layout()
    plt.legend()
    plt.grid()
    plt.rcParams.update({'font.size': 18})
    plt.rcParams.update({'axes.titlepad': 30})
    ax.set_axisbelow(True)
    fig.tight_layout()
    fig.subplots_adjust(top=0.88)
    plt.show()

# %% [markdown]
# ## Population

# %%
standardScatter(df['norm_Rating_Share'],
                df.norm_Population,
                "Normalised Population",
                "Normalized Share Of Ratings",
                "Share of Ratings won in Individual Olympics by NOCs")

# %%
# Linear Regression 
x = df.norm_Rating_Share
y = df.norm_Population
x_nparray = (x.values).reshape(len(x), 1)
y_nparray = (y.values).reshape(len(y), 1)
regr = LinearRegression()
regr.fit(x_nparray, y_nparray)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
fig, ax = plt.subplots(facecolor='#fafaff')

ax.plot(x_nparray, regr.predict(x_nparray), color='black', linewidth=3)
ax.scatter(x, y, color='orange')
plt.legend()
plt.grid()
plt.xlabel('Normalised Population')
plt.ylabel('Normalised Rating Share')
fig.suptitle('Population and Rating Share', fontsize=25)
ax.set_axisbelow(True)
ax.legend(('Line of best Fit', 'Country'), bbox_to_anchor=(1, 1.01), loc=1)


plt.show()
fig.savefig('../../data/final/Graphs/Pop_Effect.png')

# %%
standardScatter(df['norm_Rating_Share'],
                df.norm_Population_Density,
                "Normalised Population",
                "Normalized Share Of Ratings",
                "Share of Ratings won in Individual Olympics by NOCs")

# %%
# Linear Regression 
x = df.norm_Rating_Share
y = df.norm_Population_Density
x_nparray = (x.values).reshape(len(x), 1)
y_nparray = (y.values).reshape(len(y), 1)
regr = LinearRegression()
regr.fit(x_nparray, y_nparray)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
fig, ax = plt.subplots(facecolor='#fafaff')

ax.plot(x_nparray, regr.predict(x_nparray), color='black', linewidth=3)
ax.scatter(x, y, color='orange')
plt.legend()
plt.grid()
plt.xlabel('Normalised Population')
plt.ylabel('Normalised Rating Share')
fig.suptitle('Population density and Rating Share', fontsize=25)
ax.set_axisbelow(True)
ax.legend(('Line of best Fit', 'Country'), bbox_to_anchor=(1, 1.01), loc=1)


plt.show()
fig.savefig('../../data/final/Graphs/PopD_Effect.png')

# %%
temp[temp.norm_Population > .25].Country.unique()
# Out:
# array([], dtype=object)

# %%
standardScatterWithRect(
                            df['norm_Rating_Share'],
                            df.norm_Population,
                            "Normalised Population",
                            "Normalized Share Of Ratings",
                            "Share of Ratings won in Individual Olympics by NOCs",
                            "China"+"\n"+"India",
                            (-0.02,0.28),
                            .3,
                            .77
               )

# %%
standardScatterLine(df['norm_Rating_Share'],
                df.norm_Population,
                "Normalised Population",
                "Normalized Share Of Ratings",
                "Share of Ratings won in Individual Olympics by NOCs")

# %%
p = temp['norm_Rating_Share'].corr(temp.norm_Population)
(p*p)*100
# Out:
# 97.714626742404562

# %%
standardScatterLine(df[df.norm_Population < .25]['norm_Rating_Share'],
                df[df.norm_Population < .25].norm_Population,
                "Normalised Population",
                "Normalized Share Of Ratings",
                "Share of Ratings won in Individual Olympics by NOCs")

# %%
p = temp[temp.norm_Population < .25]['norm_Rating_Share'].corr(temp[temp.norm_Population < .25].norm_Population)
(p*p)*100
# Out:
# 97.714626742404562

# %%
temp.columns
# Out:
# Index(['index', 'Country', 'Host_City', 'Year', 'Gold_Share', 'Medal_Share',
#        'Rating_Share', 'Males', 'Females', 'Summer', 'Winter',
#        'Population_Density', 'Population', 'NOC_Males_Sent',
#        'NOC_Females_Sent', 'NOC_Total_Sent', 'Female_Representation',
#        'Male_Representation', 'Population_Representation', 'norm_Gold_Share',
#        'norm_Medal_Share', 'norm_Rating_Share', 'norm_Population',
#        'norm_Population_Density', 'norm_Male_Representation',
#        'norm_Female_Representation', 'norm_Population_Representation',
#        'norm_Males', 'norm_Females', 'Ath_Rating', 'Log_Pop', 'norm_Log_Pop',
#        'Rating_Capita', 'Rating_Share_Capita'],
#       dtype='object')

# %%
standardScatter(df['norm_Rating_Share'],
                df.norm_Population_Density,
                "Normalised Population",
                "Normalized Share Of Ratings",
                "Share of Ratings won in Individual Olympics by NOCs")

# %%
temp[temp.norm_Population_Density > .1].Country.unique()
# Out:
# array([], dtype=object)

# %%
standardScatterWithRect(
                            temp['norm_Rating_Share'],
                            temp.norm_Population_Density,
                            "Normalised Population",
                            "Normalized Share Of Ratings",
                            "Share of Golds won in Individual Olympics by NOCs",
                            "Bahrain"+"\n"+"Bermuda"+"\n"+'Hong Kong'+"\n"+'Singapore',
                            (-0.02,0.1),
                            .05,
                            .92
               )

# %%
standardScatterLine(temp['norm_Rating_Share'],
                temp.norm_Population_Density,
                "Normalised Population",
                "Normalized Share Of Ratings",
                "Share of Ratings won in Individual Olympics by NOCs")

# %%
standardScatterLine(df[df.norm_Population_Density < .1]['norm_Rating_Share'],
                df[df.norm_Population_Density < .1].norm_Population_Density,
                "Normalised Population",
                "Normalized Share Of Ratings",
                "Share of Ratings won in Individual Olympics by NOCs")

# %%
temp.columns
# Out:
# Index(['Country', 'Host_City', 'Year', 'Gold_Share', 'Medal_Share',
#        'Rating_Share', 'Males', 'Females', 'Summer', 'Winter',
#        'Population_Density', 'Population', 'NOC_Males_Sent',
#        'NOC_Females_Sent', 'NOC_Total_Sent', 'Female_Representation',
#        'Male_Representation', 'Population_Representation', 'norm_Gold_Share',
#        'norm_Medal_Share', 'norm_Rating_Share', 'norm_Population',
#        'norm_Population_Density', 'norm_Male_Representation',
#        'norm_Female_Representation', 'norm_Population_Representation',
#        'norm_Males', 'norm_Females', 'norm_Log_Pop'],
#       dtype='object')

# %%
standardScatter(temp['norm_Rating_Share'],
                temp.norm_Population_Representation,
                "Normalised Population",
                "Normalized Share Of Ratings",
                "Share of Ratings won in Individual Olympics by NOCs")

# %%
temp[['norm_Medal_Share', 'norm_Rating_Share', 'norm_Population',
       'norm_Population_Density', 'norm_Male_Representation',
       'norm_Female_Representation', 'norm_Population_Representation',
       'norm_Males', 'norm_Females','norm_Log_Pop']].corr()
# Out:
#                                 norm_Medal_Share  norm_Rating_Share  \
# norm_Medal_Share                        1.000000           0.966559
# norm_Rating_Share                       0.966559           1.000000
# norm_Population                         0.158798           0.164896
# norm_Population_Density                -0.058182          -0.056389
# norm_Male_Representation               -0.065156          -0.066821
# norm_Female_Representation             -0.067092          -0.067054
# norm_Population_Representation         -0.069079          -0.070291
# norm_Males                              0.147593           0.153015
# norm_Females                            0.170517           0.177324
# norm_Log_Pop                            0.259785           0.269608
#
#                                 norm_Population  norm_Population_Density  \
# norm_Medal_Share                       0.158798                -0.058182
# norm_Rating_Share                      0.164896                -0.056389
# norm_Population                        1.000000                -0.007431
# norm_Population_Density               -0.007431                 1.000000
# norm_Male_Representation              -0.107911                -0.006590
# norm_Female_Representation            -0.111986                 0.006297
# norm_Population_Representation        -0.114368                -0.003459
# norm_Males                             0.999772                -0.006239
# norm_Females                           0.999748                -0.008681
# norm_Log_Pop                           0.590362                -0.040775
#
#                                 norm_Male_Representation  \
# norm_Medal_Share                               -0.065156
# norm_Rating_Share                              -0.066821
# norm_Population                                -0.107911
# norm_Population_Density                        -0.006590
# norm_Male_Representation                        1.000000
# norm_Female_Representation                      0.799787
# norm_Population_Representation                  0.986701
# norm_Males                                     -0.105544
# norm_Females                                   -0.110350
# norm_Log_Pop                                   -0.496966
#
#                                 norm_Female_Representation  \
# norm_Medal_Share                                 -0.067092
# norm_Rating_Share                                -0.067054
# norm_Population                                  -0.111986
# norm_Population_Density                           0.006297
# norm_Male_Representation                          0.799787
# norm_Female_Representation                        1.000000
# norm_Population_Representation                    0.885772
# norm_Males                                       -0.109620
# norm_Females                                     -0.114422
# norm_Log_Pop                                     -0.479074
#
#                                 norm_Population_Representation  norm_Males  \
# norm_Medal_Share                                     -0.069079    0.147593
# norm_Rating_Share                                    -0.070291    0.153015
# norm_Population                                      -0.114368    0.999772
# norm_Population_Density                              -0.003459   -0.006239
# norm_Male_Representation                              0.986701   -0.105544
# norm_Female_Representation                            0.885772   -0.109620
# norm_Population_Representation                        1.000000   -0.111877
# norm_Males                                           -0.111877    1.000000
# norm_Females                                         -0.116933    0.999041
# norm_Log_Pop                                         -0.515894    0.581622
#
#                                 norm_Females  norm_Log_Pop
# norm_Medal_Share                    0.170517      0.259785
# norm_Rating_Share                   0.177324      0.269608
# norm_Population                     0.999748      0.590362
# norm_Population_Density            -0.008681     -0.040775
# norm_Male_Representation           -0.110350     -0.496966
# norm_Female_Representation         -0.114422     -0.479074
# norm_Population_Representation     -0.116933     -0.515894
# norm_Males                          0.999041      0.581622
# norm_Females                        1.000000      0.599275
# norm_Log_Pop                        0.599275      1.000000

# %%
standardScatterLine(temp['norm_Rating_Share'],
                temp.norm_Log_Pop,
                "Normalised Population",
                "Normalized Share Of Ratings",
                "Share of Ratings won in Individual Olympics by NOCs")

# %%
temp['norm_Rating_Share'].corr(temp.norm_Log_Pop)
# Out:
# 0.26960806444539376
