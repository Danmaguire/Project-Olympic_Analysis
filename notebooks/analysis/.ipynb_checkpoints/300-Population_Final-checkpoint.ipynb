# %% [markdown]
# # Population

# %% [markdown]
# Import necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import os.path
from sklearn.linear_model import LinearRegression 
import math

# %% [markdown]
# Loads in the dataset

# %%
filepath = '../../data/analysis/population_data.csv'

# %%
if not os.path.exists( filepath ):
    print("Missing dataset file")
else:
    df = pd.read_csv(filepath , encoding = "ISO-8859-1")
    print("File Read")
# Out:
# File Read

# %%
df.head()
# Out:
#    Unnamed: 0  Year Host_City Host_Country  Total_Males  Total_Females  \
# 0           0  1960      Rome          ITA         4727            611
# 1           1  1960      Rome          ITA         4727            611
# 2           2  1960      Rome          ITA         4727            611
# 3           3  1960      Rome          ITA         4727            611
# 4           4  1960      Rome          ITA         4727            611
#
#    Total_Athletes  Summer  Winter Discipline  ...     Country  Population  \
# 0            5338    True   False    Sailing  ...   Argentina  20619075.0
# 1            5338    True   False    Sailing  ...   Argentina  20619075.0
# 2            5338    True   False    Sailing  ...   Argentina  20619075.0
# 3            5338    True   False     Boxing  ...   Argentina  20619075.0
# 4            5338    True   False   Swimming  ...   Australia  10276477.0
#
#         Males     Females  Life_Expectancy         Region  Elevation  \
# ...

# %% [markdown]
# Print the column names

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Year', 'Host_City', 'Host_Country', 'Total_Males',
#        'Total_Females', 'Total_Athletes', 'Summer', 'Winter', 'Discipline',
#        'Sport', 'Ath_Name', 'Gender', 'NOC', 'NOC_Males_Sent',
#        'NOC_Females_Sent', 'NOC_Total_Sent', 'Home_Adv', 'Gold', 'Silver',
#        'Bronze', 'Total_Medals', 'NOC_Gold', 'NOC_Silver', 'NOC_Bronze',
#        'NOC_Total_Medals', 'NOC_Rating', 'NOC_Rank', 'Ath_Rating', 'Ath_Rank',
#        'Country', 'Population', 'Males', 'Females', 'Life_Expectancy',
#        'Region', 'Elevation', 'Area_SqKM', 'Population_Density', 'Code'],
#       dtype='object')

# %% [markdown]
# ## Adding Column for Share of Medals and Rating won at a single games
# To quantify how successful countires are over different games in which different numbers of medals are given out we decided the best methof of comparison was to compare df.head() countries based on the share of medals won or ratings they won at a given Olympics, this gives us a method of comparrison between different games<br>
# To work out the fraction of medals and ratings taken home by each country we must first work out the total number of medals and total ratings awarded at each Games

# %%
totMeds = df.groupby(['Year','Host_City'])[['Gold','Total_Medals','Ath_Rating']].sum()
totMeds.head(10)
# Out:
#                    Gold  Total_Medals  Ath_Rating
# Year Host_City
# 1960 Rome           295           882        1758
#      Squaw Valley    50           147         295
# 1964 Innsbruck       60           185         372
#      Tokyo          331          1013        2013
# 1968 Grenoble        66           199         401
#      Mexico         341          1030        2051
# 1972 Munich         387          1184        2343
#      Sapporo         70           200         404
# 1976 Innsbruck       70           210         420
#      Montréal       429          1304        2591

# %% [markdown]
# The next stage is to figure out the number of gold medals and medals overall that were won for every games along with the ratings of each country and

# %%
countryDF = df.groupby(['Country','Host_City','Year','Gender'])[['Gold', 'Silver','Bronze', 'Total_Medals','Ath_Rating']].sum()
countryDF = countryDF.reset_index()
countryDF.head(10)
# Out:
#        Country    Host_City  Year Gender  Gold  Silver  Bronze  Total_Medals  \
# 0  Afghanistan      Beijing  2008    Men     0       0       1             1
# 1  Afghanistan       London  2012    Men     0       0       1             1
# 2      Algeria      Atlanta  1996    Men     2       0       1             3
# 3      Algeria    Barcelone  1992    Men     0       0       1             1
# 4      Algeria    Barcelone  1992  Women     1       0       0             1
# 5      Algeria      Beijing  2008    Men     0       1       0             1
# 6      Algeria      Beijing  2008  Women     0       0       1             1
# 7      Algeria       London  2012    Men     1       0       0             1
# 8      Algeria  Los Angeles  1984    Men     0       0       2             2
# 9      Algeria          Rio  2016    Men     0       2       0             2
#
#    Ath_Rating
# 0           1
# 1           1
# 2           7
# 3           1
# 4           3
# 5           2
# ...

# %% [markdown]
# ### Share of Golds

# %%
countryDF['Gold_Share'] = countryDF.apply(lambda x: x.Gold/totMeds.loc[x.Year].loc[x.Host_City].Gold, axis=1 )
countryDF.head()
# Out:
#        Country  Host_City  Year Gender  Gold  Silver  Bronze  Total_Medals  \
# 0  Afghanistan    Beijing  2008    Men     0       0       1             1
# 1  Afghanistan     London  2012    Men     0       0       1             1
# 2      Algeria    Atlanta  1996    Men     2       0       1             3
# 3      Algeria  Barcelone  1992    Men     0       0       1             1
# 4      Algeria  Barcelone  1992  Women     1       0       0             1
#
#    Ath_Rating  Gold_Share
# 0           1    0.000000
# 1           1    0.000000
# 2           7    0.003252
# 3           1    0.000000
# 4           3    0.001779

# %% [markdown]
# ### Share of Total Medals

# %%
countryDF['Medal_Share'] = countryDF.apply(lambda x: x.Total_Medals/totMeds.loc[x.Year].loc[x.Host_City].Total_Medals, axis=1 )
countryDF.head()
# Out:
#        Country  Host_City  Year Gender  Gold  Silver  Bronze  Total_Medals  \
# 0  Afghanistan    Beijing  2008    Men     0       0       1             1
# 1  Afghanistan     London  2012    Men     0       0       1             1
# 2      Algeria    Atlanta  1996    Men     2       0       1             3
# 3      Algeria  Barcelone  1992    Men     0       0       1             1
# 4      Algeria  Barcelone  1992  Women     1       0       0             1
#
#    Ath_Rating  Gold_Share  Medal_Share
# 0           1    0.000000     0.000490
# 1           1    0.000000     0.000514
# 2           7    0.003252     0.001616
# 3           1    0.000000     0.000584
# 4           3    0.001779     0.000584

# %% [markdown]
# ### Share of Ratings

# %%
countryDF['Rating_Share'] = countryDF.apply(lambda x: x.Ath_Rating/totMeds.loc[x.Year].loc[x.Host_City].Ath_Rating, axis=1 )
countryDF.head()
# Out:
#        Country  Host_City  Year Gender  Gold  Silver  Bronze  Total_Medals  \
# 0  Afghanistan    Beijing  2008    Men     0       0       1             1
# 1  Afghanistan     London  2012    Men     0       0       1             1
# 2      Algeria    Atlanta  1996    Men     2       0       1             3
# 3      Algeria  Barcelone  1992    Men     0       0       1             1
# 4      Algeria  Barcelone  1992  Women     1       0       0             1
#
#    Ath_Rating  Gold_Share  Medal_Share  Rating_Share
# 0           1    0.000000     0.000490      0.000248
# 1           1    0.000000     0.000514      0.000260
# 2           7    0.003252     0.001616      0.001894
# 3           1    0.000000     0.000584      0.000295
# 4           3    0.001779     0.000584      0.000885

# %% [markdown]
# # Adding in relevant Population Data
# The data for the population, number of males and females along with population density and how many athelets they sent to the games will now be added to the countryDF

# %% [markdown]
# Select the relevant data from the the dataframe

# %%
popDF = df[['Year','Host_City','Country','Males','Females','Summer','Winter','Population_Density','Population',
            'NOC_Males_Sent', 'NOC_Females_Sent','NOC_Total_Sent']]

popDF = popDF.drop_duplicates()
popDF.head()
# Out:
#     Year Host_City    Country       Males     Females  Summer  Winter  \
# 0   1960      Rome  Argentina  10471009.0  10148066.0    True   False
# 4   1960      Rome  Australia   5191453.0   5085024.0    True   False
# 28  1960      Rome    Austria   3282797.0   3764742.0    True   False
# 31  1960      Rome    Belgium   4503524.0   4649965.0    True   False
# 35  1960      Rome     Brazil  35952077.0  36255477.0    True   False
#
#     Population_Density  Population  NOC_Males_Sent  NOC_Females_Sent  \
# 0             7.429224  20619075.0            91.0               0.0
# 4             1.341123  10276477.0           165.0              29.0
# 28           83.004368   7047539.0            83.0              21.0
# 31          292.272576   9153489.0            86.0               8.0
# 35            8.575067  72207554.0            70.0               1.0
#
#     NOC_Total_Sent
# 0             91.0
# 4            194.0
# 28           104.0
# 31            94.0
# 35            71.0

# %% [markdown]
# The next step was to join the two dataframes together on Country, Year and Host_City columns

# %%
new_df = pd.merge(countryDF, popDF,  how='left', left_on=['Country','Host_City','Year'], 
                    right_on = ['Country','Host_City','Year'])
new_df.head()
# Out:
#        Country  Host_City  Year Gender  Gold  Silver  Bronze  Total_Medals  \
# 0  Afghanistan    Beijing  2008    Men     0       0       1             1
# 1  Afghanistan     London  2012    Men     0       0       1             1
# 2      Algeria    Atlanta  1996    Men     2       0       1             3
# 3      Algeria  Barcelone  1992    Men     0       0       1             1
# 4      Algeria  Barcelone  1992  Women     1       0       0             1
#
#    Ath_Rating  Gold_Share       ...        Rating_Share       Males  \
# 0           1    0.000000       ...            0.000248  14054874.0
# 1           1    0.000000       ...            0.000260  15784301.0
# 2           7    0.003252       ...            0.001894  14898762.0
# 3           1    0.000000       ...            0.000295  13764639.0
# 4           3    0.001779       ...            0.000885  13764639.0
#
#       Females  Summer  Winter  Population_Density  Population  NOC_Males_Sent  \
# ...

# %% [markdown]
# # Population Representation
# Examine the representation of each country in terms of the fraction of their population who compete at the games

# %% [markdown]
# ### Female

# %%
new_df['Female_Representation'] = new_df.NOC_Females_Sent/new_df.Females
new_df.head()
# Out:
#        Country  Host_City  Year Gender  Gold  Silver  Bronze  Total_Medals  \
# 0  Afghanistan    Beijing  2008    Men     0       0       1             1
# 1  Afghanistan     London  2012    Men     0       0       1             1
# 2      Algeria    Atlanta  1996    Men     2       0       1             3
# 3      Algeria  Barcelone  1992    Men     0       0       1             1
# 4      Algeria  Barcelone  1992  Women     1       0       0             1
#
#    Ath_Rating  Gold_Share          ...                 Males     Females  \
# 0           1    0.000000          ...            14054874.0  13239157.0
# 1           1    0.000000          ...            15784301.0  14912657.0
# 2           7    0.003252          ...            14898762.0  14512653.0
# 3           1    0.000000          ...            13764639.0  13416455.0
# 4           3    0.001779          ...            13764639.0  13416455.0
#
#    Summer  Winter  Population_Density  Population  NOC_Males_Sent  \
# ...

# %% [markdown]
# ### Male

# %%
new_df['Male_Representation'] = new_df.NOC_Males_Sent/new_df.Males
new_df.head()
# Out:
#        Country  Host_City  Year Gender  Gold  Silver  Bronze  Total_Medals  \
# 0  Afghanistan    Beijing  2008    Men     0       0       1             1
# 1  Afghanistan     London  2012    Men     0       0       1             1
# 2      Algeria    Atlanta  1996    Men     2       0       1             3
# 3      Algeria  Barcelone  1992    Men     0       0       1             1
# 4      Algeria  Barcelone  1992  Women     1       0       0             1
#
#    Ath_Rating  Gold_Share         ...              Females  Summer  Winter  \
# 0           1    0.000000         ...           13239157.0    True   False
# 1           1    0.000000         ...           14912657.0    True   False
# 2           7    0.003252         ...           14512653.0    True   False
# 3           1    0.000000         ...           13416455.0    True   False
# 4           3    0.001779         ...           13416455.0    True   False
#
# ...

# %% [markdown]
# ### Overall

# %%
new_df['Population_Representation'] = new_df.NOC_Total_Sent/new_df.Population
new_df.head()
# Out:
#        Country  Host_City  Year Gender  Gold  Silver  Bronze  Total_Medals  \
# 0  Afghanistan    Beijing  2008    Men     0       0       1             1
# 1  Afghanistan     London  2012    Men     0       0       1             1
# 2      Algeria    Atlanta  1996    Men     2       0       1             3
# 3      Algeria  Barcelone  1992    Men     0       0       1             1
# 4      Algeria  Barcelone  1992  Women     1       0       0             1
#
#    Ath_Rating  Gold_Share            ...              Summer  Winter  \
# 0           1    0.000000            ...                True   False
# 1           1    0.000000            ...                True   False
# 2           7    0.003252            ...                True   False
# 3           1    0.000000            ...                True   False
# 4           3    0.001779            ...                True   False
#
#    Population_Density  Population  NOC_Males_Sent  NOC_Females_Sent  \
# ...

# %% [markdown]
# # Normalising Data
# Now that all of the relevant data is stored within a single dataframe the next stage is to normalise it so that it is all within the same scale (0 - 1)<br>
#
# To normalise the data we decided to use the min max formalua

# %%
def minMaxNorm(mn,mx,val):
    return (val-mn)/(mx-mn)

# %% [markdown]
# ### Gold_Share

# %%
mn = new_df['Gold_Share'].min()
mx = new_df['Gold_Share'].max()
new_df['norm_Gold_Share'] = new_df['Gold_Share'].apply(lambda x: minMaxNorm(mn,mx,x))
new_df.head()
# Out:
#        Country  Host_City  Year Gender  Gold  Silver  Bronze  Total_Medals  \
# 0  Afghanistan    Beijing  2008    Men     0       0       1             1
# 1  Afghanistan     London  2012    Men     0       0       1             1
# 2      Algeria    Atlanta  1996    Men     2       0       1             3
# 3      Algeria  Barcelone  1992    Men     0       0       1             1
# 4      Algeria  Barcelone  1992  Women     1       0       0             1
#
#    Ath_Rating  Gold_Share       ...         Winter  Population_Density  \
# 0           1    0.000000       ...          False           42.236961
# 1           1    0.000000       ...          False           47.502922
# 2           7    0.003252       ...          False           12.735059
# 3           1    0.000000       ...          False           11.769336
# 4           3    0.001779       ...          False           11.769336
#
#    Population  NOC_Males_Sent  NOC_Females_Sent  NOC_Total_Sent  \
# ...

# %% [markdown]
# ### Medal_Share

# %%
mn = new_df['Medal_Share'].min()
mx = new_df['Medal_Share'].max()
new_df['norm_Medal_Share'] = new_df['Medal_Share'].apply(lambda x: minMaxNorm(mn,mx,x))
new_df.head()
# Out:
#        Country  Host_City  Year Gender  Gold  Silver  Bronze  Total_Medals  \
# 0  Afghanistan    Beijing  2008    Men     0       0       1             1
# 1  Afghanistan     London  2012    Men     0       0       1             1
# 2      Algeria    Atlanta  1996    Men     2       0       1             3
# 3      Algeria  Barcelone  1992    Men     0       0       1             1
# 4      Algeria  Barcelone  1992  Women     1       0       0             1
#
#    Ath_Rating  Gold_Share        ...         Population_Density  Population  \
# 0           1    0.000000        ...                  42.236961  27294031.0
# 1           1    0.000000        ...                  47.502922  30696958.0
# 2           7    0.003252        ...                  12.735059  29411415.0
# 3           1    0.000000        ...                  11.769336  27181094.0
# 4           3    0.001779        ...                  11.769336  27181094.0
#
# ...

# %% [markdown]
# ### Rating_Share

# %%
mn = new_df['Rating_Share'].min()
mx = new_df['Rating_Share'].max()
new_df['norm_Rating_Share'] = new_df['Rating_Share'].apply(lambda x: minMaxNorm(mn,mx,x))
new_df.head()
# Out:
#        Country  Host_City  Year Gender  Gold  Silver  Bronze  Total_Medals  \
# 0  Afghanistan    Beijing  2008    Men     0       0       1             1
# 1  Afghanistan     London  2012    Men     0       0       1             1
# 2      Algeria    Atlanta  1996    Men     2       0       1             3
# 3      Algeria  Barcelone  1992    Men     0       0       1             1
# 4      Algeria  Barcelone  1992  Women     1       0       0             1
#
#    Ath_Rating  Gold_Share        ...          Population  NOC_Males_Sent  \
# 0           1    0.000000        ...          27294031.0             3.0
# 1           1    0.000000        ...          30696958.0             5.0
# 2           7    0.003252        ...          29411415.0            38.0
# 3           1    0.000000        ...          27181094.0            33.0
# 4           3    0.001779        ...          27181094.0            33.0
#
#    NOC_Females_Sent  NOC_Total_Sent  Female_Representation  \
# ...

# %% [markdown]
# ### Population

# %%
mn = new_df['Population'].min()
mx = new_df['Population'].max()
new_df['norm_Population'] = new_df['Population'].apply(lambda x: minMaxNorm(mn,mx,x))
new_df.head()
# Out:
#        Country  Host_City  Year Gender  Gold  Silver  Bronze  Total_Medals  \
# 0  Afghanistan    Beijing  2008    Men     0       0       1             1
# 1  Afghanistan     London  2012    Men     0       0       1             1
# 2      Algeria    Atlanta  1996    Men     2       0       1             3
# 3      Algeria  Barcelone  1992    Men     0       0       1             1
# 4      Algeria  Barcelone  1992  Women     1       0       0             1
#
#    Ath_Rating  Gold_Share       ...         NOC_Males_Sent  NOC_Females_Sent  \
# 0           1    0.000000       ...                    3.0               1.0
# 1           1    0.000000       ...                    5.0               1.0
# 2           7    0.003252       ...                   38.0               6.0
# 3           1    0.000000       ...                   33.0               2.0
# 4           3    0.001779       ...                   33.0               2.0
#
# ...

# %% [markdown]
# ### Population Density

# %%
mn = new_df['Population_Density'].min()
mx = new_df['Population_Density'].max()
new_df['norm_Population_Density'] = new_df['Population_Density'].apply(lambda x: minMaxNorm(mn,mx,x))
new_df.head()
# Out:
#        Country  Host_City  Year Gender  Gold  Silver  Bronze  Total_Medals  \
# 0  Afghanistan    Beijing  2008    Men     0       0       1             1
# 1  Afghanistan     London  2012    Men     0       0       1             1
# 2      Algeria    Atlanta  1996    Men     2       0       1             3
# 3      Algeria  Barcelone  1992    Men     0       0       1             1
# 4      Algeria  Barcelone  1992  Women     1       0       0             1
#
#    Ath_Rating  Gold_Share           ...             NOC_Females_Sent  \
# 0           1    0.000000           ...                          1.0
# 1           1    0.000000           ...                          1.0
# 2           7    0.003252           ...                          6.0
# 3           1    0.000000           ...                          2.0
# 4           3    0.001779           ...                          2.0
#
#    NOC_Total_Sent  Female_Representation  Male_Representation  \
# ...

# %% [markdown]
# ### Male, Female and Overall Representation

# %%
columns = ['Male_Representation','Female_Representation','Population_Representation']
for col in columns:
    mn = new_df[col].min()
    mx = new_df[col].max()
    new_df['norm_'+col] = new_df[col].apply(lambda x: minMaxNorm(mn,mx,x))
new_df.head()
# Out:
#        Country  Host_City  Year Gender  Gold  Silver  Bronze  Total_Medals  \
# 0  Afghanistan    Beijing  2008    Men     0       0       1             1
# 1  Afghanistan     London  2012    Men     0       0       1             1
# 2      Algeria    Atlanta  1996    Men     2       0       1             3
# 3      Algeria  Barcelone  1992    Men     0       0       1             1
# 4      Algeria  Barcelone  1992  Women     1       0       0             1
#
#    Ath_Rating  Gold_Share               ...                \
# 0           1    0.000000               ...
# 1           1    0.000000               ...
# 2           7    0.003252               ...
# 3           1    0.000000               ...
# 4           3    0.001779               ...
#
#    Male_Representation  Population_Representation  norm_Gold_Share  \
# 0         2.134491e-07               1.465522e-07         0.000000
# 1         3.167704e-07               1.954591e-07         0.000000
# ...

# %% [markdown]
# ### Males and Females

# %%
columns = ['Males','Females']
for col in columns:
    mn = new_df[col].min()
    mx = new_df[col].max()
    new_df['norm_'+col] = new_df[col].apply(lambda x: minMaxNorm(mn,mx,x))
new_df.head()
# Out:
#        Country  Host_City  Year Gender  Gold  Silver  Bronze  Total_Medals  \
# 0  Afghanistan    Beijing  2008    Men     0       0       1             1
# 1  Afghanistan     London  2012    Men     0       0       1             1
# 2      Algeria    Atlanta  1996    Men     2       0       1             3
# 3      Algeria  Barcelone  1992    Men     0       0       1             1
# 4      Algeria  Barcelone  1992  Women     1       0       0             1
#
#    Ath_Rating  Gold_Share      ...       norm_Gold_Share  norm_Medal_Share  \
# 0           1    0.000000      ...              0.000000          0.000000
# 1           1    0.000000      ...              0.000000          0.000101
# 2           7    0.003252      ...              0.007588          0.004735
# 3           1    0.000000      ...              0.000000          0.000394
# 4           3    0.001779      ...              0.004152          0.000394
#
# ...

# %% [markdown]
# # Output Data for Final Analysis

# %%
new_df.to_csv('../../data/final/Population.csv', index=False)

# %%
new_df.columns
# Out:
# Index(['Country', 'Host_City', 'Year', 'Gender', 'Gold', 'Silver', 'Bronze',
#        'Total_Medals', 'Ath_Rating', 'Gold_Share', 'Medal_Share',
#        'Rating_Share', 'Males', 'Females', 'Summer', 'Winter',
#        'Population_Density', 'Population', 'NOC_Males_Sent',
#        'NOC_Females_Sent', 'NOC_Total_Sent', 'Female_Representation',
#        'Male_Representation', 'Population_Representation', 'norm_Gold_Share',
#        'norm_Medal_Share', 'norm_Rating_Share', 'norm_Population',
#        'norm_Population_Density', 'norm_Male_Representation',
#        'norm_Female_Representation', 'norm_Population_Representation',
#        'norm_Males', 'norm_Females'],
#       dtype='object')

# %% [markdown]
# # Initial Analysis of Population

# %% [markdown]
# ### Set Figure size

# %%
fig_size = plt.rcParams["figure.figsize"]
print ("Current size:"+str(fig_size))
# Out:
# Current size:[6.0, 4.0]

# %%
fig_size[0] = 10
fig_size[1] = 8
plt.rcParams["figure.figsize"] = fig_size

# %%
temp = new_df.groupby(['Country','Host_City','Year'])['Gold_Share', 'Medal_Share','Rating_Share'].sum().reset_index()
tmp = new_df.groupby(['Country','Host_City','Year']).last().reset_index()[['Country','Host_City','Year','Males', 'Females', 'Summer', 'Winter',
       'Population_Density', 'Population', 'NOC_Males_Sent',
       'NOC_Females_Sent', 'NOC_Total_Sent', 'Female_Representation',
       'Male_Representation', 'Population_Representation']]
temp = pd.merge(temp, tmp,  how='left', left_on=['Country','Host_City','Year'], 
                    right_on = ['Country','Host_City','Year'])
temp.head()
# Out:
#        Country  Host_City  Year  Gold_Share  Medal_Share  Rating_Share  \
# 0  Afghanistan    Beijing  2008    0.000000     0.000490      0.000248
# 1  Afghanistan     London  2012    0.000000     0.000514      0.000260
# 2      Algeria    Atlanta  1996    0.003252     0.001616      0.001894
# 3      Algeria  Barcelone  1992    0.001779     0.001168      0.001180
# 4      Algeria    Beijing  2008    0.000000     0.000981      0.000743
#
#         Males     Females  Summer  Winter  Population_Density  Population  \
# 0  14054874.0  13239157.0    True   False           42.236961  27294031.0
# 1  15784301.0  14912657.0    True   False           47.502922  30696958.0
# 2  14898762.0  14512653.0    True   False           12.735059  29411415.0
# 3  13764639.0  13416455.0    True   False           11.769336  27181094.0
# 4  17605574.0  17255141.0    True   False           15.094590  34860715.0
#
#    NOC_Males_Sent  NOC_Females_Sent  NOC_Total_Sent  Female_Representation  \
# ...

# %% [markdown]
# ## Representation

# %%
repDF = temp.set_index(['Country','Host_City','Summer','Year'])[['Male_Representation','Female_Representation']].reset_index()#.tail(10).plot(kind='bar')
aveRep = repDF.groupby(['Year','Summer'])[['Male_Representation','Female_Representation']].mean().reset_index('Summer')
repDF.head()
# Out:
#        Country  Host_City  Summer  Year  Male_Representation  \
# 0  Afghanistan    Beijing    True  2008         2.134491e-07
# 1  Afghanistan     London    True  2012         3.167704e-07
# 2      Algeria    Atlanta    True  1996         2.550547e-06
# 3      Algeria  Barcelone    True  1992         2.397448e-06
# 4      Algeria    Beijing    True  2008         1.931207e-06
#
#    Female_Representation
# 0           7.553351e-08
# 1           6.705713e-08
# 2           4.134323e-07
# 3           1.490707e-07
# 4           1.390890e-06

# %%
Max_Male = [] 
Min_Male = []

Max_Female = [] 
Min_Female = []

for i in aveRep.reset_index().index:
    year = aveRep.reset_index().loc[i].Year
    summer = aveRep.reset_index().loc[i].Summer
    Max_Male.append(repDF.set_index(['Year','Summer']).loc[year].loc[summer]['Male_Representation'].max())
    Min_Male.append(repDF.set_index(['Year','Summer']).loc[year].loc[summer]['Male_Representation'].min())
    Max_Female.append(repDF.set_index(['Year','Summer']).loc[year].loc[summer]['Female_Representation'].max())
    Min_Female.append(repDF.set_index(['Year','Summer']).loc[year].loc[summer]['Female_Representation'].min())
    
aveRep['Max_Male_Representation'] = Max_Male
aveRep['Min_Male_Representation'] = Min_Male
aveRep['Max_Female_Representation'] = Max_Female
aveRep['Min_Female_Representation'] = Min_Female
aveRep.head()
# Out:
#       Summer  Male_Representation  Female_Representation  \
# Year
# 1960   False             0.000005               0.000001
# 1960    True             0.000013               0.000001
# 1964   False             0.000007               0.000001
# 1964    True             0.000015               0.000001
# 1968   False             0.000008               0.000002
#
#       Max_Male_Representation  Min_Male_Representation  \
# Year
# 1960                 0.000020             4.883051e-07
# 1960                 0.000057             1.940249e-07
# 1964                 0.000028             5.127116e-07
# 1964                 0.000154             2.063633e-07
# 1968                 0.000029             4.865897e-07
#
#       Max_Female_Representation  Min_Female_Representation
# Year
# 1960                   0.000003               1.201737e-07
# 1960                   0.000006               0.000000e+00
# 1964                   0.000004               1.303169e-07
# ...

# %%
athSent = new_df.groupby(['Year','Summer'])[['NOC_Males_Sent','NOC_Females_Sent', 'NOC_Total_Sent']].sum().reset_index('Summer')
athSent[athSent.Summer][['NOC_Males_Sent','NOC_Females_Sent', 'NOC_Total_Sent']].plot(kind = 'bar', color=['blue','pink','red'])
plt.title('Athletes sent to the Summer Games')

athSent[~athSent.Summer][['NOC_Males_Sent','NOC_Females_Sent', 'NOC_Total_Sent']].plot(kind = 'bar',color=['blue','pink','red'])
plt.title('Athletes sent to the Winter Games')
plt.show()
plt.show()

# %%
sumAve= aveRep[aveRep.Summer]
sumAve.Male_Representation.plot(label='Average Male Representation')
plt.fill_between(sumAve.index,sumAve.Min_Male_Representation,sumAve.Max_Male_Representation,facecolor='blue', alpha=0.15,
                label='Male Representations')

sumAve.Female_Representation.plot(label='Average Female Representation')
plt.fill_between(sumAve.index,sumAve.Min_Female_Representation,sumAve.Max_Female_Representation,facecolor='orange', alpha=0.15,
                label='Female Representations')

plt.title('Gender Representation at the Summer Olympics')
plt.ylabel('Fraction of Population Sent')
plt.legend(loc='upper left')



plt.show()

# %%
winAve = aveRep[~aveRep.Summer]
winAve.Male_Representation.plot(label='Average Male Representation')
plt.fill_between(winAve.index,winAve.Min_Male_Representation,winAve.Max_Male_Representation,facecolor='blue', alpha=0.15,
                label='Male Representations')

winAve.Female_Representation.plot(label='Average Female Representation')
plt.fill_between(winAve.index,winAve.Min_Female_Representation,winAve.Max_Female_Representation,facecolor='orange', alpha=0.15,
                label='Female Representations')

plt.title('Gender Representation at the Winter Olympics')
plt.ylabel('Fraction of Population Sent')
plt.legend(loc='upper left')
plt.show()

# %%
temp.set_index(['Country','Host_City','Year'])['Female_Representation'].sort_values().tail(20).plot(kind='bar')
plt.title('Countries with the highest levels of Female Participation')
plt.show()
temp[temp.Female_Representation > 0].set_index(['Country','Host_City','Year'])['Female_Representation'].sort_values().head(20).plot(kind='bar')
plt.title('Countries with the lowest levels of Female Participation')
plt.show()

# %%
temp.set_index(['Country','Host_City','Year'])['Male_Representation'].sort_values().tail(20).plot(kind='bar')
plt.title('Countries with the highest levels of Male Participation')
plt.show()
temp[temp.Female_Representation > 0].set_index(['Country','Host_City','Year'])['Male_Representation'].sort_values().head(20).plot(kind='bar')
plt.title('Countries with the lowest levels of Male Participation')
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111) # Create matplotlib axes
ax2 = ax.twinx() # Create another axes that shares the same x-axis as ax.

width = 0.3


temp.set_index(['Country','Host_City','Year']).sort_values('Male_Representation').tail(50)['Male_Representation'].plot(kind='bar', color='red',width=width, ax=ax, position=1)
temp.set_index(['Country','Host_City','Year']).sort_values('Male_Representation').tail(50)['Population'].plot(kind='bar', color='grey', ax=ax2, width=width, position=0)

plt.title('Countries with the highest levels of Male Participation')


#temp.Population.plot(kind='bar', color='red', ax=ax, width=width, position=1)
#temp.Male_Representation.plot(kind='bar', color='blue', ax=ax2, width=width, position=0)

#ax.set_ylabel('Amount')
#ax2.set_ylabel('Price')


plt.show()

# %%
test = temp['Male_Representation']-temp['Female_Representation']
test.sort_values().tail(1)
# Out:
# 652    0.000686
# dtype: float64

# %%
temp.loc[652]
# Out:
# Country                      Liechtenstein
# Host_City                          Calgary
# Year                                  1988
# Gold_Share                               0
# Medal_Share                     0.00378788
# Rating_Share                    0.00189394
# Males                                13388
# Females                              14707
# Summer                               False
# Winter                                True
# Population_Density                 175.594
# Population                           28095
# NOC_Males_Sent                          11
# NOC_Females_Sent                         2
# NOC_Total_Sent                          13
# Female_Representation           0.00013599
# Male_Representation            0.000821631
# Population_Representation      0.000462716
# Name: 652, dtype: object

# %%
temp[temp['Male_Representation']-temp['Female_Representation'] < 0].Country.unique()
# Out:
# array(['Australia', 'Bahrain', 'Belarus', 'Bulgaria', 'Cameroon', 'Canada',
#        'China', 'Colombia', "Cote d'Ivoire", 'Denmark',
#        'Dominican Republic', 'Ethiopia', 'Finland', 'Hong Kong SAR, China',
#        'Iceland', 'Israel', 'Jamaica', 'Japan', 'Kazakhstan', 'Kenya',
#        'Korea, Dem. People?s Rep.', 'Korea, Rep.', 'Kosovo', 'Netherlands',
#        'Nigeria', 'Norway', 'Peru', 'Puerto Rico', 'Qatar', 'Romania',
#        'Singapore', 'Slovenia', 'Sweden', 'Taiwan', 'Thailand', 'Turkey',
#        'Ukraine', 'United States', 'Uzbekistan', 'Vietnam'], dtype=object)
