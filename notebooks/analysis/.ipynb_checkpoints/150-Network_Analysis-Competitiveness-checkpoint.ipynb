# %% [markdown]
# # Network Analysis of Competitiveness Nocs
# We want to create a network where we showcase the competitiveness between countries that meet on the podium of an event in each of the games. By competitiveness we mean a relationships between 1st and 2nd and 2nd and 3rd. We want to do this for all games summer and winter seperately than we'll will do it for winter and summer in general to get a broader view over time of these relationships. The relationships will differ from the last networks we created.
# *	If we have an event E.g. (USA, UK, RUS) where USA is 1st, UK 2nd etc.. the competitiveness relationships would look like:
# 	-> USA,UK <br>
# 	-> UK,RUS <br>
# *   If we had a draw situation E.g. (USA, UK, RUS, GER) where RUS and GER drew 3rd. The relationships would look like:
#     <br>
# 	-> USA,UK <br>
# 	-> UK,RUS <br>
#     -> UK, GER

# %%
import os.path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
# %matplotlib inline
from bs4 import BeautifulSoup
import webbrowser
import urllib.request
from lxml import html
import zipfile
import re
import string
import sys, os
from IPython.display import Image
import itertools

# %%
# Ensure the file exists
if not os.path.exists( r"..\..\data\prep\Games\Games-Unedited-500.csv" ):
    print("Missing dataset file")

# %%
# read the medal csv into a dataframe
df = pd.read_csv( r"..\..\data\prep\Games\Games-Unedited-500.csv" , encoding = "ISO-8859-1")

# %%
df.head(3)
# Out:
#           Ath_Name Host_City Discipline         Event Event_Gender Gender  \
# 0  WEBSTER, Robert      Rome     Diving  10m platform            M    Men
# 1     TOBIAN, Gary      Rome     Diving  10m platform            M    Men
# 2    PHELPS, Brian      Rome     Diving  10m platform            M    Men
#
#     Medal  NOC     Sport  Summer  Winter  Year
# 0    Gold  USA  Aquatics    True   False  1960
# 1  Silver  USA  Aquatics    True   False  1960
# 2  Bronze  GBR  Aquatics    True   False  1960

# %%
# dropping some redundant columns keeping only the ones we need
df = df.drop(df.columns[[0, 4, 8]], axis=1)

# %%
df.head(3)
# Out:
#   Host_City Discipline         Event Gender   Medal  NOC  Summer  Winter  Year
# 0      Rome     Diving  10m platform    Men    Gold  USA    True   False  1960
# 1      Rome     Diving  10m platform    Men  Silver  USA    True   False  1960
# 2      Rome     Diving  10m platform    Men  Bronze  GBR    True   False  1960

# %%
# Here we're sorting the df so we can find out which countires are podiuming together 
df= df.sort_values(by=['Host_City', 'Year', 'Summer', 'Winter', 'Gender', 'Event'], ascending=False)

# %% [markdown]
# # Multi athlete events
# Below we showcase the situation where mutliple athletes from each country are involved in an event meaning more than 3 medals are given out it will be (3 * Team size). We will have to remove all of the teams medal wins bar one  because we only want a team win to show up as a single occurance of a podium for a country. <br> </br>
# Another siutation to think about is the possability of a draw or if there is less than three medals awarded due to unforseen circumstances such as drug disquailfications etc.
# We're not sure as of yet about why some of the situations where less than three medals were awarded occurred but we've seen some examples of the boxing draw occuring.

# %%
df.head(10)
# Out:
#        Host_City     Discipline    Event Gender   Medal  NOC  Summer  Winter  \
# 27223  Vancouver      Bobsleigh  two-man      M  Bronze  RUS   False    True
# 27224  Vancouver      Bobsleigh  two-man      M  Bronze  RUS   False    True
# 27225  Vancouver      Bobsleigh  two-man      M    Gold  GER   False    True
# 27226  Vancouver      Bobsleigh  two-man      M    Gold  GER   False    True
# 27227  Vancouver      Bobsleigh  two-man      M  Silver  GER   False    True
# 27228  Vancouver      Bobsleigh  two-man      M  Silver  GER   False    True
# 27554  Vancouver  Alpine Skiing  super-G      M  Bronze  USA   False    True
# 27555  Vancouver  Alpine Skiing  super-G      M    Gold  NOR   False    True
# 27556  Vancouver  Alpine Skiing  super-G      M  Silver  USA   False    True
# 27542  Vancouver  Alpine Skiing   slalom      M  Bronze  SWE   False    True
#
#        Year
# 27223  2010
# 27224  2010
# 27225  2010
# 27226  2010
# 27227  2010
# 27228  2010
# 27554  2010
# 27555  2010
# 27556  2010
# 27542  2010

# %%
# here we're dropping all the team meaals and leaving one so the relationship will be intact
df = df.drop_duplicates(keep='first')

# %%
df.head(10)
# Out:
#        Host_City     Discipline    Event Gender   Medal  NOC  Summer  Winter  \
# 27223  Vancouver      Bobsleigh  two-man      M  Bronze  RUS   False    True
# 27225  Vancouver      Bobsleigh  two-man      M    Gold  GER   False    True
# 27227  Vancouver      Bobsleigh  two-man      M  Silver  GER   False    True
# 27554  Vancouver  Alpine Skiing  super-G      M  Bronze  USA   False    True
# 27555  Vancouver  Alpine Skiing  super-G      M    Gold  NOR   False    True
# 27556  Vancouver  Alpine Skiing  super-G      M  Silver  USA   False    True
# 27542  Vancouver  Alpine Skiing   slalom      M  Bronze  SWE   False    True
# 27543  Vancouver  Alpine Skiing   slalom      M    Gold  ITA   False    True
# 27544  Vancouver  Alpine Skiing   slalom      M  Silver  CRO   False    True
# 27409  Vancouver           Luge  singles      M  Bronze  ITA   False    True
#
#        Year
# 27223  2010
# 27225  2010
# 27227  2010
# 27554  2010
# 27555  2010
# 27556  2010
# 27542  2010
# 27543  2010
# 27544  2010
# 27409  2010

# %%
# Re-sorting again and dropping the previus index column
df= df.sort_values(by=['Year', 'Winter', 'Gender', 'Discipline', 'Event', 'Medal']).reset_index()
# dropping the old index column
df = df.drop(df.columns[[0]], axis=1)

# %%
# Changing the order of the columns 
df = df[['Year', 'Host_City', 'Summer', 'Winter', 'Discipline', 'Event', 'Gender', 'NOC' , 'Medal']]

# %%
df.head(1)
# Out:
#    Year Host_City  Summer  Winter Discipline   Event Gender  NOC   Medal
# 0  1960      Rome    True   False  Athletics  10000m    Men  AUS  Bronze

# %% [markdown]
# # Creating the relationships
# We've taken out the duplicate medals for team wins now we have to create the competitiveness relationships shared by podiuming countries split 1st -> 2nd and 2nd -> 3rd. Realationships will be between countries that win a medals in a certain event. We have to get these relationships for each event split into the different olympics by year and whether they are summer or winter and also. So we can create a sub networks for every olympics and then at the end we can have a network that covers all the olympics since 1960 however we'll probaly still spilt that into summer and winter games.

# %%
df.head(10)
# Out:
#    Year Host_City  Summer  Winter Discipline         Event Gender  NOC   Medal
# 0  1960      Rome    True   False  Athletics        10000m    Men  AUS  Bronze
# 1  1960      Rome    True   False  Athletics        10000m    Men  URS    Gold
# 2  1960      Rome    True   False  Athletics        10000m    Men  EUA  Silver
# 3  1960      Rome    True   False  Athletics          100m    Men  GBR  Bronze
# 4  1960      Rome    True   False  Athletics          100m    Men  EUA    Gold
# 5  1960      Rome    True   False  Athletics          100m    Men  USA  Silver
# 6  1960      Rome    True   False  Athletics  110m hurdles    Men  USA  Bronze
# 7  1960      Rome    True   False  Athletics  110m hurdles    Men  USA    Gold
# 8  1960      Rome    True   False  Athletics  110m hurdles    Men  USA  Silver
# 9  1960      Rome    True   False  Athletics         1500m    Men  HUN  Bronze

# %% [markdown]
# # How?
# I think the easiest way to do this would to just get an ordered list of all the NOCs who won a medal (podiumed) for each games. If the list is order as the df above we know each set of three have the podium relationsip. Then after we get these lists, one for each games we can then turn the list form e.g. ['GER', 'USA' 'CHN'....] to ['GER,CHN', 'GER,USA', 'USA,CHN'....].
# This is crucial because as of now one easy way to create a network of relationships is to have a csv containg nodes (Unique NOC names) and relationships (the lists we talked about above).
# <br></br>
# The other consideration we have to deal with is the sitatuions of draws and less than three medals awarded like we talked about above. This would mean that a list of all the NOCs sorted like this ['GER', 'USA' 'CHN'....] taking every three to be a podium  might not represent the relatioships correctly because as we said before we could have a draw sitatuion where four NOCs could be on a podium. <br> </br>
# This issue is addressed below by putting each events podiums into a seperate list and putting all these event lists into a list that represent that given olympic games. Then we will put all of these lists of games into a final list.
# <br></br>
# So to be clear we will have a main list of olympic games lists and in each olympic games list there will be lists for every event in that games containing every NOC that reaches the podium for that event.
# We will also need to split up each event list into lists of placings for the ** Competitivenss relationships ** so in the event of a draw like so: (USA, UK, RUS, GER) our event list would look like [ [USA], [UK], [RUS, GER] ].

# %%
# first I'll create a list to hold all of the lists for each olympics 
olympicGsList = []
# Then a list to hold the values for the current olympics Games
currGamesList = []
# Then a list to hold the values for the current olympics events 
currEventList = []
# Then a list to hold the values for the current olympics event placing  
goldList = []
silverList = []
bronzeList = []

# %% [markdown]
# Note: The Medals are sorted in the df alphabetically so bronze, gold silver.

# %%
# The lastyear and lasthost varaibles are needed so we can track when the games change in the iteration
lastyear = df['Year'].iloc[0]
lastHost = df['Host_City'].iloc[0]
# The lastyEvent and lastDis varaibles are needed so we can track when the events change in the iteration
lastEvent = df['Event'].iloc[0]
lastDis = df['Discipline'].iloc[0]
# tracking the current medal so each medal is part of a different list in each event list this covers draw situations 
lastPlacing = df['Medal'].iloc[0]

for x, row in df.iterrows():
    
    # current year and host to compare with the last years 
    curryear = df['Year'].iloc[x]
    currHost = df['Host_City'].iloc[x]
    
    # current placing to compare with last itertaion
    currPlacing = df['Medal'].iloc[x]
    
    # varaible for the country 
    country = df['NOC'].iloc[x]
    
    # current event and year 
    currEvent = df['Event'].iloc[x]
    currDis = df['Discipline'].iloc[x]
    
    
    # as long as the current host and year are the same we're in the same games
    # so each list representing an event is added to the currGamesList
    if(curryear == lastyear and currHost == lastHost):
        
         # as long as the current event and discipline are the same then these placing lists will be added to the currEventList 
        if( currEvent == lastEvent and currDis == lastDis):
            
            if(currPlacing == 'Bronze'):
                bronzeList.append(country)
            if(currPlacing == 'Silver'):
                silverList.append(country)
            if(currPlacing == 'Gold'):
                goldList.append(country)
            
            
            
            
            
         # when the event changes 
        else:

            # add the last medal list 
            currEventList.append(bronzeList)
            currEventList.append(silverList)
            currEventList.append(goldList)
            # add the ast event to currGames
            currGamesList.append(currEventList)
            # null both event and medal lists 
            currEventList = [] 
            goldList = []
            silverList = []
            bronzeList = []
                
            if(currPlacing == 'Bronze'):
                bronzeList.append(country)
            if(currPlacing == 'Sliver'):
                silverList.append(country)
            if(currPlacing == 'Gold'):
                goldList.append(country)

    
    # if we change to a new games 
    else:
        # add last placing list to event 
        currEventList.append(bronzeList)
        currEventList.append(silverList)
        currEventList.append(goldList)
        #add the last event to the currGames list 
        currGamesList.append(currEventList)
        #add this last games to the olympicGList
        olympicGsList.append(currGamesList)
        # null all lists 
        currGamesList = []
        currEventList = []
        goldList = []
        silverList = []
        bronzeList = []
        if(currPlacing == 'Bronze'):
            bronzeList.append(country)
        if(currPlacing == 'Sliver'):
            silverList.append(country)
        if(currPlacing == 'Gold'):
            goldList.append(country)
            
    

    # give all the iteration varaibles theie new values 
    lastyear = curryear
    lastHost = currHost 
    lastEvent = currEvent
    lastDis = currDis
    lastPlacing = currPlacing
    
# This just appends the last placing list 
# then add the last event to the currentGamesList and then this last games to the olympic list
currEventList.append(bronzeList)
currEventList.append(silverList)
currEventList.append(goldList)
currGamesList.append(currEventList)
olympicGsList.append(currGamesList)

# %% [markdown]
# ** Quick note .append places the lists at the end of the list ** <br>
# This means our list will start at the NOCS from 1960 and end with 2018

# %% [markdown]
# # Creating the relationsips
# As I said before we are now left with the list olympicGsList contains a list for every olympic games. Now in these lists are seperate lists, one for each of the events in the games.
# The structure of an event list e.g RUS, UK, USA, order bronze gold silver is like so [['USA], [UK], [CAN]'] so for an event like this is relationships would look like this 'USA,UK' and 'UK,CAN'. So we have to do this for every event for every games. Once we have create the realationships we can just have a list of relationships for each games they do not have to be seperated into events.

# %%
# This list will contain the list of relationsips for each olympic games 
relationList = []

# %% [markdown]
# # Relationship for Loop
# The second nested for loop is where the relationships are created. olympicGsList[x][y] will be an event list in one of the list of games. The third nested loop will take this list and produce all the possible relationships like in the example we talked about above. Then it will append these relationships in the currNodeList and do the same for every event in that games. After the last event is done this list of realatioships for a given games is appended onto the relationList. The process is completed untill the relationList contains a list of realatioships for every games.

# %%
# This lists is used to append each NOC to the indivdual lists in the nodeList
currNodeList = []

# This list will contain the list of relationsips for each olympic games 
relationList = [] 

for x in range(len(olympicGsList)): 

    for y in range(len(olympicGsList[x])):
            gold = olympicGsList[x][y][2]
            silver = olympicGsList[x][y][1]
            bronze = olympicGsList[x][y][0]
            
            for nocg in gold:
                
                for nocs in silver:
                    rel = nocg+","+nocs
                    currNodeList.append(rel)

            for nocs in silver:
                
                for nocb in bronze:
                    rel = nocs+","+nocb
                    currNodeList.append(rel)

    # appending all the NOCs from a single olympics to the NodeList
    relationList.append(currNodeList)
    currNodeList = []

# %%
relationList
# Out:
# [['URS,EUA',
#   'EUA,AUS',
#   'EUA,USA',
#   'USA,GBR',
#   'USA,USA',
#   'USA,USA',
#   'AUS,FRA',
#   'FRA,HUN',
#   'ITA,USA',
#   'USA,FRA',
#   'URS,AUS',
#   'AUS,GBR',
#   'POL,URS',
#   'URS,URS',
#   'USA,EUA',
#   'EUA,RSA',
#   'USA,USA',
#   'USA,USA',
#   'EUA,URS',
#   'URS,GBR',
#   'USA,EUA',
#   'EUA,BWI',
#   'NZL,EUA',
#   'EUA,POL',
#   'GBR,SWE',
#   'SWE,ITA',
#   'NZL,BEL',
#   'BEL,BWI',
#   'USA,TPE',
#   'TPE,URS',
#   'USA,USA',
#   'USA,USA',
#   'URS,HUN',
#   'HUN,POL',
#   'URS,URS',
#   'URS,USA',
#   'URS,EUA',
#   'EUA,HUN',
#   'USA,USA',
#   'USA,URS',
#   'ETH,MAR',
#   'MAR,NZL',
#   'USA,USA',
#   'USA,FIN',
#   'USA,USA',
#   'USA,USA',
#   'POL,URS',
#   'URS,URS',
#   'USA,URS',
#   'URS,BRA',
#   'ITA,RSA',
#   'RSA,TCH',
#   'RSA,EUA',
#   'HUN,URS',
#   'URS,EGY',
#   'URS,JPN',
#   'URS,ITA',
#   'ITA,POL',
#   'ITA,AUS',
#   'ITA,POL',
#   'POL,FIN',
#   'POL,RSA',
#   'POL,ITA',
#   'ITA,ARG',
#   'ITA,GBR',
#   'TCH,GHA',
#   'GHA,USA',
#   'GHA,POL',
#   'ITA,URS',
#   'URS,POL',
#   'URS,GBR',
#   'USA,ITA',
#   'ITA,GBR',
#   'ITA,URS',
#   'USA,POL',
#   'POL,URS',
#   'POL,ROU',
#   'USA,POL',
#   'POL,AUS',
#   'POL,ITA',
#   'HUN,URS',
#   'URS,ROU',
#   'URS,ITA',
#   'ITA,HUN',
#   'DEN,HUN',
#   'HUN,SWE',
#   'EUA,HUN',
#   'HUN,DEN',
#   'SWE,HUN',
#   'HUN,POL',
#   'ITA,EUA',
#   'EUA,URS',
#   'URS,ITA',
#   'ITA,BEL',
#   'ITA,EUA',
#   'EUA,URS',
#   'ITA,EUA',
#   'EUA,URS',
#   'ITA,BEL',
#   'BEL,ITA',
#   'ITA,EUA',
#   'EUA,URS',
#   'USA,USA',
#   'USA,GBR',
#   'USA,USA',
#   'USA,MEX',
#   'URS,SUI',
#   'SUI,EUA',
#   'AUS,AUS',
#   'AUS,SUI',
#   'AUS,SUI',
#   'SUI,FRA',
#   'URS,ITA',
#   'ITA,EUA',
#   'URS,URS',
#   'URS,USA',
#   'HUN,POL',
#   'POL,ITA',
#   'HUN,HUN',
#   'HUN,ITA',
#   'ITA,GBR',
#   'GBR,URS',
#   'ITA,GBR',
#   'GBR,URS',
#   'YUG,DEN',
#   'DEN,HUN',
#   'JPN,URS',
#   'URS,ITA',
#   'JPN,URS',
#   'URS,ITA',
#   'JPN,JPN',
#   'JPN,URS',
#   'URS,JPN',
#   'JPN,URS',
#   'URS,ITA',
#   'ITA,JPN',
#   'URS,URS',
#   'URS,BUL',
#   'URS,JPN',
#   'PAK,IND',
#   'IND,ESP',
#   'ITA,ITA',
#   'ITA,GBR',
#   'EUA,USA',
#   'USA,ITA',
#   'HUN,HUN',
#   'HUN,USA',
#   'HUN,URS',
#   'URS,USA',
#   'EUA,FRA',
#   'FRA,ITA',
#   'EUA,URS',
#   'URS,USA',
#   'USA,ITA',
#   'ITA,URS',
#   'URS,AUT',
#   'AUT,FIN',
#   'TCH,URS',
#   'URS,SUI',
#   'EUA,CAN',
#   'CAN,TCH',
#   'URS,EUA',
#   'EUA,POL',
#   'USA,DEN',
#   'DEN,SUI',
#   'DEN,URS',
#   'URS,BEL',
#   'URS,POR',
#   'POR,USA',
#   'GRE,ARG',
#   'ARG,ITA',
#   'NOR,DEN',
#   'DEN,EUA',
#   'USA,FIN',
#   'FIN,URS',
#   'AUT,SUI',
#   'SUI,URS',
#   'URS,URS',
#   'URS,JPN',
#   'URS,URS',
#   'URS,EUA',
#   'EUA,USA',
#   'USA,VEN',
#   'ROU,ITA',
#   'ITA,URS',
#   'AUS,USA',
#   'USA,USA',
#   'AUS,USA',
#   'USA,BRA',
#   'AUS,AUS',
#   'AUS,USA',
#   'USA,JPN',
#   'JPN,NED',
#   'USA,AUS',
#   'AUS,USA',
#   'AUS,JPN',
#   'JPN,AUS',
#   'USA,AUS',
#   'AUS,JPN',
#   'USA,JPN',
#   'JPN,AUS',
#   'ITA,URS',
#   'URS,HUN',
#   'URS,USA',
#   'USA,USA',
#   'USA,JPN',
#   'JPN,IRI',
#   'URS,USA',
#   'USA,ITA',
#   'URS,SGP',
#   'SGP,IRQ',
#   'URS,USA',
#   'USA,HUN',
#   'POL,USA',
#   'USA,POL',
#   'URS,URS',
#   'URS,GBR',
#   'EUA,TUR',
#   'TUR,URS',
#   'TUR,JPN',
#   'JPN,IRI',
#   'USA,BUL',
#   'BUL,POL',
#   'TUR,BUL',
#   'BUL,URS',
#   'USA,URS',
#   'URS,BUL',
#   'USA,TUR',
#   'TUR,PAK',
#   'TUR,URS',
#   'URS,SWE',
#   'TUR,IRI',
#   'IRI,URS',
#   'URS,EUA',
#   'EUA,TCH',
#   'ROU,EGY',
#   'EGY,IRI',
#   'URS,ROU',
#   'ROU,BUL',
#   'TUR,HUN',
#   'HUN,URS',
#   'URS,YUG',
#   'YUG,SWE',
#   'TUR,EUA',
#   'EUA,FRA',
#   'BUL,EUA',
#   'EUA,ROU',
#   'TUR,BUL',
#   'BUL,URS',
#   'USA,GBR',
#   'GBR,ITA',
#   'USA,EUA',
#   'EUA,GBR',
#   'USA,EUA',
#   'EUA,POL',
#   'URS,AUS',
#   'AUS,EUA',
#   'URS,GBR',
#   'GBR,EUA',
#   'URS,URS',
#   'URS,ROU',
#   'ROU,POL',
#   'ROU,GBR',
#   'URS,TCH',
#   'TCH,URS',
#   'URS,POL',
#   'POL,EUA',
#   'URS,EUA',
#   'EUA,USA',
#   'URS,EUA',
#   'EUA,POL',
#   'URS,EUA',
#   'EUA,HUN',
#   'EUA,USA',
#   'USA,URS',
#   'EUA,USA',
#   'USA,GBR',
#   'URS,HUN',
#   'HUN,ITA',
#   'EUA,URS',
#   'URS,ROU',
#   'URS,TCH',
#   'TCH,ROU',
#   'TCH,URS',
#   'URS,URS',
#   'URS,URS',
#   'URS,URS',
#   'URS,URS',
#   'URS,URS',
#   'URS,URS',
#   'URS,URS',
#   'URS,URS',
#   'URS,URS',
#   'USA,GBR',
#   'GBR,JPN',
#   'USA,NED',
#   'NED,AUS',
#   'AUS,USA',
#   'USA,GBR',
#   'GBR,EUA',
#   'EUA,EUA',
#   'USA,SWE',
#   'SWE,NED',
#   'USA,AUS',
#   'AUS,EUA',
#   'USA,AUS',
#   'AUS,EUA'],
#  ['EUA,USA',
#   'USA,AUT',
#   'SUI,USA',
#   'USA,ITA',
#   'CAN,USA',
#   'USA,EUA',
#   'URS,URS',
#   'URS,URS',
#   'SWE,URS',
#   'URS,FIN',
#   'USA,NED',
#   'NED,USA',
#   'CAN,EUA',
#   'EUA,USA',
#   'URS,EUA',
#   'EUA,URS',
#   'URS,POL',
#   'POL,POL',
#   'URS,URS',
#   'URS,FIN',
#   'EUA,URS',
#   'URS,USA',
#   'FRA,EUA',
#   'EUA,FRA',
#   'SUI,AUT',
#   'AUT,AUT',
#   'AUT,AUT',
#   'AUT,FRA',
#   'SWE,FIN',
#   'FIN,URS',
#   'NOR,SWE',
#   'SWE,FIN',
#   'SWE,SWE',
#   'SWE,URS',
#   'FIN,NOR',
#   'NOR,URS',
#   'FIN,FIN',
#   'FIN,SWE',
#   'USA,TCH',
#   'TCH,CAN',
#   'CAN,EUA',
#   'EUA,USA',
#   'USA,CAN',
#   'CAN,URS',
#   'EUA,NOR',
#   'NOR,URS',
#   'EUA,FIN',
#   'FIN,AUT',
#   'NOR,URS',
#   'URS,SWE',
#   'URS,NOR',
#   'NOR,NED',
#   'URS,USA',
#   'USA,URS'],
#  ['USA,TUN',
#   'TUN,AUS',
#   'USA,CUB',
#   'CUB,CAN',
#   'USA,USA',
#   'USA,URS',
#   'NZL,TCH',
#   'TCH,NZL',
#   'USA,USA',
#   'USA,TTO',
#   'GBR,EUA',
#   'EUA,URS',
#   'BEL,GBR',
#   'GBR,URS',
#   'USA,TTO',
#   'TTO,POL',
#   'USA,GBR',
#   'GBR,ITA',
#   'USA,POL',
#   'POL,FRA',
#   'USA,GBR',
#   'GBR,TTO',
#   'USA,EUA',
#   'EUA,USA',
#   'ITA,GBR',
#   'GBR,SWE',
#   'NZL,CAN',
#   'CAN,KEN',
#   'EUA,URS',
#   'URS,EUA',
#   'USA,TCH',
#   'TCH,USA',
#   'URS,HUN',
#   'HUN,EUA',
#   'URS,USA',
#   'USA,USA',
#   'FIN,HUN',
#   'HUN,URS',
#   'GBR,USA',
#   'USA,URS',
#   'ETH,GBR',
#   'GBR,JPN',
#   'USA,EUA',
#   'EUA,EUA',
#   'USA,USA',
#   'USA,HUN',
#   'POL,URS',
#   'URS,URS',
#   'USA,URS',
#   'URS,BRA',
#   'USA,EUA',
#   'EUA,ITA',
#   'EUA,URS',
#   'ITA,POL',
#   'POL,USA',
#   'POL,URS',
#   'JPN,KOR',
#   'KOR,MEX',
#   'KOR,URU',
#   'URS,PHI',
#   'PHI,USA',
#   'PHI,EUA',
#   'POL,URS',
#   'URS,USA',
#   'URS,IRL',
#   'POL,URS',
#   'URS,GHA',
#   'URS,TUN',
#   'POL,URS',
#   'URS,ITA',
#   'URS,FIN',
#   'URS,FRA',
#   'FRA,POL',
#   'FRA,NGR',
#   'URS,EUA',
#   'EUA,ITA',
#   'EUA,POL',
#   'ITA,URS',
#   'URS,BUL',
#   'URS,POL',
#   'EUA,ROU',
#   'ROU,URS',
#   'URS,FRA',
#   'FRA,DEN',
#   'SWE,HUN',
#   'HUN,ROU',
#   'SWE,NED',
#   'NED,EUA',
#   'URS,EUA',
#   'EUA,ROU',
#   'NED,ITA',
#   'ITA,SWE',
#   'ITA,DEN',
#   'DEN,BEL',
#   'BEL,ITA',
#   'ITA,FRA',
#   'ITA,URS',
#   'URS,EUA',
#   'TCH,ITA',
#   'ITA,DEN',
#   'ITA,ITA',
#   'ITA,FRA',
#   'EUA,ITA',
#   'ITA,NED',
#   'USA,ITA',
#   'ITA,USA',
#   'USA,USA',
#   'USA,USA',
#   'SUI,EUA',
#   'EUA,URS',
#   'EUA,SUI',
#   'SUI,URS',
#   'ITA,ARG',
#   'ARG,EUA',
#   'ITA,USA',
#   'USA,EUA',
#   'URS,POL',
#   'POL,FRA',
#   'POL,FRA',
#   'FRA,FRA',
#   'URS,ITA',
#   'ITA,POL',
#   'HUN,FRA',
#   'FRA,URS',
#   'HUN,ITA',
#   'ITA,FRA',
#   'URS,GBR',
#   'GBR,URS',
#   'HUN,TCH',
#   'TCH,EUA',
#   'JPN,URS',
#   'URS,EUA',
#   'ITA,JPN',
#   'ITA,URS',
#   'URS,URS',
#   'URS,YUG',
#   'JPN,URS',
#   'JPN,JPN',
#   'JPN,JPN',
#   'JPN,ITA',
#   'YUG,JPN',
#   'JPN,URS',
#   'JPN,ITA',
#   'ITA,URS',
#   'JPN,URS',
#   'URS,FIN',
#   'IND,PAK',
#   'PAK,AUS',
#   'JPN,CAN',
#   'CAN,URS',
#   'JPN,SUI',
#   'SUI,URS',
#   'JPN,EUA',
#   'EUA,USA',
#   'EUA,KOR',
#   'NED,JPN',
#   'JPN,AUS',
#   'JPN,EUA',
#   'FRA,EUA',
#   'EUA,GBR',
#   'EUA,FRA',
#   'FRA,ITA',
#   'HUN,URS',
#   'URS,URS',
#   'URS,USA',
#   'USA,HUN',
#   'EUA,ITA',
#   'ITA,NED',
#   'USA,FRA',
#   'FRA,NED',
#   'DEN,GBR',
#   'GBR,USA',
#   'CAN,NED',
#   'NED,EUA',
#   'URS,USA',
#   'USA,TCH',
#   'USA,EUA',
#   'EUA,TCH',
#   'URS,EUA',
#   'EUA,SUI',
#   'AUS,SWE',
#   'SWE,USA',
#   'EUA,USA',
#   'USA,DEN',
#   'BAH,USA',
#   'USA,SWE',
#   'DEN,EUA',
#   'EUA,USA',
#   'NZL,GBR',
#   'GBR,USA',
#   'FIN,ROU',
#   'ROU,TCH',
#   'USA,URS',
#   'URS,USA',
#   'FIN,USA',
#   'USA,JPN',
#   'USA,BUL',
#   'BUL,HUN',
#   'HUN,USA',
#   'USA,USA',
#   'ITA,URS',
#   'URS,USA',
#   'USA,GBR',
#   'GBR,EUA',
#   'AUS,USA',
#   'USA,AUS',
#   'USA,USA',
#   'USA,USA',
#   'AUS,URS',
#   'URS,USA',
#   'AUS,USA',
#   'USA,USA',
#   'USA,EUA',
#   'EUA,AUS',
#   'USA,USA',
#   'USA,EUA',
#   'USA,EUA',
#   'EUA,AUS',
#   'USA,EUA',
#   'EUA,AUS',
#   'USA,EUA',
#   'EUA,JPN',
#   'URS,TCH',
#   'TCH,JPN',
#   'HUN,YUG',
#   'YUG,URS',
#   'URS,URS',
#   'URS,USA',
#   'URS,HUN',
#   'HUN,JPN',
#   'JPN,USA',
#   'USA,POL',
#   'POL,URS',
#   'URS,POL',
#   'TCH,URS',
#   'URS,JPN',
#   'URS,HUN',
#   'HUN,HUN',
#   'URS,GBR',
#   'GBR,POL',
#   'URS,BUL',
#   'BUL,TUR',
#   'JPN,KOR',
#   'KOR,IRI',
#   'JPN,TUR',
#   'TUR,URS',
#   'JPN,BUL',
#   'BUL,URS',
#   'BUL,EUA',
#   'EUA,JPN',
#   'TUR,URS',
#   'URS,IRI',
#   'BUL,TUR',
#   'TUR,USA',
#   'URS,TUR',
#   'TUR,BUL',
#   'JPN,BUL',
#   'BUL,ROU',
#   'JPN,URS',
#   'URS,ROU',
#   'HUN,URS',
#   'URS,YUG',
#   'TUR,ROU',
#   'ROU,URS',
#   'URS,BUL',
#   'BUL,SWE',
#   'YUG,TCH',
#   'TCH,EUA',
#   'BUL,SWE',
#   'SWE,EUA',
#   'HUN,URS',
#   'URS,EUA',
#   'USA,USA',
#   'USA,POL',
#   'USA,POL',
#   'POL,AUS',
#   'AUS,GBR',
#   'GBR,AUS',
#   'POL,USA',
#   'USA,GBR',
#   'GBR,FRA',
#   'FRA,NZL',
#   'EUA,POL',
#   'POL,AUS',
#   'URS,EUA',
#   'EUA,ROU',
#   'ROU,AUS',
#   'AUS,URS',
#   'ROU,HUN',
#   'HUN,URS',
#   'GBR,POL',
#   'POL,URS',
#   'URS,GBR',
#   'GBR,URS',
#   'URS,EUA',
#   'EUA,URS',
#   'URS,ROU',
#   'ROU,USA',
#   'EUA,USA',
#   'USA,ROU',
#   'USA,EUA',
#   'EUA,URS',
#   'EUA,USA',
#   'USA,USA',
#   'HUN,URS',
#   'URS,EUA',
#   'HUN,EUA',
#   'EUA,ITA',
#   'URS,TCH',
#   'TCH,JPN',
#   'TCH,URS',
#   'URS,URS',
#   'URS,URS',
#   'URS,HUN',
#   'TCH,URS',
#   'URS,URS',
#   'URS,HUN',
#   'HUN,URS',
#   'TCH,URS',
#   'TCH,EUA',
#   'USA,FRA',
#   'FRA,USA',
#   'USA,NED',
#   'NED,USA',
#   'AUS,USA',
#   'USA,USA',
#   'URS,USA',
#   'USA,URS',
#   'USA,USA',
#   'USA,USA',
#   'USA,USA',
#   'USA,USA',
#   'USA,AUS',
#   'AUS,NED',
#   'USA,NED',
#   'NED,URS',
#   'JPN,URS',
#   'URS,POL'],
#  ['AUT,AUT',
#   'AUT,AUT',
#   'FRA,FRA',
#   'FRA,USA',
#   'FRA,FRA',
#   'FRA,USA',
#   'URS,URS',
#   'URS,URS',
#   'URS,SWE',
#   'SWE,FIN',
#   'URS,FIN',
#   'FIN,URS',
#   'NED,AUT',
#   'AUT,CAN',
#   'URS,CAN',
#   'URS,EUA',
#   'CAN,USA',
#   'EUA,USA',
#   'EUA,EUA',
#   'EUA,AUT',
#   'URS,URS',
#   'URS,FIN',
#   'URS,FIN',
#   'FIN,URS',
#   'URS,PRK',
#   'URS,URS',
#   'URS,URS',
#   'URS,URS',
#   'AUT,FRA',
#   'FRA,EUA',
#   'FRA,AUT',
#   'AUT,AUT',
#   'AUT,USA',
#   'USA,USA',
#   'URS,URS',
#   'URS,NOR',
#   'CAN,AUT',
#   'AUT,ITA',
#   'GBR,ITA',
#   'ITA,ITA',
#   'FIN,NOR',
#   'NOR,SWE',
#   'FIN,NOR',
#   'NOR,URS',
#   'SWE,FIN',
#   'FIN,URS',
#   'SWE,SWE',
#   'SWE,FIN',
#   'EUA,FRA',
#   'FRA,USA',
#   'URS,CAN',
#   'URS,EUA',
#   'CAN,USA',
#   'EUA,USA',
#   'URS,SWE',
#   'SWE,TCH',
#   'AUT,AUT',
#   'AUT,ITA',
#   'EUA,EUA',
#   'EUA,EUA',
#   'NOR,URS',
#   'URS,EUA',
#   'NOR,FIN',
#   'FIN,NOR',
#   'FIN,NOR',
#   'NOR,NOR',
#   'SWE,NOR',
#   'NOR,NOR',
#   'URS,NED',
#   'NED,NOR',
#   'NOR,NOR',
#   'NOR,NOR',
#   'USA,NOR',
#   'USA,URS'],
#  ['KEN,ETH',
#   'ETH,TUN',
#   'USA,JAM',
#   'JAM,USA',
#   'USA,USA',
#   'USA,ITA',
#   'KEN,USA',
#   'USA,FRG',
#   'USA,AUS',
#   'AUS,USA',
#   'URS,MEX',
#   'MEX,URS',
#   'KEN,KEN',
#   'KEN,USA',
#   'USA,USA',
#   'USA,USA',
#   'GBR,FRG',
#   'FRG,GBR',
#   'USA,CUB',
#   'CUB,FRA',
#   'USA,KEN',
#   'KEN,FRG',
#   'TUN,KEN',
#   'KEN,KEN',
#   'GDR,HUN',
#   'HUN,USA',
#   'AUS,KEN',
#   'KEN,USA',
#   'USA,FRG',
#   'FRG,FRG',
#   'USA,GDR',
#   'GDR,TCH',
#   'HUN,URS',
#   'URS,HUN',
#   'USA,USA',
#   'USA,URS',
#   'URS,FIN',
#   'FIN,HUN',
#   'USA,GDR',
#   'GDR,USA',
#   'ETH,JPN',
#   'JPN,NZL',
#   'USA,FRG',
#   'FRG,GDR',
#   'USA,USA',
#   'USA,URS',
#   'URS,BRA',
#   'BRA,ITA',
#   'USA,YUG',
#   'YUG,URS',
#   'USA,URS',
#   'URS,ITA',
#   'URS,MEX',
#   'VEN,KOR',
#   'KOR,USA',
#   'KOR,POL',
#   'MEX,POL',
#   'POL,BRA',
#   'POL,UGA',
#   'URS,UGA',
#   'UGA,KOR',
#   'UGA,JPN',
#   'MEX,USA',
#   'USA,BUL',
#   'USA,KEN',
#   'USA,POL',
#   'POL,ROU',
#   'POL,YUG',
#   'POL,CUB',
#   'CUB,FIN',
#   'CUB,USA',
#   'GDR,CMR',
#   'CMR,ARG',
#   'CMR,URS',
#   'URS,CUB',
#   'CUB,USA',
#   'CUB,FRG',
#   'GBR,URS',
#   'URS,USA',
#   'URS,MEX',
#   'URS,ROU',
#   'ROU,POL',
#   'ROU,BUL',
#   'HUN,FRG',
#   'FRG,URS',
#   'ROU,HUN',
#   'HUN,URS',
#   'HUN,URS',
#   'URS,DEN',
#   'URS,HUN',
#   'HUN,AUT',
#   'NOR,ROU',
#   'ROU,HUN',
#   'NED,SWE',
#   'SWE,ITA',
#   'ITA,DEN',
#   'DEN,SWE',
#   'FRA,DEN',
#   'DEN,POL',
#   'FRA,NED',
#   'NED,BEL',
#   'FRA,DEN',
#   'DEN,SUI',
#   'FRA,ITA',
#   'ITA,FRA',
#   'DEN,FRG',
#   'FRG,ITA',
#   'ITA,MEX',
#   'MEX,USA',
#   'USA,ITA',
#   'ITA,USA',
#   'URS,FRG',
#   'FRG,FRG',
#   'FRG,URS',
#   'URS,SUI',
#   'FRA,GBR',
#   'GBR,USA',
#   'GBR,USA',
#   'USA,AUS',
#   'FRA,URS',
#   'URS,POL',
#   'ROU,HUN',
#   'HUN,FRA',
#   'URS,ITA',
#   'ITA,HUN',
#   'POL,URS',
#   'URS,HUN',
#   'HUN,URS',
#   'URS,POL',
#   'HUN,URS',
#   'URS,ITA',
#   'HUN,BUL',
#   'BUL,JPN',
#   'JPN,URS',
#   'URS,GDR',
#   'JPN,JPN',
#   'JPN,JPN',
#   'JPN,URS',
#   'URS,JPN',
#   'JPN,URS',
#   'URS,URS',
#   'YUG,FIN',
#   'FIN,URS',
#   'JPN,URS',
#   'URS,JPN',
#   'URS,JPN',
#   'JPN,URS',
#   'PAK,AUS',
#   'AUS,IND',
#   'CAN,FRA',
#   'FRA,FRG',
#   'SWE,HUN',
#   'HUN,URS',
#   'HUN,URS',
#   'URS,FRA',
#   'NZL,GDR',
#   'GDR,SUI',
#   'ITA,NED',
#   'NED,DEN',
#   'GDR,HUN',
#   'HUN,ITA',
#   'GDR,USA',
#   'USA,DEN',
#   'URS,NED',
#   'NED,USA',
#   'FRG,AUS',
#   'AUS,URS',
#   'NED,FRG',
#   'FRG,ARG',
#   'SWE,SUI',
#   'SUI,GBR',
#   'URS,AUT',
#   'AUT,ITA',
#   'USA,NOR',
#   'NOR,ITA',
#   'USA,DEN',
#   'DEN,GDR',
#   'GBR,FRG',
#   'FRG,BRA',
#   'POL,ROU',
#   'ROU,URS',
#   'USA,URS',
#   'URS,SUI',
#   'URS,FRG',
#   'FRG,GDR',
#   'FRG,USA',
#   'USA,URS',
#   'TCH,HUN',
#   'HUN,NZL',
#   'URS,ITA',
#   'ITA,FRG',
#   'GBR,USA',
#   'USA,GDR',
#   'GDR,USA',
#   'USA,USA',
#   'USA,URS',
#   'URS,URS',
#   'USA,USA',
#   'USA,USA',
#   'AUS,USA',
#   'USA,USA',
#   'USA,USA',
#   'USA,AUS',
#   'GDR,USA',
#   'USA,USA',
#   'MEX,URS',
#   'URS,USA',
#   'USA,GBR',
#   'GBR,USA',
#   'AUS,USA',
#   'USA,USA',
#   'USA,USA',
#   'USA,USA',
#   'USA,CAN',
#   'CAN,FRA',
#   'USA,USA',
#   'USA,FRG',
#   'USA,URS',
#   'URS,AUS',
#   'USA,GDR',
#   'GDR,URS',
#   'USA,AUS',
#   'AUS,URS',
#   'URS,JPN',
#   'JPN,TCH',
#   'YUG,URS',
#   'URS,HUN',
#   'URS,BEL',
#   'BEL,USA',
#   'IRI,HUN',
#   'HUN,POL',
#   'JPN,URS',
#   'URS,JPN',
#   'POL,IRI',
#   'IRI,POL',
#   'URS,JPN',
#   'JPN,HUN',
#   'URS,URS',
#   'URS,POL',
#   'FIN,URS',
#   'URS,POL',
#   'URS,BUL',
#   'BUL,FRG',
#   'JPN,USA',
#   'USA,MGL',
#   'JPN,USA',
#   'USA,IRI',
#   'JPN,BUL',
#   'BUL,IRI',
#   'IRI,BUL',
#   'BUL,MGL',
#   'TUR,FRA',
#   'FRA,MGL',
#   'URS,MGL',
#   'MGL,BUL',
#   'TUR,URS',
#   'URS,HUN',
#   'BUL,URS',
#   'URS,TCH',
#   'HUN,ROU',
#   'ROU,URS',
#   'URS,JPN',
#   'JPN,ROU',
#   'JPN,YUG',
#   'YUG,GRE',
#   'GDR,FRA',
#   'FRA,HUN',
#   'GDR,URS',
#   'URS,YUG',
#   'BUL,URS',
#   'URS,ROU',
#   'HUN,URS',
#   'URS,TCH',
#   'USA,USA',
#   'USA,POL',
#   'POL,AUS',
#   'AUS,AUS',
#   'FRA,GBR',
#   'GBR,URS',
#   'USA,CUB',
#   'CUB,URS',
#   'USA,ROU',
#   'ROU,NED',
#   'AUS,AUS',
#   'AUS,TPE',
#   'ROU,FRG',
#   'FRG,HUN',
#   'TCH,URS',
#   'URS,URS',
#   'HUN,ROU',
#   'ROU,AUT',
#   'ROU,GBR',
#   'GBR,URS',
#   'FRG,AUT',
#   'AUT,HUN',
#   'GDR,GDR',
#   'GDR,URS',
#   'URS,FRG',
#   'FRG,ROU',
#   'FRG,HUN',
#   'HUN,URS',
#   'TCH,URS',
#   'URS,USA',
#   'USA,URS',
#   'URS,USA',
#   'FRG,URS',
#   'URS,SUI',
#   'URS,HUN',
#   'HUN,ROU',
#   'URS,MEX',
#   'MEX,HUN',
#   'URS,TCH',
#   'TCH,GDR',
#   'URS,TCH',
#   'TCH,URS',
#   'TCH,URS',
#   'URS,URS',
#   'TCH,GDR',
#   'GDR,URS',
#   'TCH,GDR',
#   'GDR,URS',
#   'USA,CAN',
#   'CAN,USA',
#   'YUG,URS',
#   'URS,USA',
#   'AUS,USA',
#   'USA,USA',
#   'USA,USA',
#   'USA,USA',
#   'USA,CAN',
#   'CAN,USA',
#   'USA,YUG',
#   'YUG,URS',
#   'NED,GDR',
#   'GDR,USA',
#   'USA,USA',
#   'USA,USA',
#   'USA,USA',
#   'USA,USA',
#   'USA,USA',
#   'USA,AUS',
#   'USA,USA',
#   'USA,GDR',
#   'USA,GDR',
#   'GDR,CAN',
#   'USA,AUS',
#   'AUS,FRG',
#   'USA,USA',
#   'USA,MEX',
#   'URS,JPN',
#   'JPN,POL'],
#  ['AUT,FRA',
#   'FRA,AUT',
#   'CAN,FRA',
#   'FRA,SUI',
#   'FRA,CAN',
#   'CAN,FRA',
#   'SWE,NOR',
#   'NOR,NOR',
#   'NOR,SWE',
#   'SWE,URS',
#   'SWE,URS',
#   'URS,URS',
#   'USA,GDR',
#   'GDR,TCH',
#   'URS,URS',
#   'URS,FRG',
#   'ITA,FRG',
#   'FRG,FRG',
#   'NED,URS',
#   'URS,USA',
#   'FIN,NED',
#   'NED,NED',
#   'NED,FIN',
#   'FIN,NED',
#   'URS,USA',
#   'FRA,FRA',
#   'FRA,SUI',
#   'FRA,SUI',
#   'SUI,AUT',
#   'FRA,AUT',
#   'AUT,AUT',
#   'NOR,URS',
#   'URS,URS',
#   'URS,NOR',
#   'NOR,SWE',
#   'ITA,AUT',
#   'AUT,SUI',
#   'ITA,FRG',
#   'FRG,ROU',
#   'NOR,FIN',
#   'FIN,SWE',
#   'ITA,NOR',
#   'NOR,FIN',
#   'NOR,SWE',
#   'SWE,FIN',
#   'NOR,URS',
#   'URS,SUI',
#   'AUT,USA',
#   'USA,FRA',
#   'URS,URS',
#   'URS,FRG',
#   'URS,TCH',
#   'TCH,CAN',
#   'GDR,AUT',
#   'AUT,FRG',
#   'AUT,GDR',
#   'GDR,GDR',
#   'FRG,SUI',
#   'SUI,GDR',
#   'URS,TCH',
#   'TCH,NOR',
#   'TCH,AUT',
#   'AUT,AUT',
#   'SWE,NOR',
#   'NOR,SWE',
#   'NED,NED',
#   'NED,NOR',
#   'NOR,NED',
#   'NED,NED',
#   'FRG,NOR',
#   'FRG,USA'],
#  ['USA,SWE',
#   'SWE,FIN',
#   'FIN,BEL',
#   'BEL,ETH',
#   'URS,USA',
#   'USA,JAM',
#   'USA,FRA',
#   'FRA,USA',
#   'FIN,KEN',
#   'KEN,NZL',
#   'URS,USA',
#   'USA,ITA',
#   'GDR,URS',
#   'URS,GDR',
#   'KEN,KEN',
#   'KEN,FIN',
#   'USA,USA',
#   'USA,KEN',
#   'UGA,USA',
#   'USA,GBR',
#   'USA,URS',
#   'URS,FRG',
#   'KEN,GBR',
#   'GBR,FRA',
#   'FIN,TUN',
#   'TUN,GBR',
#   'FRG,URS',
#   'URS,USA',
#   'USA,URS',
#   'URS,KEN',
#   'URS,URS',
#   'URS,POL',
#   'TCH,USA',
#   'USA,SWE',
#   'URS,GDR',
#   'GDR,URS',
#   'URS,GDR',
#   'GDR,USA',
#   'FRG,URS',
#   'URS,USA',
#   'USA,FRG',
#   'FRG,USA',
#   'USA,BEL',
#   'BEL,ETH',
#   'GDR,USA',
#   'USA,USA',
#   'POL,USA',
#   'USA,GDR',
#   'URS,GDR',
#   'GDR,BRA',
#   'URS,USA',
#   'USA,CUB',
#   'CUB,ROU',
#   'ROU,FRG',
#   'ROU,SWE',
#   'HUN,PRK',
#   'PRK,GBR',
#   'PRK,ESP',
#   'BUL,UGA',
#   'UGA,POL',
#   'UGA,CUB',
#   'CUB,MEX',
#   'MEX,USA',
#   'MEX,GBR',
#   'URS,KEN',
#   'KEN,HUN',
#   'KEN,COL',
#   'POL,HUN',
#   'HUN,KEN',
#   'HUN,COL',
#   'USA,BUL',
#   'BUL,NIG',
#   'BUL,YUG',
#   'CUB,HUN',
#   'HUN,KEN',
#   'HUN,USA',
#   'FRG,POL',
#   'POL,GBR',
#   'POL,GDR',
#   'URS,FIN',
#   'FIN,GHA',
#   'FIN,USA',
#   'YUG,CUB',
#   'CUB,POL',
#   'CUB,NGR',
#   'GDR,FRG',
#   'FRG,USA',
#   'GDR,FRG',
#   'FRG,FRA',
#   'GDR,AUT',
#   'AUT,GDR',
#   'ROU,HUN',
#   'HUN,FRG',
#   'URS,ROU',
#   'ROU,BUL',
#   'URS,SWE',
#   'SWE,HUN',
#   'URS,HUN',
#   'HUN,POL',
#   'URS,ROU',
#   'ROU,NOR',
#   'URS,POL',
#   'NED,AUS',
#   'DEN,AUS',
#   'AUS,GDR',
#   'URS,GDR',
#   'GDR,POL',
#   'NOR,SUI',
#   'SUI,FRG',
#   'FRA,AUS',
#   'AUS,URS',
#   'FRG,GDR',
#   'GDR,GBR',
#   'ITA,USA',
#   'USA,ITA',
#   'URS,ITA',
#   'ITA,USA',
#   'URS,FRG',
#   'GBR,ITA',
#   'ITA,SWE',
#   'GBR,USA',
#   'USA,FRG',
#   'POL,URS',
#   'URS,FRA',
#   'POL,HUN',
#   'HUN,FRA',
#   'ITA,URS',
#   'URS,HUN',
#   'URS,HUN',
#   'HUN,URS',
#   'HUN,SUI',
#   'SUI,URS',
#   'HUN,FRA',
#   'FRA,HUN',
#   'POL,HUN',
#   'HUN,URS',
#   'HUN,GDR',
#   'JPN,URS',
#   'URS,GDR',
#   'URS,JPN',
#   'JPN,JPN',
#   'JPN,JPN',
#   'JPN,JPN',
#   'JPN,JPN',
#   'JPN,JPN',
#   'JPN,JPN',
#   'JPN,JPN',
#   'URS,JPN',
#   'JPN,JPN',
#   'JPN,URS',
#   'URS,JPN',
#   'GDR,URS',
#   'URS,URS',
#   'YUG,TCH',
#   'TCH,ROU',
#   'FRG,PAK',
#   'PAK,IND',
#   'NED,FRG',
#   'FRG,JPN',
#   'FRG,URS',
#   'JPN,POL',
#   'POL,GDR',
#   'POL,URS',
#   'JPN,KOR',
#   'KOR,FRA',
#   'KOR,GBR',
#   'URS,GBR',
#   'GBR,FRG',
#   'GBR,BRA',
#   'NED,URS',
#   'URS,FRA',
#   'URS,GBR',
#   'FRG,USA',
#   'USA,ITA',
#   'HUN,URS',
#   'URS,URS',
#   'URS,HUN',
#   'HUN,FIN',
#   'FRG,GDR',
#   'GDR,TCH',
#   'GDR,TCH',
#   'TCH,ROU',
#   'GDR,NZL',
#   'NZL,FRG',
#   'GDR,SUI',
#   'SUI,NED',
#   'URS,NOR',
#   'NOR,GDR',
#   'NZL,USA',
#   'USA,GDR',
#   'URS,ARG',
#   'ARG,GDR',
#   'FRA,GRE',
#   'GRE,URS',
#   'USA,SWE',
#   'SWE,CAN',
#   'AUS,SWE',
#   'SWE,FRG',
#   'AUS,GDR',
#   'GDR,USA',
#   'GBR,FRA',
#   'FRA,FRG',
#   'URS,GBR',
#   'GBR,USA',
#   'POL,TCH',
#   'TCH,URS',
#   'USA,URS',
#   'URS,HUN',
#   'SWE,ROU',
#   'ROU,AUT',
#   'USA,USA',
#   'USA,GDR',
#   'PRK,USA',
#   'USA,ROU',
#   'URS,COL',
#   'COL,GBR',
#   'FRG,URS',
#   'URS,GDR',
#   'ITA,FRA',
#   'FRA,ITA',
#   'GDR,USA',
#   'USA,USA',
#   'JPN,USA',
#   'USA,USA',
#   'USA,CAN',
#   'CAN,USA',
#   'USA,USA',
#   'USA,URS',
#   'USA,AUS',
#   'AUS,USA',
#   'GDR,USA',
#   'USA,USA',
#   'USA,GBR',
#   'GBR,JPN',
#   'USA,USA',
#   'USA,USA',
#   'USA,USA',
#   'USA,FRG',
#   'SWE,USA',
#   'USA,USA',
#   'AUS,USA',
#   'USA,USA',
#   'SWE,USA',
#   'USA,HUN',
#   'USA,URS',
#   'URS,GDR',
#   'USA,GDR',
#   'GDR,CAN',
#   'USA,FRG',
#   'FRG,URS',
#   'JPN,GDR',
#   'GDR,URS',
#   'URS,HUN',
#   'HUN,USA',
#   'URS,FRG',
#   'FRG,GDR',
#   'POL,HUN',
#   'HUN,HUN',
#   'HUN,IRI',
#   'IRI,URS',
#   'BUL,URS',
#   'URS,HUN',
#   'URS,BUL',
#   'BUL,POL',
#   'BUL,LBN',
#   'LBN,ITA',
#   'NOR,POL',
#   'POL,HUN',
#   'BUL,BUL',
#   'BUL,SWE',
#   'URS,BUL',
#   'BUL,GDR',
#   'URS,BUL',
#   'BUL,USA',
#   'URS,BUL',
#   'BUL,IRI',
#   'JPN,URS',
#   'URS,PRK',
#   'JPN,USA',
#   'USA,HUN',
#   'URS,TUR',
#   'TUR,BUL',
#   'USA,JPN',
#   'JPN,URS',
#   'USA,SWE',
#   'SWE,FRG',
#   'URS,USA',
#   'USA,ROU',
#   'USA,URS',
#   'URS,HUN',
#   'URS,MGL',
#   'MGL,HUN',
#   'URS,BUL',
#   'BUL,ROU',
#   'ROU,IRI',
#   'IRI,BUL',
#   'BUL,JPN',
#   'JPN,ITA',
#   'URS,FRG',
#   'FRG,FIN',
#   'BUL,GDR',
#   'GDR,POL',
#   'URS,BUL',
#   'BUL,ITA',
#   'TCH,GRE',
#   'GRE,SWE',
#   'HUN,URS',
#   'URS,YUG',
#   'URS,YUG',
#   'YUG,POL',
#   'ROU,URS',
#   'URS,HUN',
#   'USA,POL',
#   'POL,URS',
#   'GDR,AUS',
#   'AUS,CUB',
#   'GDR,ROU',
#   'ROU,GDR',
#   'URS,GDR',
#   'GDR,ITA',
#   'GDR,AUS',
#   'AUS,POL',
#   'GDR,FRG',
#   'FRG,USA',
#   'FRG,GDR',
#   'GDR,CUB',
#   'GDR,USA',
#   'USA,FRG',
#   'FRG,URS',
#   'URS,GDR',
#   'URS,ROU',
#   'ROU,BUL',
#   'FRG,BUL',
#   'BUL,AUT',
#   'GDR,GDR',
#   'GDR,USA',
#   'FRG,BUL',
#   'BUL,TCH',
#   'GBR,FRG',
#   'FRG,GDR',
#   'URS,GDR',
#   'GDR,BUL',
#   'GDR,FRG',
#   'FRG,FRG',
#   'URS,NED',
#   'NED,HUN',
#   'URS,GDR',
#   'GDR,ROU',
#   'SWE,TCH',
#   'TCH,GDR',
#   'USA,SWE',
#   'SWE,GDR',
#   'FRG,URS',
#   'URS,FRG',
#   'FRG,SWE',
#   'URS,HUN',
#   'HUN,ROU',
#   'ITA,HUN',
#   'HUN,URS',
#   'URS,GDR',
#   'GDR,HUN',
#   'URS,URS',
#   'URS,GDR',
#   'URS,URS',
#   'URS,URS',
#   'URS,GDR',
#   'GDR,URS',
#   'GDR,URS',
#   'GDR,GDR',
#   'GDR,GDR',
#   'GDR,URS',
#   'USA,HUN',
#   'HUN,USA',
#   'USA,URS',
#   'URS,AUS',
#   'JPN,GDR',
#   'GDR,HUN',
#   'USA,USA',
#   'USA,AUS',
#   'USA,USA',
#   'USA,CAN',
#   'AUS,USA',
#   'USA,URS',
#   'USA,USA',
#   'USA,USA',
#   'AUS,USA',
#   'USA,USA',
#   'AUS,GDR',
#   'GDR,USA',
#   'AUS,ITA',
#   'ITA,GDR',
#   'AUS,CAN',
#   'CAN,ITA',
#   'USA,GDR',
#   'GDR,FRG',
#   'USA,GDR',
#   'GDR,FRG',
#   'USA,AUS',
#   'AUS,ITA',
#   'URS,JPN',
#   'JPN,PRK'],
#  ['SUI,AUT',
#   'AUT,USA',
#   'SUI,AUT',
#   'AUT,AUT',
#   'USA,FRA',
#   'FRA,FRA',
#   'URS,URS',
#   'URS,FIN',
#   'URS,FIN',
#   'FIN,NOR',
#   'URS,FIN',
#   'FIN,TCH',
#   'AUT,CAN',
#   'CAN,USA',
#   'URS,URS',
#   'URS,GDR',
#   'GDR,GDR',
#   'GDR,GDR',
#   'FRG,NED',
#   'NED,USA',
#   'USA,NED',
#   'NED,NED',
#   'NED,USA',
#   'USA,NED',
#   'USA,URS',
#   'URS,URS',
#   'SUI,SUI',
#   'SUI,AUT',
#   'ITA,SUI',
#   'SUI,SUI',
#   'ESP,ITA',
#   'ITA,ITA',
#   'NOR,GDR',
#   'GDR,SWE',
#   'URS,FIN',
#   'FIN,GDR',
#   'SUI,ITA',
#   'ITA,FRG',
#   'FRG,FRG',
#   'FRG,SUI',
#   'SWE,URS',
#   'URS,NOR',
#   'URS,NOR',
#   'NOR,NOR',
#   'URS,NOR',
#   'NOR,SUI',
#   'NOR,NOR',
#   'NOR,URS',
#   'TCH,URS',
#   'URS,FRA',
#   'URS,URS',
#   'URS,GDR',
#   'URS,USA',
#   'USA,TCH',
#   'GDR,GDR',
#   'GDR,GDR',
#   'GDR,FIN',
#   'FIN,GDR',
#   'POL,SUI',
#   'SUI,GDR',
#   'JPN,JPN',
#   'JPN,JPN',
#   'NED,NED',
#   'NED,NOR',
#   'NED,NOR',
#   'NOR,SWE',
#   'NED,NOR',
#   'NOR,NOR',
#   'FRG,SWE',
#   'SWE,URS'],
#  ['USA,JPN',
#   'JPN,ITA',
#   'FIN,POR',
#   'POR,GBR',
#   'TTO,JAM',
#   'JAM,URS',
#   'FRA,CUB',
#   'CUB,USA',
#   'NZL,BEL',
#   'BEL,FRG',
#   'JAM,USA',
#   'USA,USA',
#   'MEX,GDR',
#   'GDR,GDR',
#   'SWE,POL',
#   'POL,GDR',
#   'CUB,USA',
#   'USA,USA',
#   'USA,USA',
#   'USA,URS',
#   'USA,GDR',
#   'GDR,URS',
#   'USA,POL',
#   'POL,FRG',
#   'FIN,NZL',
#   'NZL,FRG',
#   'CUB,BEL',
#   'BEL,USA',
#   'USA,FRG',
#   'FRG,URS',
#   'USA,GDR',
#   'GDR,USA',
#   'URS,URS',
#   'URS,URS',
#   'POL,CAN',
#   'CAN,USA',
#   'HUN,FIN',
#   'FIN,ROU',
#   'USA,USA',
#   'USA,GDR',
#   'GDR,USA',
#   'USA,BEL',
#   'POL,FIN',
#   'FIN,USA',
#   'GDR,URS',
#   'URS,URS',
#   'URS,USA',
#   'USA,BRA',
#   'USA,YUG',
#   'YUG,URS',
#   'CUB,ROU',
#   'ROU,BER',
#   'ROU,USA',
#   'CUB,PRK',
#   'PRK,PUR',
#   'PRK,THA',
#   'USA,CUB',
#   'CUB,POL',
#   'CUB,URS',
#   'PRK,USA',
#   'USA,GBR',
#   'USA,URS',
#   'CUB,GDR',
#   'GDR,POL',
#   'GDR,MEX',
#   'USA,ROU',
#   'ROU,YUG',
#   'ROU,URS',
#   'USA,CUB',
#   'CUB,BUL',
#   'CUB,POL',
#   'GDR,VEN',
#   'VEN,FRG',
#   'VEN,ROU',
#   'POL,YUG',
#   'YUG,CUB',
#   'YUG,URS',
#   'USA,URS',
#   'URS,CUB',
#   'URS,ROU',
#   'USA,CUB',
#   'CUB,ROU',
#   'CUB,POL',
#   'YUG,URS',
#   'URS,HUN',
#   'URS,CAN',
#   'CAN,YUG',
#   'URS,ROU',
#   'ROU,HUN',
#   'URS,POL',
#   'POL,HUN',
#   'GDR,HUN',
#   'HUN,ROU',
#   'ROU,HUN',
#   'HUN,GDR',
#   'URS,GDR',
#   'GDR,HUN',
#   'GDR,URS',
#   'URS,ROU',
#   'URS,ESP',
#   'ESP,GDR',
#   'URS,POL',
#   'POL,DEN',
#   'SWE,ITA',
#   'ITA,POL',
#   'GDR,BEL',
#   'BEL,DEN',
#   'FRG,NED',
#   'NED,GDR',
#   'TCH,FRA',
#   'FRA,GDR',
#   'FRG,URS',
#   'URS,GBR',
#   'ITA,USA',
#   'USA,URS',
#   'USA,ITA',
#   'ITA,URS',
#   'FRG,FRG',
#   'FRG,SUI',
#   'USA,USA',
#   'USA,FRG',
#   'USA,FRG',
#   'FRG,AUS',
#   'FRG,ITA',
#   'ITA,FRA',
#   'ITA,URS',
#   'URS,FRA',
#   'URS,ITA',
#   'ITA,ROU',
#   'URS,URS',
#   'URS,URS',
#   'SWE,FRG',
#   'FRG,SUI',
#   'FRG,FRG',
#   'FRG,HUN',
#   'GDR,POL',
#   'POL,URS',
#   'JPN,URS',
#   'URS,GDR',
#   'URS,URS',
#   'URS,USA',
#   'JPN,JPN',
#   'JPN,FRA',
#   'JPN,FRG',
#   'URS,JPN',
#   'JPN,JPN',
#   'JPN,URS',
#   'URS,JPN',
#   'HUN,JPN',
#   'JPN,URS',
#   'JPN,GDR',
#   'URS,URS',
#   'URS,ROU',
#   'URS,JPN',
#   'JPN,JPN',
#   'URS,ROU',
#   'ROU,POL',
#   'NZL,AUS',
#   'AUS,PAK',
#   'URS,FRG',
#   'FRG,USA',
#   'FRG,JPN',
#   'CUB,KOR',
#   'KOR,ITA',
#   'KOR,HUN',
#   'URS,JPN',
#   'JPN,POL',
#   'JPN,FRA',
#   'JPN,URS',
#   'URS,YUG',
#   'URS,KOR',
#   'JPN,URS',
#   'URS,SUI',
#   'URS,GBR',
#   'JPN,GBR',
#   'GBR,KOR',
#   'GBR,URS',
#   'FRG,CAN',
#   'CAN,BEL',
#   'FRA,FRG',
#   'FRG,BEL',
#   'POL,URS',
#   'URS,TCH',
#   'GBR,TCH',
#   'TCH,HUN',
#   'URS,GDR',
#   'GDR,FRG',
#   'GDR,URS',
#   'URS,TCH',
#   'GDR,NOR',
#   'NOR,URS',
#   'GDR,USA',
#   'USA,FRG',
#   'NOR,GBR',
#   'GBR,GDR',
#   'GDR,GBR',
#   'GBR,NZL',
#   'GDR,URS',
#   'URS,TCH',
#   'FIN,FRG',
#   'FRG,GDR',
#   'FRG,ESP',
#   'ESP,AUS',
#   'GDR,URS',
#   'URS,AUS',
#   'DEN,USA',
#   'USA,GDR',
#   'GBR,USA',
#   'USA,FRG',
#   'FRG,GBR',
#   'GBR,BRA',
#   'SWE,URS',
#   'URS,USA',
#   'GDR,GDR',
#   'GDR,ITA',
#   'GDR,GDR',
#   'GDR,AUT',
#   'FRG,FRG',
#   'FRG,URS',
#   'URS,URS',
#   'URS,POL',
#   'TCH,NED',
#   'NED,POL',
#   'USA,POR',
#   'POR,ITA',
#   'USA,USA',
#   'USA,GDR',
#   'USA,GBR',
#   'GBR,URS',
#   'USA,USA',
#   'USA,USA',
#   'USA,USA',
#   'USA,FRG',
#   'USA,USA',
#   'USA,AUS',
#   'USA,USA',
#   'USA,USA',
#   'GBR,USA',
#   'USA,USA',
#   'USA,USA',
#   'USA,USA',
#   'USA,USA',
#   'USA,USA',
#   'USA,USA',
#   'USA,URS',
#   'USA,USA',
#   'USA,URS',
#   'USA,CAN',
#   'CAN,FRG',
#   'USA,URS',
#   'URS,GBR',
#   'POL,URS',
#   'URS,CUB',
#   'HUN,ITA',
#   'ITA,NED',
#   'URS,GDR',
#   'GDR,GDR',
#   'URS,HUN',
#   'HUN,IRI',
#   'BUL,POL',
#   'POL,JPN',
#   'URS,BUL',
#   'BUL,JPN',
#   'URS,FRA',
#   'FRA,POL',
#   'BUL,URS',
#   'URS,GDR',
#   'URS,BUL',
#   'BUL,HUN',
#   'URS,USA',
#   'USA,BUL',
#   'URS,BUL',
#   'BUL,POL',
#   'URS,HUN',
#   'HUN,ROU',
#   'BUL,URS',
#   'URS,JPN',
#   'JPN,URS',
#   'URS,KOR',
#   'URS,GDR',
#   'GDR,JPN',
#   'KOR,MGL',
#   'MGL,USA',
#   'URS,USA',
#   'USA,JPN',
#   'JPN,IRI',
#   'IRI,USA',
#   'USA,URS',
#   'URS,FRG',
#   'URS,USA',
#   'USA,ROU',
#   'URS,USA',
#   'USA,BUL',
#   'URS,BUL',
#   'BUL,ROU',
#   'URS,ROU',
#   'ROU,BUL',
#   'URS,ROU',
#   'ROU,JPN',
#   'FIN,YUG',
#   'YUG,URS',
#   'POL,URS',
#   'URS,HUN',
#   'URS,ROU',
#   'ROU,GDR',
#   'URS,TCH',
#   'TCH,FRG',
#   'YUG,URS',
#   'URS,BUL',
#   'URS,BUL',
#   'BUL,POL',
#   'URS,BUL',
#   'BUL,POL',
#   'USA,URS',
#   'URS,URS',
#   'FRG,GDR',
#   'GDR,FRG',
#   'GDR,URS',
#   'URS,URS',
#   'URS,GDR',
#   'GDR,GDR',
#   'GDR,FRG',
#   'FRG,GDR',
#   'POL,GDR',
#   'GDR,GDR',
#   'GDR,FRG',
#   'FRG,URS',
#   'GDR,USA',
#   'USA,URS',
#   'URS,BUL',
#   'BUL,GDR',
#   'GDR,BUL',
#   'BUL,GDR',
#   'GDR,ITA',
#   'ITA,BUL',
#   'GDR,FRG',
#   'FRG,USA',
#   'GDR,USA',
#   'USA,URS',
#   'GDR,GDR',
#   'GDR,GDR',
#   'BUL,URS',
#   'URS,TCH',
#   'URS,USA',
#   'USA,BUL',
#   'GDR,URS',
#   'URS,HUN',
#   'URS,HUN',
#   'HUN,GDR',
#   'URS,SWE',
#   'SWE,USA',
#   'USA,GDR',
#   'GDR,USA',
#   'FRG,SUI',
#   'SUI,USA',
#   'URS,FRA',
#   'FRA,HUN',
#   'HUN,ITA',
#   'ITA,URS',
#   'URS,ROU',
#   'ROU,GDR',
#   'ROU,URS',
#   'URS,ROU',
#   'URS,URS',
#   'URS,ROU',
#   'ROU,URS',
#   'URS,URS',
#   'ROU,ROU',
#   'ROU,HUN',
#   'URS,GDR',
#   'URS,URS',
#   'URS,GDR',
#   'GDR,HUN',
#   'BUL,GDR',
#   'GDR,FRG',
#   'BUL,GDR',
#   'GDR,URS',
#   'GDR,URS',
#   'URS,USA',
#   'GDR,BUL',
#   'BUL,URS',
#   'GDR,URS',
#   'URS,ROU',
#   'GDR,USA',
#   'USA,URS',
#   'GDR,GDR',
#   'GDR,CAN',
#   'GDR,URS',
#   'URS,URS',
#   'GDR,GDR',
#   'GDR,USA',
#   'GDR,GDR',
#   'GDR,NED',
#   'GDR,GDR',
#   'GDR,CAN',
#   'URS,URS',
#   'URS,URS',
#   'GDR,GDR',
#   'GDR,GDR',
#   'GDR,USA',
#   'USA,NED',
#   'GDR,USA',
#   'USA,CAN',
#   'GDR,CAN',
#   'CAN,CAN',
#   'USA,GDR',
#   'GDR,CAN',
#   'GDR,USA',
#   'USA,CAN',
#   'GDR,USA',
#   'USA,USA',
#   'JPN,URS',
#   'URS,KOR'],
#  ['FRG,AUT',
#   'AUT,USA',
#   'CAN,FRG',
#   'FRG,FRA',
#   'FRG,ITA',
#   'ITA,LIE',
#   'URS,FIN',
#   'FIN,URS',
#   'URS,FIN',
#   'FIN,GDR',
#   'FIN,URS',
#   'URS,URS',
#   'URS,URS',
#   'URS,USA',
#   'USA,NED',
#   'NED,GDR',
#   'URS,GDR',
#   'GDR,GDR',
#   'GDR,GDR',
#   'GDR,FRG',
#   'URS,USA',
#   'USA,USA',
#   'URS,USA',
#   'USA,URS',
#   'URS,GDR',
#   'GDR,NOR',
#   'USA,CAN',
#   'CAN,URS',
#   'AUT,SUI',
#   'SUI,ITA',
#   'SUI,SUI',
#   'SUI,SWE',
#   'ITA,ITA',
#   'ITA,LIE',
#   'URS,FIN',
#   'FIN,URS',
#   'URS,FIN',
#   'FIN,GDR',
#   'GDR,SUI',
#   'SUI,FRG',
#   'GDR,FRG',
#   'FRG,SUI',
#   'URS,URS',
#   'URS,FIN',
#   'URS,USA',
#   'USA,URS',
#   'FIN,NOR',
#   'NOR,URS',
#   'NOR,GDR',
#   'GDR,SWE',
#   'URS,URS',
#   'URS,USA',
#   'GBR,URS',
#   'URS,CAN',
#   'URS,GDR',
#   'GDR,GDR',
#   'URS,TCH',
#   'TCH,FRG',
#   'GDR,FRG',
#   'FRG,AUT',
#   'GDR,FRG',
#   'FRG,GDR',
#   'GDR,FRG',
#   'FRG,GDR',
#   'AUT,AUT',
#   'AUT,GDR',
#   'GDR,GDR',
#   'GDR,AUT',
#   'NED,NOR',
#   'NOR,NED',
#   'USA,NOR',
#   'NOR,URS',
#   'NOR,URS',
#   'URS,NED',
#   'NOR,NED',
#   'NED,NED',
#   'URS,URS',
#   'URS,USA'],
#  ['FIN,URS',
#   'URS,ITA',
#   'ETH,FIN',
#   'FIN,ETH',
#   'GBR,CUB',
#   'CUB,BUL',
#   'GDR,CUB',
#   'CUB,URS',
#   'GBR,GDR',
#   'GDR,GBR',
#   'ITA,GBR',
#   'GBR,JAM',
#   'ITA,URS',
#   'URS,GDR',
#   'POL,TAN',
#   'TAN,ETH',
#   'URS,AUS',
#   'AUS,GDR',
#   'GDR,URS',
#   'URS,GBR',
#   'URS,POL',
#   'POL,FRA',
#   'URS,GDR',
#   'GDR,ITA',
#   'ETH,TAN',
#   'TAN,FIN',
#   'GDR,ESP',
#   'ESP,URS',
#   'GBR,GBR',
#   'GBR,URS',
#   'GBR,URS',
#   'URS,URS',
#   'URS,TCH',
#   'TCH,CUB',
#   'URS,URS',
#   'URS,URS',
#   'GDR,POL',
#   'POL,GDR',
#   'URS,URS',
#   'URS,GDR',
#   'GDR,GDR',
#   'GDR,URS',
#   'GDR,NED',
#   'NED,URS',
#   'POL,POL',
#   'POL,URS',
#   'URS,URS',
#   'URS,GDR',
#   'URS,URS',
#   'URS,BRA',
#   'YUG,ITA',
#   'ITA,URS',
#   'CUB,URS',
#   'URS,GDR',
#   'URS,HUN',
#   'URS,CUB',
#   'CUB,BUL',
#   'CUB,PRK',
#   'BUL,URS',
#   'URS,IRL',
#   'URS,HUN',
#   'CUB,VEN',
#   'VEN,GUY',
#   'VEN,ROU',
#   'GDR,CUB',
#   'CUB,POL',
#   'CUB,URS',
#   'CUB,URS',
#   'URS,POL',
#   'URS,GDR',
#   'ITA,URS',
#   'URS,CUB',
#   'URS,GBR',
#   'CUB,UGA',
#   'UGA,GDR',
#   'UGA,POL',
#   'CUB,URS',
#   'URS,TCH',
#   'URS,GDR',
#   'CUB,URS',
#   'URS,POL',
#   'URS,ROU',
#   'YUG,POL',
#   'POL,GDR',
#   'POL,CUB',
#   'BUL,URS',
#   'URS,GDR',
#   'URS,BUL',
#   'BUL,GDR',
#   'ROU,GDR',
#   'GDR,URS',
#   'HUN,ROU',
#   'ROU,BUL',
#   'GDR,FRA',
#   'FRA,ROU',
#   'URS,AUS',
#   'AUS,ROU',
#   'URS,HUN',
#   'HUN,ESP',
#   'URS,ESP',
#   'ESP,GDR',
#   'GDR,ROU',
#   'ROU,BUL',
#   'URS,GDR',
#   'GDR,TCH',
#   'URS,POL',
#   'POL,URS',
#   'GDR,URS',
#   'URS,JAM',
#   'SUI,FRA',
#   'FRA,DEN',
#   'GDR,FRA',
#   'FRA,URS',
#   'URS,GDR',
#   'GDR,TCH',
#   'GDR,URS',
#   'URS,URS',
#   'URS,MEX',
#   'MEX,ITA',
#   'URS,URS',
#   'URS,BUL',
#   'BUL,ROU',
#   'ITA,URS',
#   'URS,URS',
#   'URS,ITA',
#   'ITA,MEX',
#   'FRA,URS',
#   'URS,POL',
#   'URS,FRA',
#   'FRA,URS',
#   'URS,ITA',
#   'ITA,HUN',
#   'URS,URS',
#   'URS,HUN',
#   'FRA,POL',
#   'POL,URS',
#   'SWE,HUN',
#   'HUN,FRA',
#   'TCH,GDR',
#   'GDR,URS',
#   'URS,GDR',
#   'GDR,HUN',
#   'GDR,URS',
#   'URS,URS',
#   'BUL,URS',
#   'URS,URS',
#   'URS,URS',
#   'URS,BUL',
#   'URS,URS',
#   'URS,GDR',
#   'HUN,URS',
#   'URS,GDR',
#   'URS,URS',
#   'URS,TCH',
#   'URS,URS',
#   'URS,GDR',
#   'GDR,URS',
#   'URS,ROU',
#   'IND,ESP',
#   'ESP,URS',
#   'FRA,BUL',
#   'BUL,TCH',
#   'BUL,YUG',
#   'FRA,CUB',
#   'CUB,URS',
#   'CUB,HUN',
#   'URS,MGL',
#   'MGL,BUL',
#   'MGL,POL',
#   'ITA,GBR',
#   'GBR,MGL',
#   'GBR,GDR',
#   'URS,CUB',
#   'CUB,GDR',
#   'CUB,FRA',
#   'SUI,CUB',
#   'CUB,GDR',
#   'CUB,URS',
#   'BEL,URS',
#   'URS,GDR',
#   'URS,NED',
#   'GDR,FRA',
#   'FRA,GBR',
#   'FRA,HUN',
#   'POL,URS',
#   'URS,MEX',
#   'URS,POL',
#   'POL,MEX',
#   'URS,HUN',
#   'HUN,URS',
#   'URS,HUN',
#   'HUN,SWE',
#   'GDR,URS',
#   'URS,POL',
#   'GDR,URS',
#   'URS,YUG',
#   'GDR,URS',
#   'URS,GBR',
#   'GDR,URS',
#   'URS,GBR',
#   'GDR,YUG',
#   'YUG,TCH',
#   'GDR,GBR',
#   'GBR,URS',
#   'GDR,URS',
#   'URS,BUL',
#   'FIN,URS',
#   'URS,GDR',
#   'BRA,GDR',
#   'GDR,FIN',
#   'FIN,AUT',
#   'AUT,URS',
#   'DEN,URS',
#   'URS,GRE',
#   'URS,AUT',
#   'AUT,ITA',
#   'BRA,DEN',
#   'DEN,SWE',
#   'ESP,IRL',
#   'IRL,HUN',
#   'ROU,GDR',
#   'GDR,AUT',
#   'URS,GDR',
#   'GDR,BUL',
#   'URS,GDR',
#   'GDR,SWE',
#   'HUN,GDR',
#   'GDR,BUL',
#   'URS,GDR',
#   'GDR,URS',
#   'DEN,SWE',
#   'SWE,CUB',
#   'ITA,URS',
#   'URS,GDR',
#   'SWE,URS',
#   'URS,URS',
#   'GBR,URS',
#   'URS,AUS',
#   'SWE,GDR',
#   'GDR,ESP',
#   'GDR,SWE',
#   'SWE,SWE',
#   'URS,URS',
#   'URS,AUS',
#   'HUN,HUN',
#   'HUN,AUS',
#   'URS,HUN',
#   'HUN,URS',
#   'URS,GBR',
#   'GBR,GDR',
#   'URS,URS',
#   'URS,AUS',
#   'URS,URS',
#   'URS,URS',
#   'URS,URS',
#   'URS,HUN',
#   'AUS,URS',
#   'URS,GBR',
#   'URS,GDR',
#   'GDR,BRA',
#   'URS,BUL',
#   'BUL,ROU',
#   'URS,YUG',
#   'YUG,HUN',
#   'URS,GDR',
#   'GDR,POL',
#   'URS,PRK',
#   'PRK,PRK',
#   'CUB,URS',
#   'URS,POL',
#   'URS,BUL',
#   'BUL,HUN',
#   'URS,BUL',
#   'BUL,POL',
#   'BUL,GDR',
#   'GDR,BUL',
#   'BUL,URS',
#   'URS,BUL',
#   'URS,BUL',
#   'BUL,TCH',
#   'HUN,BUL',
#   'BUL,GDR',
#   'TCH,URS',
#   'URS,CUB',
#   'URS,HUN',
#   'HUN,POL',
#   'ITA,PRK',
#   'PRK,URS',
#   'URS,POL',
#   'POL,BUL',
#   'URS,PRK',
#   'PRK,MGL',
#   'URS,BUL',
#   'BUL,GRE',
#   'URS,BUL',
#   'BUL,YUG',
#   'BUL,MGL',
#   'MGL,TCH',
#   'BUL,URS',
#   'URS,HUN',
#   'URS,GDR',
#   'GDR,POL',
#   'URS,BUL',
#   'BUL,TCH',
#   'URS,BUL',
#   'BUL,LBN',
#   'URS,ROU',
#   'ROU,HUN',
#   'URS,HUN',
#   'HUN,BUL',
#   'URS,POL',
#   'POL,SWE',
#   'GRE,HUN',
#   'HUN,URS',
#   'ROU,POL',
#   'POL,SWE',
#   'HUN,URS',
#   'URS,FIN',
#   'URS,POL',
#   'POL,BUL',
#   'HUN,URS',
#   'URS,ROU',
#   'BUL,POL',
#   'POL,ROU',
#   'URS,URS',
#   'URS,FIN',
#   'URS,GDR',
#   'GDR,GDR',
#   'URS,GDR',
#   'GDR,POL',
#   'URS,GDR',
#   'GDR,URS',
#   'GDR,URS',
#   'URS,JAM',
#   'GDR,TCH',
#   'TCH,GDR',
#   'GDR,URS',
#   'URS,GBR',
#   'URS,GDR',
#   'GDR,GBR',
#   'URS,URS',
#   'URS,URS',
#   'GDR,BUL',
#   'BUL,URS',
#   'ITA,POL',
#   'POL,GDR',
#   'CUB,URS',
#   'URS,GDR',
#   'URS,GDR',
#   'GDR,URS',
#   'URS,URS',
#   'URS,URS',
#   'GDR,URS',
#   'URS,GDR',
#   'URS,BUL',
#   'BUL,YUG',
#   'GDR,BUL',
#   'BUL,URS',
#   'GDR,URS',
#   'URS,HUN',
#   'GDR,URS',
#   'URS,URS',
#   'URS,GDR',
#   'GDR,GDR',
#   'FRA,URS',
#   'URS,HUN',
#   'FRA,HUN',
#   'HUN,POL',
#   'URS,ROU',
#   'ROU,GDR',
#   'ROU,URS',
#   'URS,URS',
#   'URS,ROU',
#   'URS,GDR',
#   'GDR,ROU',
#   'ROU,URS',
#   'ROU,GDR',
#   'ROU,ROU',
#   'URS,GDR',
#   'GDR,ROU',
#   'URS,YUG',
#   'YUG,GDR',
#   'ZIM,TCH',
#   'TCH,URS',
#   'GDR,POL',
#   'POL,BUL',
#   'URS,GDR',
#   'GDR,ROU',
#   'GDR,URS',
#   'URS,ROU',
#   'GDR,BUL',
#   'BUL,URS',
#   'GDR,URS',
#   'URS,BUL',
#   'ROU,URS',
#   'URS,GDR',
#   'GDR,GDR',
#   'GDR,GDR',
#   'GDR,URS',
#   'URS,DEN',
#   'GDR,GDR',
#   'GDR,GDR',
#   'GDR,GDR',
#   'GDR,GDR',
#   'GDR,GDR',
#   'GDR,GDR',
#   'URS,URS',
#   'URS,URS',
#   'GDR,GDR',
#   'GDR,AUS',
#   'GDR,GDR',
#   'GDR,GDR',
#   'GDR,GDR',
#   'GDR,GDR',
#   'GDR,GBR',
#   'GBR,POL',
#   'GDR,SWE',
#   'SWE,NED',
#   'GDR,GBR',
#   'GBR,URS',
#   'AUS,GDR',
#   'GDR,GDR',
#   'URS,GDR',
#   'GDR,BUL'],
#  ['AUT,LIE',
#   'LIE,SUI',
#   'LIE,FRG',
#   'FRG,FRA',
#   'LIE,FRG',
#   'FRG,SUI',
#   'GDR,FIN',
#   'FIN,FIN',
#   'GDR,URS',
#   'URS,NOR',
#   'URS,FIN',
#   'FIN,TCH',
#   'URS,HUN',
#   'HUN,URS',
#   'GDR,USA',
#   'USA,FRG',
#   'URS,URS',
#   'URS,GDR',
#   'URS,GDR',
#   'GDR,URS',
#   'URS,USA',
#   'USA,GDR',
#   'NED,NED',
#   'NED,GDR',
#   'NOR,GDR',
#   'GDR,USA',
#   'GDR,USA',
#   'USA,URS',
#   'AUT,AUT',
#   'AUT,CAN',
#   'SWE,LIE',
#   'LIE,AUT',
#   'SWE,USA',
#   'USA,SUI',
#   'GDR,URS',
#   'URS,URS',
#   'URS,GDR',
#   'GDR,GDR',
#   'URS,GDR',
#   'GDR,FRG',
#   'GDR,SUI',
#   'SUI,GDR',
#   'SUI,GDR',
#   'GDR,GDR',
#   'SWE,FIN',
#   'FIN,NOR',
#   'URS,URS',
#   'URS,BUL',
#   'URS,NOR',
#   'NOR,FIN',
#   'URS,FIN',
#   'FIN,URS',
#   'URS,HUN',
#   'HUN,URS',
#   'GBR,GDR',
#   'GDR,USA',
#   'URS,URS',
#   'URS,GDR',
#   'USA,URS',
#   'URS,SWE',
#   'GDR,ITA',
#   'ITA,AUT',
#   'GDR,ITA',
#   'ITA,FRG',
#   'GDR,FIN',
#   'FIN,GDR',
#   'FIN,AUT',
#   'AUT,FIN',
#   'AUT,GDR',
#   'AUT,JPN',
#   'USA,NED',
#   'NED,NOR',
#   'USA,CAN',
#   'CAN,NOR',
#   'CAN,URS',
#   'USA,NOR',
#   'NOR,NOR',
#   'USA,NOR',
#   'NOR,NOR',
#   'USA,URS',
#   'URS,NED'],
#  ['USA,USA',
#   'USA,JPN',
#   'ITA,GBR',
#   'GBR,KEN',
#   'USA,USA',
#   'USA,CAN',
#   'USA,USA',
#   'USA,FIN',
#   'GBR,GBR',
#   'GBR,ESP',
#   'USA,USA',
#   'USA,USA',
#   'MEX,MEX',
#   'MEX,ITA',
#   'KEN,FRA',
#   'FRA,USA',
#   'USA,CIV',
#   'CIV,USA',
#   'USA,USA',
#   'USA,FRG',
#   'USA,JAM',
#   'JAM,CAN',
#   'USA,GBR',
#   'GBR,NGR',
#   'MAR,SUI',
#   'SUI,POR',
#   'MEX,SWE',
#   'SWE,ITA',
#   'BRA,GBR',
#   'GBR,USA',
#   'GBR,FRG',
#   'FRG,FRG',
#   'FRG,USA',
#   'USA,USA',
#   'FIN,FRG',
#   'FRG,FRG',
#   'FRG,SWE',
#   'SWE,CHN',
#   'FIN,GBR',
#   'GBR,SWE',
#   'USA,AUS',
#   'AUS,ITA',
#   'POR,IRL',
#   'IRL,GBR',
#   'FRA,USA',
#   'USA,USA',
#   'USA,FRA',
#   'ITA,USA',
#   'USA,USA',
#   'USA,USA',
#   'USA,GBR',
#   'USA,ESP',
#   'ESP,YUG',
#   'USA,ITA',
#   'ITA,YUG',
#   'ITA,GBR',
#   'USA,ITA',
#   'ITA,VEN',
#   'ITA,ZAM',
#   'USA,YUG',
#   'YUG,KEN',
#   'YUG,TUR',
#   'ITA,MEX',
#   'MEX,DOM',
#   'MEX,CAN',
#   'USA,NGR',
#   'NGR,TUR',
#   'NGR,VEN',
#   'USA,PUR',
#   'PUR,KOR',
#   'PUR,CMR',
#   'USA,THA',
#   'THA,ROU',
#   'THA,YUG',
#   'USA,KOR',
#   'KOR,ITA',
#   'KOR,FIN',
#   'USA,CAN',
#   'CAN,FRA',
#   'CAN,FRG',
#   'KOR,USA',
#   'USA,PUR',
#   'USA,ALG',
#   'YUG,NZL',
#   'NZL,USA',
#   'NZL,ALG',
#   'USA,CAN',
#   'CAN,ITA',
#   'CAN,NED',
#   'FRG,CAN',
#   'CAN,DEN',
#   'CAN,DEN',
#   'DEN,ROU',
#   'ROU,YUG',
#   'YUG,FRA',
#   'YUG,ROU',
#   'ROU,ESP',
#   'NZL,YUG',
#   'YUG,USA',
#   'NZL,SWE',
#   'SWE,FRA',
#   'CAN,FRA',
#   'FRA,AUS',
#   'NZL,SWE',
#   'SWE,CAN',
#   'NZL,SWE',
#   'SWE,FRA',
#   'ITA,SUI',
#   'SUI,USA',
#   'USA,CAN',
#   'CAN,NOR',
#   'FRG,CAN',
#   'CAN,FRA',
#   'USA,FRG',
#   'FRG,USA',
#   'BEL,FRG',
#   'FRG,MEX',
#   'USA,USA',
#   'USA,JPN',
#   'AUS,USA',
#   'USA,FRG',
#   'USA,USA',
#   'USA,CHN',
#   'USA,CHN',
#   'CHN,USA',
#   'FRG,SUI',
#   'USA,GBR',
#   'GBR,FRG',
#   'ITA,FRG',
#   'FRG,FRA',
#   'ITA,FRG',
#   'FRG,ITA',
#   'ITA,FRA',
#   'FRA,ROU',
#   'FRA,ITA',
#   'ITA,USA',
#   'FRG,FRA',
#   'FRA,ITA',
#   'FRA,SWE',
#   'SWE,FRA',
#   'FRA,BRA',
#   'BRA,YUG',
#   'USA,CHN',
#   'CHN,JPN',
#   'CHN,CHN',
#   'CHN,JPN',
#   'CHN,FRA',
#   'JPN,CHN',
#   'CHN,JPN',
#   'JPN,USA',
#   'USA,CHN',
#   'USA,JPN',
#   'JPN,USA',
#   'CHN,USA',
#   'CHN,JPN',
#   'CHN,CHN',
#   'YUG,FRG',
#   'FRG,ROU',
#   'PAK,FRG',
#   'FRG,GBR',
#   'JPN,FRA',
#   'FRA,CAN',
#   'FRA,KOR',
#   'JPN,KOR',
#   'KOR,GBR',
#   'KOR,USA',
#   'JPN,KOR',
#   'KOR,FRA',
#   'KOR,AUT',
#   'KOR,ITA',
#   'ITA,GBR',
#   'ITA,BRA',
#   'FRG,GBR',
#   'GBR,ROU',
#   'GBR,FRA',
#   'AUT,USA',
#   'USA,BRA',
#   'USA,JPN',
#   'KOR,BRA',
#   'BRA,ISL',
#   'BRA,FRG',
#   'JPN,EGY',
#   'EGY,ROU',
#   'EGY,FRG',
#   'USA,USA',
#   'USA,GBR',
#   'GBR,FRG',
#   'ITA,SWE',
#   'SWE,ITA',
#   'ITA,USA',
#   'USA,FRA',
#   'GBR,USA',
#   'USA,NZL',
#   'ITA,ROU',
#   'ROU,USA',
#   'NZL,USA',
#   'USA,DEN',
#   'ROU,ESP',
#   'ESP,NOR',
#   'USA,BEL',
#   'BEL,YUG',
#   'CAN,USA',
#   'USA,AUS',
#   'FRG,AUS',
#   'AUS,CAN',
#   'FIN,FRG',
#   'FRG,CAN',
#   'ESP,USA',
#   'USA,FRA',
#   'NZL,USA',
#   'USA,CAN',
#   'USA,BRA',
#   'BRA,CAN',
#   'USA,FRG',
#   'FRG,ITA',
#   'NZL,USA',
#   'USA,AUS',
#   'NED,USA',
#   'USA,NZL',
#   'USA,CAN',
#   'CAN,GBR',
#   'FRA,AUT',
#   'AUT,GBR',
#   'JPN,ROU',
#   'ROU,FIN',
#   'CHN,SWE',
#   'SWE,CHN',
#   'GBR,SUI',
#   'SUI,GBR',
#   'USA,FRA',
#   'FRA,GBR',
#   'CHN,COL',
#   'COL,CHN',
#   'USA,DEN',
#   'DEN,ITA',
#   'ITA,PER',
#   'PER,USA',
#   'USA,USA',
#   'USA,CAN',
#   'USA,CAN',
#   'CAN,AUS',
#   'FRG,USA',
#   'USA,AUS',
#   'USA,AUS',
#   'AUS,SWE',
#   'USA,USA',
#   'USA,FRG',
#   'USA,FRA',
#   'FRA,CAN',
#   'CAN,AUS',
#   'AUS,SUI',
#   'AUS,FRG',
#   'FRG,VEN',
#   'FRG,USA',
#   'USA,FRG',
#   'CAN,USA',
#   'USA,GBR',
#   'USA,USA',
#   'USA,AUS',
#   'CAN,BRA',
#   'BRA,AUS',
#   'USA,AUS',
#   'AUS,SWE',
#   'USA,CAN',
#   'CAN,AUS',
#   'USA,FRG',
#   'FRG,GBR',
#   'USA,BRA',
#   'BRA,ITA',
#   'YUG,USA',
#   'USA,FRG',
#   'AUS,USA',
#   'USA,FRG',
#   'CHN,CHN',
#   'CHN,JPN',
#   'CHN,CHN',
#   'CHN,JPN',
#   'ITA,ROU',
#   'ROU,USA',
#   'CHN,ROU',
#   'ROU,TPE',
#   'CHN,ROU',
#   'ROU,FIN',
#   'FRG,CAN',
#   'CAN,ROU',
#   'ROU,AUS',
#   'AUS,JPN',
#   'ROU,ROU',
#   'ROU,GBR',
#   'FRG,ROU',
#   'ROU,FIN',
#   'USA,CAN',
#   'CAN,TUR',
#   'USA,JPN',
#   'JPN,KOR',
#   'YUG,KOR',
#   'KOR,JPN',
#   'JPN,USA',
#   'USA,KOR',
#   'USA,JPN',
#   'JPN,KOR',
#   'KOR,USA',
#   'USA,FIN',
#   'USA,FRG',
#   'FRG,YUG',
#   'USA,JPN',
#   'JPN,CAN',
#   'USA,JPN',
#   'JPN,GBR',
#   'USA,SYR',
#   'SYR,ROU',
#   'USA,YUG',
#   'YUG,ROU',
#   'ITA,FRG',
#   'FRG,JPN',
#   'JPN,MEX',
#   'MEX,KOR',
#   'FRG,JPN',
#   'JPN,GRE',
#   'KOR,SWE',
#   'SWE,SUI',
#   'YUG,FIN',
#   'FIN,USA',
#   'FIN,SWE',
#   'SWE,ROU',
#   'ROU,GRE',
#   'GRE,SWE',
#   'USA,ROU',
#   'ROU,SWE',
#   'ROU,USA',
#   'USA,YUG',
#   'KOR,CHN',
#   'CHN,KOR',
#   'USA,USA',
#   'USA,JAM',
#   'USA,GBR',
#   'GBR,FRA',
#   'GBR,USA',
#   'ITA,ROU',
#   'ROU,ROU',
#   'USA,USA',
#   'USA,JAM',
#   'ROU,GBR',
#   'GBR,CAN',
#   'USA,USA',
#   'USA,GBR',
#   'MAR,USA',
#   'USA,ROU',
#   'USA,CAN',
#   'CAN,GBR',
#   'USA,CAN',
#   'CAN,FRG',
#   'ROU,USA',
#   'USA,ROU',
#   'NED,USA',
#   'USA,ROU',
#   'AUS,USA',
#   'USA,FRG',
#   'FRG,ITA',
#   'ITA,USA',
#   'GBR,FIN',
#   'FIN,GBR',
#   'ROU,ROU',
#   'ROU,GBR',
#   'USA,NOR',
#   'NOR,POR',
#   'FRG,ROU',
#   'ROU,AUS',
#   'USA,KOR',
#   'KOR,CHN',
#   'SWE,FRG',
#   'FRG,NED',
#   'SWE,CAN',
#   'CAN,FRG',
#   'ROU,SWE',
#   'SWE,CAN',
#   'USA,USA',
#   'USA,FRG',
#   'CHN,USA',
#   'USA,USA',
#   'CAN,USA',
#   'USA,USA',
#   'SUI,SWE',
#   'USA,GBR',
#   'USA,GBR',
#   'GBR,FRG',
#   'FRG,ROU',
#   'ROU,FRA',
#   'CHN,FRG',
#   'FRG,ITA',
#   'ROU,USA',
#   'USA,CHN',
#   'ROU,USA',
#   'USA,USA',
#   'USA,ROU',
#   'ROU,ROU',
#   'ROU,USA',
#   'USA,ROU',
#   'CAN,ROU',
#   'ROU,FRG',
#   'YUG,KOR',
#   'KOR,CHN',
#   'NED,FRG',
#   'FRG,USA',
#   'ROU,CAN',
#   'CAN,FRG',
#   'ROU,NED',
#   'NED,CAN',
#   'USA,ROU',
#   'ROU,NED',
#   'ROU,CAN',
#   'CAN,AUS',
#   'ROU,USA',
#   'USA,DEN',
#   'ROU,USA',
#   'USA,BEL',
#   'USA,ITA',
#   'ITA,CHN',
#   'CAN,USA',
#   'USA,AUS',
#   'CHN,FRG',
#   'FRG,USA',
#   'USA,USA',
#   'USA,NED',
#   'NED,CAN',
#   'CAN,FRA',
#   'USA,USA',
#   'USA,FRG',
#   'NED,USA',
#   'USA,ROU',
#   'CAN,USA',
#   'USA,BEL',
#   'USA,AUS',
#   'AUS,FRG',
#   'USA,USA',
#   'USA,NED',
#   'USA,USA',
#   'USA,AUS',
#   'USA,GBR',
#   'GBR,GBR',
#   'USA,AUS',
#   'AUS,FRG',
#   'USA,NED',
#   'NED,FRG',
#   'USA,FRG',
#   'FRG,CAN',
#   'USA,USA',
#   'USA,GBR',
#   'USA,CAN',
#   'CAN,JPN',
#   'USA,CAN',
#   'CAN,JPN',
#   'CHN,USA',
#   'USA,JPN'],
#  ['SUI,SUI',
#   'SUI,TCH',
#   'USA,USA',
#   'USA,FRA',
#   'ITA,FRA',
#   'FRA,LIE',
#   'FIN,URS',
#   'URS,NOR',
#   'FIN,URS',
#   'URS,NOR',
#   'NOR,TCH',
#   'TCH,FIN',
#   'FIN,NOR',
#   'NOR,TCH',
#   'GBR,URS',
#   'URS,URS',
#   'GDR,USA',
#   'USA,URS',
#   'URS,USA',
#   'USA,URS',
#   'GDR,GDR',
#   'GDR,GDR',
#   'GDR,GDR',
#   'GDR,URS',
#   'GDR,GDR',
#   'GDR,URS',
#   'GDR,GDR',
#   'GDR,GDR',
#   'GDR,GDR',
#   'GDR,URS',
#   'USA,SUI',
#   'SUI,AUT',
#   'SUI,YUG',
#   'YUG,LIE',
#   'USA,USA',
#   'USA,FRA',
#   'NOR,FRG',
#   'FRG,GDR',
#   'FRG,GDR',
#   'GDR,NOR',
#   'URS,NOR',
#   'NOR,FRG',
#   'GDR,GDR',
#   'GDR,SUI',
#   'GDR,GDR',
#   'GDR,URS',
#   'SWE,FIN',
#   'FIN,FIN',
#   'URS,URS',
#   'URS,SWE',
#   'SWE,URS',
#   'URS,FIN',
#   'SWE,SWE',
#   'SWE,FIN',
#   'GBR,URS',
#   'URS,URS',
#   'USA,CAN',
#   'CAN,TCH',
#   'URS,USA',
#   'USA,URS',
#   'URS,TCH',
#   'TCH,SWE',
#   'FRG,URS',
#   'URS,GDR',
#   'ITA,URS',
#   'URS,URS',
#   'NOR,FIN',
#   'FIN,FIN',
#   'FIN,GDR',
#   'GDR,TCH',
#   'GDR,FIN',
#   'FIN,FIN',
#   'URS,SWE',
#   'SWE,GDR',
#   'CAN,URS',
#   'URS,NOR',
#   'CAN,URS',
#   'URS,URS',
#   'SWE,URS',
#   'URS,GDR',
#   'URS,JPN',
#   'JPN,CAN'],
#  ['USA,KOR',
#   'KOR,URS',
#   'KOR,USA',
#   'USA,GBR',
#   'MAR,ITA',
#   'ITA,KEN',
#   'USA,GBR',
#   'GBR,USA',
#   'USA,GBR',
#   'GBR,USA',
#   'KEN,GBR',
#   'GBR,GDR',
#   'USA,USA',
#   'USA,BRA',
#   'TCH,GDR',
#   'GDR,ITA',
#   'KEN,KEN',
#   'KEN,GBR',
#   'USA,USA',
#   'USA,USA',
#   'USA,SEN',
#   'SEN,USA',
#   'URS,GBR',
#   'GBR,FRA',
#   'USA,JAM',
#   'JAM,FRG',
#   'KEN,FRG',
#   'FRG,GDR',
#   'URS,GDR',
#   'GDR,GDR',
#   'KEN,BRA',
#   'BRA,MAR',
#   'GDR,GDR',
#   'GDR,CAN',
#   'GDR,URS',
#   'URS,FRG',
#   'URS,URS',
#   'URS,URS',
#   'URS,USA',
#   'USA,URS',
#   'USA,SWE',
#   'FIN,TCH',
#   'TCH,FIN',
#   'USA,USA',
#   'USA,USA',
#   'ITA,KEN',
#   'KEN,DJI',
#   'URS,URS',
#   'URS,URS',
#   'GDR,USA',
#   'USA,SUI',
#   'BUL,URS',
#   'URS,URS',
#   'URS,YUG',
#   'YUG,USA',
#   'CAN,USA',
#   'USA,URS',
#   'USA,POL',
#   'BUL,USA',
#   'USA,HUN',
#   'USA,PHI',
#   'KOR,GDR',
#   'GDR,MEX',
#   'GDR,URS',
#   'USA,BUL',
#   'BUL,COL',
#   'BUL,THA',
#   'ITA,ROU',
#   'ROU,MAR',
#   'ROU,KOR',
#   'GDR,SWE',
#   'SWE,USA',
#   'SWE,MGL',
#   'URS,AUS',
#   'AUS,FRG',
#   'AUS,SWE',
#   'KEN,FRA',
#   'FRA,POL',
#   'FRA,USA',
#   'KOR,USA',
#   'USA,CAN',
#   'USA,GBR',
#   'GDR,CAN',
#   'CAN,KEN',
#   'CAN,PAK',
#   'USA,URS',
#   'URS,POL',
#   'URS,YUG',
#   'USA,KOR',
#   'KOR,POL',
#   'KOR,NED',
#   'URS,GDR',
#   'GDR,BUL',
#   'GDR,URS',
#   'URS,BUL',
#   'URS,GDR',
#   'GDR,POL',
#   'URS,POL',
#   'POL,FRA',
#   'USA,AUS',
#   'AUS,GDR',
#   'HUN,GDR',
#   'GDR,NZL',
#   'USA,NZL',
#   'NZL,AUS',
#   'NZL,URS',
#   'URS,HUN',
#   'HUN,URS',
#   'URS,GDR',
#   'GDR,POL',
#   'POL,SWE',
#   'GDR,FRG',
#   'FRG,FRG',
#   'URS,AUS',
#   'AUS,FRG',
#   'URS,AUS',
#   'AUS,GDR',
#   'DEN,NED',
#   'NED,URS',
#   'GDR,URS',
#   'URS,AUS',
#   'URS,GDR',
#   'GDR,AUS',
#   'USA,CHN',
#   'CHN,MEX',
#   'USA,CHN',
#   'CHN,CHN',
#   'FRG,SUI',
#   'SUI,CAN',
#   'NZL,GBR',
#   'FRG,GBR',
#   'GBR,NZL',
#   'URS,FRG',
#   'FRG,HUN',
#   'ITA,GDR',
#   'GDR,URS',
#   'HUN,URS',
#   'URS,ITA',
#   'FRA,POL',
#   'POL,ITA',
#   'FRA,FRG',
#   'FRG,URS',
#   'FRG,FRA',
#   'FRA,URS',
#   'URS,BRA',
#   'BRA,FRG',
#   'URS,GDR',
#   'GDR,JPN',
#   'URS,URS',
#   'URS,JPN',
#   'URS,CHN',
#   'URS,URS',
#   'URS,URS',
#   'URS,URS',
#   'URS,GDR',
#   'CHN,GDR',
#   'GDR,KOR',
#   'URS,KOR',
#   'KOR,YUG',
#   'GBR,FRG',
#   'FRG,NED',
#   'JPN,GDR',
#   'GDR,KOR',
#   'GDR,URS',
#   'KOR,USA',
#   'USA,JPN',
#   'USA,URS',
#   'KOR,POL',
#   'POL,FRA',
#   'POL,JPN',
#   'FRA,GDR',
#   'GDR,USA',
#   'GDR,URS',
#   'POL,FRG',
#   'FRG,GDR',
#   'FRG,URS',
#   'AUT,URS',
#   'URS,JPN',
#   'URS,NED',
#   'BRA,FRG',
#   'FRG,GBR',
#   'FRG,BEL',
#   'FRA,USA',
#   'USA,FRG',
#   'FRG,USA',
#   'USA,FRA',
#   'HUN,ITA',
#   'ITA,URS',
#   'HUN,ITA',
#   'ITA,GBR',
#   'GDR,ROU',
#   'ROU,NZL',
#   'ITA,GDR',
#   'GDR,GBR',
#   'GDR,USA',
#   'USA,FRG',
#   'GBR,ROU',
#   'ROU,YUG',
#   'NED,SUI',
#   'SUI,URS',
#   'FRG,URS',
#   'URS,USA',
#   'ITA,NOR',
#   'NOR,GDR',
#   'GDR,FRG',
#   'FRG,NZL',
#   'FRA,URS',
#   'URS,USA',
#   'NZL,AHO',
#   'AHO,USA',
#   'ESP,ISV',
#   'ISV,NZL',
#   'GDR,USA',
#   'USA,DEN',
#   'GBR,USA',
#   'USA,BRA',
#   'FRA,NZL',
#   'NZL,BRA',
#   'DEN,NOR',
#   'NOR,CAN',
#   'BUL,USA',
#   'USA,CHN',
#   'YUG,FRA',
#   'FRA,FRG',
#   'URS,GDR',
#   'GDR,HUN',
#   'ROU,SWE',
#   'SWE,URS',
#   'GBR,GBR',
#   'GBR,URS',
#   'TCH,KOR',
#   'KOR,HUN',
#   'NOR,CHN',
#   'CHN,URS',
#   'GDR,CHI',
#   'CHI,ESP',
#   'URS,TCH',
#   'TCH,BEL',
#   'JPN,USA',
#   'USA,URS',
#   'GBR,GBR',
#   'GBR,HUN',
#   'HUN,GBR',
#   'HUN,HUN',
#   'GBR,ESP',
#   'GBR,URS',
#   'HUN,ESP',
#   'HUN,URS',
#   'SUR,USA',
#   'USA,GBR',
#   'USA,USA',
#   'USA,FRA',
#   'URS,FRG',
#   'FRG,GDR',
#   'URS,GDR',
#   'GDR,NZL',
#   'FRG,DEN',
#   'DEN,NZL',
#   'AUS,SWE',
#   'SWE,USA',
#   'HUN,GDR',
#   'GDR,URS',
#   'GDR,AUS',
#   'AUS,POL',
#   'HUN,USA',
#   'USA,ITA',
#   'USA,URS',
#   'URS,GDR',
#   'USA,CAN',
#   'CAN,URS',
#   'USA,GDR',
#   'GDR,FRG',
#   'USA,USA',
#   'USA,URS',
#   'CHN,YUG',
#   'YUG,KOR',
#   'KOR,KOR',
#   'KOR,SWE',
#   'USA,ESP',
#   'ESP,SWE',
#   'ESP,TCH',
#   'TCH,USA',
#   'USA,SWE',
#   'USA,USA',
#   'USA,URS',
#   'URS,ARG',
#   'YUG,USA',
#   'USA,URS',
#   'URS,FRG',
#   'FRG,FRG',
#   'BUL,KOR',
#   'KOR,CHN',
#   'URS,CHN',
#   'CHN,CHN',
#   'URS,HUN',
#   'HUN,GDR',
#   'TUR,BUL',
#   'BUL,CHN',
#   'GDR,URS',
#   'URS,CHN',
#   'BUL,GDR',
#   'GDR,BUL',
#   'URS,HUN',
#   'HUN,KOR',
#   'URS,URS',
#   'URS,POL',
#   'URS,ROU',
#   'ROU,FRG',
#   'JPN,BUL',
#   'BUL,URS',
#   'URS,USA',
#   'USA,GDR',
#   'JPN,YUG',
#   'YUG,URS',
#   'URS,IRI',
#   'IRI,KOR',
#   'USA,URS',
#   'URS,BUL',
#   'URS,KOR',
#   'KOR,USA',
#   'USA,URS',
#   'URS,BUL',
#   'KOR,TUR',
#   'TUR,TCH',
#   'URS,JPN',
#   'JPN,KOR',
#   'ROU,URS',
#   'URS,USA',
#   'ITA,POL',
#   'POL,BUL',
#   'URS,BUL',
#   'BUL,SWE',
#   'NOR,JPN',
#   'JPN,KOR',
#   'HUN,BUL',
#   'BUL,GRE',
#   'URS,BUL',
#   'BUL,KOR',
#   'URS,KOR',
#   'KOR,FIN',
#   'KOR,URS',
#   'URS,POL',
#   'URS,HUN',
#   'HUN,KOR',
#   'BUL,FIN',
#   'FIN,URS',
#   'POL,FRG',
#   'FRG,USA',
#   'KOR,KOR',
#   'KOR,KOR',
#   'KOR,INA',
#   'INA,USA',
#   'URS,GBR',
#   'GBR,URS',
#   'USA,USA',
#   'USA,GDR',
#   'BUL,GDR',
#   'GDR,FRG',
#   'ROU,URS',
#   'URS,URS',
#   'USA,JAM',
#   'JAM,GDR',
#   'URS,ROU',
#   'ROU,GBR',
#   'URS,GDR',
#   'GDR,URS',
#   'AUS,URS',
#   'URS,GDR',
#   'USA,GDR',
#   'GDR,URS',
#   'URS,USA',
#   'USA,GDR',
#   'GDR,GDR',
#   'GDR,USA',
#   'GDR,GDR',
#   'GDR,BUL',
#   'USA,GDR',
#   'GDR,GDR',
#   'USA,BUL',
#   'BUL,URS',
#   'GDR,GBR',
#   'GBR,GDR',
#   'USA,GDR',
#   'GDR,URS',
#   'POR,AUS',
#   'AUS,GDR',
#   'URS,GDR',
#   'GDR,CHN',
#   'USA,YUG',
#   'YUG,URS',
#   'BUL,GDR',
#   'GDR,POL',
#   'GDR,BUL',
#   'BUL,NED',
#   'GDR,HUN',
#   'HUN,BUL',
#   'NED,FRG',
#   'FRG,URS',
#   'URS,GDR',
#   'GDR,USA',
#   'CHN,USA',
#   'USA,USA',
#   'CHN,CHN',
#   'CHN,USA',
#   'FRG,FRA',
#   'FRA,SUI',
#   'FRG,SUI',
#   'SUI,CAN',
#   'GBR,NZL',
#   'FRG,ITA',
#   'ITA,HUN',
#   'FRG,FRG',
#   'FRG,FRG',
#   'URS,ROU',
#   'ROU,GDR',
#   'ROU,URS',
#   'URS,USA',
#   'URS,ROU',
#   'ROU,URS',
#   'URS,BUL',
#   'URS,ROU',
#   'ROU,URS',
#   'ROU,GDR',
#   'GDR,URS',
#   'URS,ROU',
#   'ROU,ROU',
#   'URS,BUL',
#   'BUL,URS',
#   'KOR,NOR',
#   'NOR,URS',
#   'AUS,KOR',
#   'KOR,NED',
#   'ROU,BUL',
#   'BUL,NZL',
#   'GDR,ROU',
#   'ROU,BUL',
#   'GDR,ROU',
#   'ROU,CHN',
#   'GDR,CHN',
#   'CHN,ROU',
#   'GDR,URS',
#   'URS,ROU',
#   'GDR,USA',
#   'USA,BUL',
#   'USA,SWE',
#   'SWE,URS',
#   'YUG,URS',
#   'URS,URS',
#   'URS,FRG',
#   'FRG,URS',
#   'URS,JPN',
#   'JPN,YUG',
#   'FRG,BUL',
#   'BUL,URS',
#   'GDR,HUN',
#   'HUN,GDR',
#   'BUL,BUL',
#   'BUL,CHN',
#   'GDR,BUL',
#   'GDR,CHN',
#   'BUL,BUL',
#   'BUL,GDR',
#   'CHN,BUL',
#   'CHN,GDR',
#   'GDR,GDR',
#   'GDR,CHN',
#   'GDR,CHN',
#   'CHN,FRA',
#   'HUN,GDR',
#   'GDR,GDR',
#   'GDR,GDR',
#   'GDR,USA',
#   'GDR,CRC',
#   'CRC,GDR',
#   'GDR,URS',
#   'URS,ROU',
#   'USA,GDR',
#   'GDR,GDR',
#   'USA,ROU',
#   'ROU,GDR',
#   'GDR,NED',
#   'NED,USA',
#   'GDR,USA',
#   'USA,CAN',
#   'GDR,CHN',
#   'CHN,GDR',
#   'CHN,USA',
#   'USA,GDR',
#   'GDR,AUS',
#   'CAN,USA',
#   'USA,JPN',
#   'CAN,USA',
#   'USA,JPN',
# ...
#   'ROU,FRA',
#   'SLO,CHN',
#   'CHN,FRA',
#   'CHN,JPN',
#   'FRA,GER',
#   'GER,COL',
#   'GER,NED',
#   'USA,GBR',
#   'GBR,BRA',
#   'GBR,FRA',
#   'HUN,USA',
#   'USA,ITA',
#   'LTU,GBR',
#   'GBR,BRA',
#   'FRA,GER',
#   'GER,USA',
#   'GBR,AUS',
#   'AUS,NZL',
#   'GBR,AUS',
#   'AUS,POL',
#   'USA,CAN',
#   'CAN,NED',
#   'GBR,CHN',
#   'CHN,GRE',
#   'UKR,GER',
#   'GER,USA',
#   'CZE,DEN',
#   'DEN,AUS',
#   'NZL,GBR',
#   'GBR,NED',
#   'ESP,AUS',
#   'AUS,FIN',
#   'CHN,NED',
#   'NED,BEL',
#   'ESP,FIN',
#   'FIN,POL',
#   'CHN,FRA',
#   'FRA,UKR',
#   'CHN,POL',
#   'POL,CHN',
#   'KOR,CHN',
#   'CHN,UKR',
#   'USA,SRB',
#   'SRB,CZE',
#   'USA,CHN',
#   'CHN,SVK',
#   'ITA,SVK',
#   'SVK,FRA',
#   'USA,AUS',
#   'AUS,JPN',
#   'LTU,USA',
#   'USA,JPN',
#   'USA,CHN',
#   'CHN,AUS',
#   'NED,BLR',
#   'BLR,CHN',
#   'USA,RUS',
#   'RUS,USA',
#   'USA,JPN',
#   'JPN,RUS',
#   'CHN,ESP',
#   'ESP,JPN',
#   'USA,FRA',
#   'FRA,AUS',
#   'CHN,AUS',
#   'AUS,USA',
#   'FRA,USA',
#   'USA,GBR',
#   'CHN,USA',
#   'USA,CHN',
#   'AUS,NED',
#   'NED,USA',
#   'USA,AUS',
#   'AUS,JPN',
#   'USA,AUS',
#   'AUS,FRA',
#   'NED,BLR',
#   'BLR,NED',
#   'USA,ESP',
#   'ESP,GBR',
#   'RUS,CHN',
#   'CHN,ESP',
#   'RUS,ESP',
#   'ESP,CHN',
#   'CHN,CHN',
#   'CHN,SGP',
#   'CHN,JPN',
#   'JPN,SGP',
#   'SRB,FRA',
#   'FRA,RUS',
#   'FRA,MEX',
#   'CHN,ESP',
#   'ESP,THA',
#   'ESP,CRO',
#   'GBR,CHN',
#   'CHN,FRA',
#   'CHN,TPE',
#   'KOR,TUR',
#   'TUR,GER',
#   'TUR,USA',
#   'USA,CZE',
#   'CZE,RUS',
#   'USA,RUS',
#   'RUS,BLR',
#   'BLR,GBR',
#   'GBR,USA',
#   'CAN,CHN',
#   'CHN,CHN',
#   'SUI,SWE',
#   'SWE,AUS',
#   'BRA,USA',
#   'USA,JPN',
#   'USA,ESP',
#   'ESP,AUS',
#   'CHN,RUS',
#   'RUS,KOR',
#   'CHN,JPN',
#   'JPN,PRK',
#   'TPE,INA',
#   'INA,UKR',
#   'CHN,THA',
#   'THA,THA',
#   'CAN,BUL',
#   'PRK,ROU',
#   'ROU,KAZ',
#   'ESP,EGY',
#   'EGY,CMR',
#   'JPN,AZE',
#   'AZE,USA',
#   'AZE,CAN',
#   'JPN,CAN',
#   'CAN,AZE',
#   'CAN,COL',
#   'JPN,CHN',
#   'CHN,MGL',
#   'CHN,RUS',
#   'RUS,BUL',
#   'BUL,KAZ',
#   'BUL,ESP'],
#  ['GER,AUT',
#   'AUT,USA',
#   'SLO,AUT',
#   'AUT,GER',
#   'USA,AUT',
#   'AUT,AUT',
#   'AUT,GER',
#   'GER,AUT',
#   'BLR,NOR',
#   'NOR,SLO',
#   'BLR,CZE',
#   'CZE,NOR',
#   'BLR,SUI',
#   'SUI,BLR',
#   'NOR,CZE',
#   'CZE,ITA',
#   'CAN,USA',
#   'USA,USA',
#   'POL,SWE',
#   'SWE,NOR',
#   'NOR,NOR',
#   'NOR,NOR',
#   'SWE,FIN',
#   'FIN,GER',
#   'NOR,SWE',
#   'SWE,NOR',
#   'NOR,FIN',
#   'FIN,SWE',
#   'NOR,NOR',
#   'NOR,SLO',
#   'CAN,SWE',
#   'SWE,GBR',
#   'RUS,CAN',
#   'CAN,USA',
#   'USA,CAN',
#   'CAN,RUS',
#   'RUS,KOR',
#   'KOR,ITA',
#   'RUS,RUS',
#   'RUS,GER',
#   'CAN,CAN',
#   'CAN,SWE',
#   'USA,FRA',
#   'FRA,JPN',
#   'CAN,USA',
#   'USA,CAN',
#   'BLR,CHN',
#   'CHN,AUS',
#   'CAN,CAN',
#   'CAN,USA',
#   'CAN,USA',
#   'USA,SUI',
#   'GER,RUS',
#   'RUS,LAT',
#   'GER,GER',
#   'GER,USA',
#   'KOR,CHN',
#   'CHN,KOR',
#   'CHN,KOR',
#   'KOR,ITA',
#   'KOR,CAN',
#   'CAN,ITA',
#   'CHN,ITA',
#   'ITA,KOR',
#   'GBR,USA',
#   'USA,RUS',
#   'GER,AUT',
#   'AUT,FRA',
#   'SUI,JPN',
#   'JPN,RUS',
#   'USA,AUS',
#   'AUS,USA',
#   'USA,FIN',
#   'FIN,GBR',
#   'CZE,CAN',
#   'CAN,FRA',
#   'AUT,GER',
#   'GER,GER',
#   'CHN,NED',
#   'NED,NED',
#   'NED,NED',
#   'NED,NED',
#   'NED,CZE',
#   'CZE,RUS',
#   'CZE,NED',
#   'NED,NED',
#   'KOR,RUS',
#   'RUS,NED',
#   'NED,POL',
#   'POL,RUS',
#   'SUI,CRO',
#   'CRO,ITA',
#   'AUT,ITA',
#   'ITA,NOR',
#   'USA,FRA',
#   'FRA,FRA',
#   'AUT,AUT',
#   'AUT,NOR',
#   'NOR,USA',
#   'USA,CAN',
#   'USA,USA',
#   'NOR,AUT',
#   'AUT,CZE',
#   'FRA,CZE',
#   'CZE,FRA',
#   'NOR,FRA',
#   'FRA,CZE',
#   'FRA,GER',
#   'GER,RUS',
#   'RUS,GER',
#   'GER,AUT',
#   'NOR,CZE',
#   'CZE,ITA',
#   'LAT,USA',
#   'SUI,USA',
#   'SUI,SWE',
#   'SWE,SWE',
#   'SWE,RUS',
#   'RUS,FRA',
#   'RUS,RUS',
#   'RUS,RUS',
#   'SUI,SWE',
#   'SWE,NOR',
#   'NOR,SWE',
#   'SWE,SWE',
#   'FIN,RUS',
#   'RUS,SWE',
#   'CAN,GBR',
#   'GBR,SWE',
#   'RUS,CAN',
#   'CAN,USA',
#   'USA,CAN',
#   'CAN,RUS',
#   'JPN,CAN',
#   'CAN,KAZ',
#   'RUS,RUS',
#   'RUS,GER',
#   'FRA,FRA',
#   'FRA,FRA',
#   'USA,CAN',
#   'CAN,FRA',
#   'USA,USA',
#   'USA,USA',
#   'BLR,AUS',
#   'AUS,CHN',
#   'CAN,CAN',
#   'CAN,RUS',
#   'CAN,SWE',
#   'SWE,FIN',
#   'GER,RUS',
#   'RUS,LAT',
#   'GER,AUT',
#   'AUT,LAT',
#   'GER,RUS',
#   'RUS,ITA',
#   'NOR,NOR',
#   'NOR,GER',
#   'NOR,GER',
#   'GER,AUT',
#   'GER,JPN',
#   'JPN,NOR',
#   'RUS,RUS',
#   'RUS,NED',
#   'CAN,CHN',
#   'CHN,RUS',
#   'RUS,USA',
#   'USA,CHN',
#   'RUS,CHN',
#   'CHN,CAN',
#   'RUS,LAT',
#   'LAT,USA',
#   'POL,JPN',
#   'JPN,SLO',
#   'POL,SLO',
#   'SLO,NOR',
#   'GER,AUT',
#   'AUT,JPN',
#   'RUS,SUI',
#   'SUI,SLO',
#   'SUI,JPN',
#   'JPN,JPN',
#   'USA,NOR',
#   'NOR,CAN',
#   'FRA,RUS',
#   'RUS,USA',
#   'RUS,SLO',
#   'SLO,AUT',
#   'NED,NED',
#   'NED,NED',
#   'NED,CAN',
#   'CAN,NED',
#   'POL,NED',
#   'NED,CAN',
#   'NED,NED',
#   'NED,NED',
#   'NED,NED',
#   'NED,NED',
#   'NED,KOR',
#   'KOR,POL'],
#  ['KOR,FRA',
#   'FRA,USA',
#   'KOR,USA',
#   'USA,AUS',
#   'GBR,KEN',
#   'KEN,ETH',
#   'JAM,USA',
#   'USA,CAN',
#   'JAM,ESP',
#   'ESP,FRA',
#   'USA,ALG',
#   'ALG,NZL',
#   'JAM,CAN',
#   'CAN,FRA',
#   'CHN,CHN',
#   'CHN,AUS',
#   'KEN,USA',
#   'USA,FRA',
#   'RSA,GRN',
#   'GRN,USA',
#   'USA,KEN',
#   'KEN,TUR',
#   'JAM,JPN',
#   'JPN,CAN',
#   'USA,JAM',
#   'JAM,BAH',
#   'GBR,USA',
#   'USA,ETH',
#   'SVK,AUS',
#   'AUS,JPN',
#   'KEN,ALG',
#   'ALG,USA',
#   'USA,FRA',
#   'FRA,CAN',
#   'GER,POL',
#   'POL,GER',
#   'TJK,BLR',
#   'BLR,POL',
#   'CAN,QAT',
#   'QAT,UKR',
#   'GER,KEN',
#   'KEN,TTO',
#   'USA,RSA',
#   'RSA,GBR',
#   'KEN,ETH',
#   'ETH,USA',
#   'BRA,FRA',
#   'FRA,USA',
#   'USA,USA',
#   'USA,NZL',
#   'USA,USA',
#   'USA,CHN',
#   'CHN,MAS',
#   'INA,MAS',
#   'MAS,GBR',
#   'MAS,CHN',
#   'CHN,MAS',
#   'MAS,DEN',
#   'USA,SRB',
#   'SRB,ESP',
#   'BRA,ITA',
#   'ITA,NED',
#   'FRA,GBR',
#   'GBR,CRO',
#   'GBR,KAZ',
#   'UZB,COL',
#   'COL,CUB',
#   'COL,USA',
#   'CUB,USA',
#   'USA,RUS',
#   'USA,UZB',
#   'BRA,FRA',
#   'FRA,CUB',
#   'FRA,MGL',
#   'UZB,AZE',
#   'AZE,GER',
#   'AZE,RUS',
#   'KAZ,UZB',
#   'UZB,FRA',
#   'UZB,MAR',
#   'CUB,UZB',
#   'UZB,AZE',
#   'UZB,MEX',
#   'CUB,KAZ',
#   'KAZ,FRA',
#   'KAZ,GBR',
#   'RUS,KAZ',
#   'KAZ,CUB',
#   'KAZ,UZB',
#   'FRA,SVK',
#   'SVK,JPN',
#   'SVK,GBR',
#   'GBR,FRA',
#   'GBR,SLO',
#   'SLO,CZE',
#   'GER,BRA',
#   'BRA,MDA',
#   'UKR,AZE',
#   'AZE,BRA',
#   'GER,BRA',
#   'BRA,UKR',
#   'ESP,CZE',
#   'CZE,RUS',
#   'GBR,FRA',
#   'FRA,ESP',
#   'FRA,GER',
#   'GER,SRB',
#   'SRB,AUS',
#   'ESP,GBR',
#   'GBR,LTU',
#   'GER,SVK',
#   'SVK,CZE',
#   'USA,NED',
#   'NED,COL',
#   'SUI,CZE',
#   'CZE,ESP',
#   'BEL,DEN',
#   'DEN,POL',
#   'SUI,NED',
#   'NED,GBR',
#   'GBR,NED',
#   'NED,MAS',
#   'ITA,GBR',
#   'GBR,DEN',
#   'GBR,GBR',
#   'GBR,RUS',
#   'GBR,AUS',
#   'AUS,DEN',
#   'GBR,NZL',
#   'NZL,FRA',
#   'CHN,MEX',
#   'MEX,USA',
#   'CHN,GBR',
#   'GBR,GER',
#   'CHN,USA',
#   'USA,GBR',
#   'GBR,USA',
#   'USA,CHN',
#   'GER,GBR',
#   'GBR,USA',
#   'GER,FRA',
#   'FRA,USA',
#   'FRA,GER',
#   'GER,AUS',
#   'GBR,SWE',
#   'SWE,CAN',
#   'FRA,USA',
#   'USA,GER',
#   'ITA,USA',
#   'USA,RUS',
#   'RUS,FRA',
#   'FRA,USA',
#   'HUN,USA',
#   'USA,KOR',
#   'KOR,HUN',
#   'HUN,FRA',
#   'FRA,ITA',
#   'ITA,HUN',
#   'BRA,GER',
#   'GER,NGR',
#   'GBR,SWE',
#   'SWE,USA',
#   'JPN,RUS',
#   'RUS,CHN',
#   'GBR,BRA',
#   'BRA,BRA',
#   'GER,USA',
#   'USA,GBR',
#   'JPN,UKR',
#   'UKR,GBR',
#   'UKR,USA',
#   'USA,RUS',
#   'GBR,GBR',
#   'GBR,USA',
#   'GRE,BRA',
#   'BRA,RUS',
#   'PRK,RUS',
#   'RUS,JPN',
#   'DEN,FRA',
#   'FRA,GER',
#   'ARG,BEL',
#   'BEL,GER',
#   'FRA,JPN',
#   'JPN,BRA',
#   'JPN,ISR',
#   'RUS,KAZ',
#   'KAZ,JPN',
#   'KAZ,UZB',
#   'ITA,KOR',
#   'KOR,JPN',
#   'KOR,UZB',
#   'JPN,AZE',
#   'AZE,BEL',
#   'AZE,GEO',
#   'RUS,USA',
#   'USA,JPN',
#   'USA,UAE',
#   'JPN,GEO',
#   'GEO,CHN',
#   'GEO,KOR',
#   'CZE,AZE',
#   'AZE,FRA',
#   'AZE,JPN',
#   'NED,GRE',
#   'GRE,FRA',
#   'RUS,UKR',
#   'UKR,MEX',
#   'GBR,AUS',
#   'AUS,ITA',
#   'NZL,RSA',
#   'RSA,ITA',
#   'CRO,LTU',
#   'LTU,NOR',
#   'GBR,GER',
#   'GER,NED',
#   'FRA,IRL',
#   'IRL,NOR',
#   'SUI,DEN',
#   'DEN,FRA',
#   'GER,AUS',
#   'AUS,EST',
#   'NZL,CRO',
#   'CRO,CZE',
#   'FIJ,GBR',
#   'GBR,RSA',
#   'CRO,AUS',
#   'AUS,GRE',
#   'NZL,AUS',
#   'AUS,GER',
#   'GBR,SLO',
#   'SLO,USA',
#   'AUS,CRO',
#   'CRO,NZL',
#   'ARG,AUS',
#   'AUS,AUT',
#   'NED,GBR',
#   'GBR,FRA',
#   'VIE,BRA',
#   'BRA,CHN',
#   'ITA,UKR',
#   'UKR,RUS',
#   'GER,FRA',
#   'FRA,CHN',
#   'KOR,VIE',
#   'VIE,PRK',
#   'ITA,RUS',
#   'RUS,FRA',
#   'GER,KOR',
#   'KOR,RUS',
#   'IOA,ITA',
#   'ITA,GBR',
#   'ITA,SWE',
#   'SWE,IOA',
#   'CRO,ITA',
#   'ITA,GBR',
#   'USA,CHN',
#   'CHN,USA',
#   'GBR,RSA',
#   'RSA,USA',
#   'SGP,HUN',
#   'SGP,RSA',
#   'SGP,USA',
#   'AUS,BEL',
#   'BEL,USA',
#   'ITA,USA',
#   'USA,ITA',
#   'USA,AUS',
#   'AUS,RUS',
#   'KAZ,USA',
#   'USA,RUS',
#   'USA,JPN',
#   'JPN,HUN',
#   'CHN,RSA',
#   'RSA,USA',
#   'USA,JPN',
#   'JPN,CHN',
#   'AUS,CHN',
#   'CHN,ITA',
#   'JPN,USA',
#   'USA,JPN',
#   'USA,FRA',
#   'FRA,AUS',
#   'USA,GBR',
#   'GBR,AUS',
#   'USA,GBR',
#   'GBR,JPN',
#   'USA,FRA',
#   'FRA,USA',
#   'CHN,CHN',
#   'CHN,JPN',
#   'CHN,JPN',
#   'JPN,GER',
#   'AZE,NIG',
#   'NIG,BRA',
#   'NIG,KOR',
#   'CHN,THA',
#   'THA,DOM',
#   'THA,KOR',
#   'JOR,RUS',
#   'RUS,ESP',
#   'RUS,KOR',
#   'CIV,GBR',
#   'GBR,AZE',
#   'GBR,TUN',
#   'ESP,ROU',
#   'ROU,USA',
#   'USA,USA',
#   'USA,CZE',
#   'GBR,ARG',
#   'ARG,JPN',
#   'BLR,CHN',
#   'CHN,CHN',
#   'GBR,GBR',
#   'GBR,RSA',
#   'BRA,ITA',
#   'ITA,USA',
#   'SRB,CRO',
#   'CRO,ITA',
#   'GEO,ARM',
#   'ARM,GEO',
#   'CHN,PRK',
#   'PRK,THA',
#   'UZB,ARM',
#   'ARM,KAZ',
#   'COL,INA',
#   'INA,KAZ',
#   'CHN,TUR',
#   'TUR,COL',
#   'KAZ,CHN',
#   'CHN,EGY',
#   'IRI,CHN',
#   'IRI,BLR',
#   'BLR,LTU',
#   'TUR,IRI',
#   'IRI,BLR',
#   'IRI,GEO',
#   'GEO,JPN',
#   'JPN,AZE',
#   'JPN,IRI',
#   'RUS,AZE',
#   'AZE,ITA',
#   'AZE,UZB',
#   'IRI,RUS',
#   'RUS,AZE',
#   'RUS,TUR',
#   'RUS,TUR',
#   'TUR,AZE',
#   'TUR,USA',
#   'USA,AZE',
#   'AZE,ROU',
#   'AZE,UZB',
#   'CUB,TUR',
#   'TUR,AZE',
#   'TUR,RUS',
#   'CUB,JPN',
#   'JPN,NOR',
#   'JPN,UZB',
#   'SRB,ARM',
#   'ARM,AZE',
#   'ARM,GEO',
#   'RUS,DEN',
#   'DEN,IRI',
#   'DEN,KOR',
#   'RUS,UKR',
#   'UKR,BLR',
#   'UKR,GER',
#   'ARM,CUB',
#   'CUB,IRI',
#   'CUB,TUR',
#   'KOR,GER',
#   'GER,KOR',
#   'KOR,RUS',
#   'RUS,TPE',
#   'ETH,KEN',
#   'KEN,ETH',
#   'JAM,USA',
#   'USA,JAM',
#   'USA,USA',
#   'USA,USA',
#   'KEN,ETH',
#   'ETH,USA',
#   'JAM,NED',
#   'NED,USA',
#   'CHN,MEX',
#   'MEX,CHN',
#   'BRN,KEN',
#   'KEN,USA',
#   'BAH,USA',
#   'USA,JAM',
#   'USA,DEN',
#   'DEN,USA',
#   'USA,JAM',
#   'JAM,GBR',
#   'USA,JAM',
#   'JAM,GBR',
#   'KEN,KEN',
#   'KEN,ETH',
#   'RSA,BDI',
#   'BDI,KEN',
#   'CRO,FRA',
#   'FRA,CUB',
#   'POL,CHN',
#   'CHN,GBR',
#   'BEL,GBR',
#   'GBR,CAN',
#   'ESP,BUL',
#   'BUL,CRO',
#   'CRO,RSA',
#   'RSA,CZE',
#   'USA,USA',
#   'USA,SRB',
#   'KEN,BRN',
#   'BRN,ETH',
#   'GRE,USA',
#   'USA,NZL',
#   'USA,NZL',
#   'NZL,HUN',
#   'COL,VEN',
#   'VEN,KAZ',
#   'JPN,DEN',
#   'JPN,MAS',
#   'INA,DEN',
#   'INA,MAS',
#   'DEN,KOR',
#   'DEN,CHN',
#   'MAS,KOR',
#   'MAS,CHN',
#   'ESP,IND',
#   'IND,JPN',
#   'USA,ESP',
#   'ESP,SRB',
#   'GER,BRA',
#   'BRA,USA',
#   'GBR,FRA',
#   'FRA,CHN',
#   'FRA,COL',
#   'FRA,CHN',
#   'CHN,FIN',
#   'CHN,RUS',
#   'USA,NED',
#   'NED,CHN',
#   'NED,KAZ',
#   'ESP,NZL',
#   'NZL,AUS',
#   'NZL,POL',
#   'POL,AZE',
#   'HUN,DEN',
#   'DEN,NZL',
#   'HUN,GER',
#   'GER,POL',
#   'HUN,GER',
#   'GER,BLR',
#   'COL,USA',
#   'USA,VEN',
#   'SWE,POL',
#   'POL,CAN',
#   'NED,SWE',
#   'SWE,ITA',
#   'USA,RUS',
#   'RUS,NED',
#   'NED,GBR',
#   'GBR,AUS',
#   'GBR,USA',
#   'USA,BEL',
#   'GBR,USA',
#   'USA,CAN',
#   'CHN,RUS',
#   'RUS,GER',
#   'GER,GBR',
#   'GBR,GBR',
#   'CHN,CHN',
#   'CHN,CAN',
#   'CHN,CHN',
#   'CHN,ITA',
#   'CHN,MAS',
#   'MAS,CAN',
#   'CHN,ITA',
#   'ITA,AUS',
#   'GBR,GER',
#   'GER,GER',
#   'GER,GBR',
#   'GBR,USA',
#   'FRA,USA',
#   'USA,GER',
#   'RUS,ITA',
#   'ITA,TUN',
#   'RUS,RUS',
#   'RUS,UKR',
#   'RUS,UKR',
#   'UKR,USA',
#   'HUN,ITA',
#   'ITA,CHN',
#   'ROU,CHN',
#   'CHN,RUS',
#   'GER,SWE',
#   'SWE,CAN',
#   'KOR,NZL',
#   'NZL,CHN',
#   'USA,RUS',
#   'RUS,CHN',
#   'NED,USA',
#   'USA,USA',
#   'USA,USA',
#   'USA,GBR',
#   'USA,USA',
#   'USA,RUS',
#   'RUS,USA',
#   'USA,GER',
#   'USA,RUS',
#   'RUS,SUI',
#   'RUS,ESP',
#   'ESP,BUL',
#   'RUS,RUS',
#   'RUS,UKR',
#   'RUS,FRA',
#   'FRA,NOR',
#   'GBR,NED',
#   'NED,GER',
#   'FRA,CUB',
#   'CUB,CHN',
#   'CUB,JPN',
#   'ARG,KOR',
#   'KOR,JPN',
#   'KOR,KAZ',
#   'KOS,ITA',
#   'ITA,JPN',
#   'ITA,RUS',
#   'BRA,MGL',
#   'MGL,JPN',
#   'MGL,POR',
#   'SLO,FRA',
#   'FRA,ISR',
#   'FRA,NED',
#   'JPN,COL',
#   'COL,GBR',
#   'COL,GER',
#   'USA,FRA',
#   'FRA,BRA',
#   'FRA,SLO',
#   'NED,ITA',
#   'ITA,BRA',
#   'AUS,FRA',
#   'FRA,POL',
#   'GBR,NZL',
#   'NZL,DEN',
#   'POL,GBR',
#   'GBR,LTU',
#   'USA,GBR',
#   'GBR,ROU',
#   'NED,CAN',
#   'CAN,CHN',
#   'GER,NED',
#   'NED,POL',
#   'AUS,USA',
#   'USA,CHN',
#   'AUS,NZL',
#   'NZL,CAN',
#   'GBR,NZL',
#   'NZL,FRA',
#   'BRA,NZL',
#   'NZL,DEN',
#   'NED,IRL',
#   'IRL,DEN',
#   'ARG,AUS',
#   'AUS,AUT',
#   'FRA,CHN',
#   'CHN,RUS',
#   'CHN,RUS',
#   'RUS,GRE',
#   'USA,CHN',
#   'CHN,CHN',
#   'GRE,GER',
#   'GER,SUI',
#   'GER,CHN',
#   'CHN,CHN',
#   'ITA,ITA',
#   'ITA,USA',
#   'AUS,NZL',
#   'NZL,USA',
#   'HUN,USA',
#   'USA,CAN',
#   'USA,CHN',
#   'USA,RUS',
#   'RUS,USA',
#   'SWE,CAN',
#   'CAN,USA',
#   'USA,HUN',
#   'HUN,CAN',
#   'JPN,RUS',
#   'RUS,CHN',
#   'ESP,AUS',
#   'AUS,JPN',
#   'USA,SWE',
#   'SWE,AUS',
#   'HUN,GBR',
#   'GBR,USA',
#   'USA,GBR',
#   'GBR,USA',
#   'HUN,USA',
#   'USA,ESP',
#   'AUS,USA',
#   'USA,CAN',
#   'USA,AUS',
#   'AUS,DEN',
#   'USA,AUS',
#   'AUS,CAN',
#   'DEN,USA',
#   'USA,BLR',
#   'USA,GBR',
#   'GBR,HUN',
#   'RUS,CHN',
#   'CHN,JPN',
#   'RUS,CHN',
#   'CHN,JPN',
#   'CHN,CHN',
#   'CHN,PRK',
#   'CHN,GER',
#   'GER,JPN',
#   'CHN,MEX',
#   'MEX,GBR',
#   'MEX,USA',
#   'KOR,SRB',
#   'SRB,AZE',
#   'SRB,THA',
#   'GBR,ESP',
#   'ESP,EGY',
#   'ESP,IRI',
#   'KOR,FRA',
#   'FRA,CIV',
#   'FRA,TUR',
#   'RUS,SUI',
#   'SUI,CZE',
#   'USA,USA',
#   'USA,CZE',
#   'PUR,GER',
#   'GER,CZE',
#   'CAN,GBR',
#   'GBR,CHN',
#   'USA,SUI',
#   'SUI,GBR',
#   'CHN,SRB',
#   'SRB,USA',
#   'USA,ITA',
#   'ITA,RUS',
#   'CHN,PRK',
#   'PRK,USA',
#   'THA,INA',
#   'INA,JPN',
#   'TPE,PHI',
#   'PHI,KOR',
#   'THA,THA',
#   'THA,TPE',
#   'CHN,PRK',
#   'PRK,KAZ',
#   'CHN,KAZ',
#   'KAZ,EGY',
#   'PRK,BLR',
#   'BLR,ESP',
#   'JPN,AZE',
#   'AZE,BUL',
#   'AZE,CHN',
#   'USA,JPN',
#   'JPN,AZE',
#   'JPN,RUS',
#   'RUS,IND',
#   'RUS,TUN',
#   'JPN,BLR',
#   'BLR,KAZ',
#   'BLR,POL',
#   'JPN,RUS',
#   'RUS,KAZ',
#   'RUS,SWE',
#   'CAN,KAZ',
#   'KAZ,CHN',
#   'KAZ,RUS'],
#  ['SUI,AUT',
#   'AUT,NOR',
#   'ITA,NOR',
#   'NOR,USA',
#   'USA,NOR',
#   'NOR,ITA',
#   'SWE,SUI',
#   'SUI,AUT',
#   'SUI,USA',
#   'USA,SUI',
#   'CZE,AUT',
#   'AUT,LIE',
#   'GER,SVK',
#   'SVK,FRA',
#   'SVK,BLR',
#   'BLR,NOR',
#   'SWE,SVK',
#   'SVK,GER',
#   'BLR,SWE',
#   'SWE,FRA',
#   'GER,NOR',
#   'NOR,CZE',
#   'FRA,NOR',
#   'NOR,ITA',
#   'GER,USA',
#   'USA,CAN',
#   'NOR,SWE',
#   'SWE,NOR',
#   'SWE,FIN',
#   'NOR,FIN',
#   'FIN,SWE',
#   'SWE,NOR',
#   'NOR,FIN',
#   'NOR,SWE',
#   'SWE,OAR',
#   'USA,SWE',
#   'SWE,NOR',
#   'SWE,NOR',
#   'NOR,OAR',
#   'CAN,SUI',
#   'SUI,NOR',
#   'SWE,KOR',
#   'KOR,JPN',
#   'CAN,FRA',
#   'FRA,USA',
#   'OAR,OAR',
#   'OAR,CAN',
#   'GER,CHN',
#   'CHN,CAN',
#   'CAN,OAR',
#   'OAR,USA',
#   'BLR,CHN',
#   'CHN,CHN',
#   'FRA,CAN',
#   'CAN,KAZ',
#   'CAN,CAN',
#   'CAN,SUI',
#   'CAN,FRA',
#   'FRA,USA',
#   'SUI,SUI',
#   'SUI,GBR',
#   'USA,CAN',
#   'CAN,FIN',
#   'GER,CAN',
#   'CAN,AUT',
#   'GER,GER',
#   'GER,CAN',
#   'NED,CAN',
#   'CAN,ITA',
#   'KOR,CHN',
#   'CHN,CAN',
#   'KOR,ITA',
#   'ITA,NED',
#   'ITA,NED',
#   'NED,CAN',
#   'GBR,GER',
#   'GER,GBR',
#   'NOR,GER',
#   'GER,JPN',
#   'AUT,USA',
#   'USA,NZL',
#   'CZE,GER',
#   'GER,GER',
#   'USA,CHN',
#   'CHN,USA',
#   'USA,CAN',
#   'CAN,FIN',
#   'ITA,FRA',
#   'FRA,CZE',
#   'NED,JPN',
#   'JPN,JPN',
#   'NED,JPN',
#   'JPN,NED',
#   'NED,NED',
#   'NED,NED',
#   'NED,CZE',
#   'CZE,OAR',
#   'JPN,KOR',
#   'KOR,CZE',
#   'JPN,KOR',
#   'KOR,NED',
#   'JPN,NED',
#   'NED,USA',
#   'SUI,AUT',
#   'AUT,NOR',
#   'NOR,NOR',
#   'NOR,SUI',
#   'AUT,NOR',
#   'NOR,FRA',
#   'SWE,SUI',
#   'SUI,AUT',
#   'AUT,FRA',
#   'FRA,FRA',
#   'AUT,SUI',
#   'SUI,NOR',
#   'GER,CZE',
#   'CZE,ITA',
#   'FRA,SWE',
#   'SWE,GER',
#   'FRA,GER',
#   'GER,NOR',
#   'NOR,SLO',
#   'SLO,AUT',
#   'SWE,NOR',
#   'NOR,GER',
#   'FRA,NOR',
#   'NOR,ITA',
#   'GER,GER',
#   'GER,KOR',
#   'SUI,NOR',
#   'NOR,OAR',
#   'FIN,OAR',
#   'OAR,OAR',
#   'NOR,NOR',
#   'NOR,NOR',
#   'NOR,OAR',
#   'OAR,FRA',
#   'NOR,ITA',
#   'ITA,OAR',
#   'NOR,OAR',
#   'OAR,FRA',
#   'CAN,SUI',
#   'SUI,NOR',
#   'USA,SWE',
#   'SWE,SUI',
#   'CAN,FRA',
#   'FRA,USA',
#   'JPN,JPN',
#   'JPN,ESP',
#   'GER,CHN',
#   'CHN,CAN',
#   'CAN,OAR',
#   'OAR,USA',
#   'UKR,CHN',
#   'CHN,OAR',
#   'CAN,AUS',
#   'AUS,JPN',
#   'CAN,SUI',
#   'SUI,OAR',
#   'USA,USA',
#   'USA,NZL',
#   'NOR,USA',
#   'USA,CAN',
#   'OAR,GER',
#   'GER,CAN',
#   'GER,AUT',
#   'AUT,GER',
#   'GER,CAN',
#   'CAN,AUT',
#   'AUT,USA',
#   'USA,GER',
#   'GER,GER',
#   'GER,GER',
#   'GER,JPN',
#   'JPN,AUT',
#   'GER,NOR',
#   'NOR,AUT',
#   'CAN,USA',
#   'USA,KOR',
#   'KOR,NED',
#   'NED,OAR',
#   'HUN,CHN',
#   'CHN,CAN',
#   'CHN,KOR',
#   'KOR,KOR',
#   'KOR,OAR',
#   'OAR,GBR',
#   'POL,GER',
#   'GER,NOR',
#   'GER,NOR',
#   'NOR,NOR',
#   'NOR,GER',
#   'GER,POL',
#   'CAN,USA',
#   'USA,GBR',
#   'SUI,KOR',
#   'KOR,SLO',
#   'USA,JPN',
#   'JPN,AUS',
#   'USA,CAN',
#   'CAN,CAN',
#   'FRA,AUS',
#   'AUS,ESP',
#   'CAN,NED',
#   'NED,ITA',
#   'NED,NOR',
#   'NOR,KOR',
#   'NED,NED',
#   'NED,KOR',
#   'NED,CAN',
#   'CAN,NOR',
#   'NOR,KOR',
#   'KOR,CHN',
#   'KOR,BEL',
#   'BEL,NED',
#   'NOR,KOR',
#   'KOR,NED']]

# %% [markdown]
# # List containing info on Games
# The list i create below can be used to get information on olympics in the relationList. The indexes for both lists will reference the same olympics so we can match the relationships of an olympics to any other infomration on that olympics.

# %%
# If we need the host city, year or anything of an olympics we can just call an index with .iloc[]
# and call the same index on relationList and we'll match the same relationships to whatever info we want. 
gameInfoDf =  df.drop_duplicates(subset=['Year', 'Host_City'], keep='first').reset_index()
# dropping the old index column
gameInfoDf = gameInfoDf.drop(gameInfoDf.columns[[0]], axis=1)

# %%
gameInfoDf.head(5)
# Out:
#    Year     Host_City  Summer  Winter     Discipline     Event Gender  NOC  \
# 0  1960          Rome    True   False      Athletics    10000m    Men  AUS
# 1  1960  Squaw Valley   False    True  Alpine Skiing  downhill      F  AUT
# 2  1964         Tokyo    True   False      Athletics    10000m    Men  AUS
# 3  1964     Innsbruck   False    True  Alpine Skiing  downhill      F  AUT
# 4  1968        Mexico    True   False      Athletics    10000m    Men  TUN
#
#     Medal
# 0  Bronze
# 1  Bronze
# 2  Bronze
# 3  Bronze
# 4  Bronze

# %% [markdown]
# # Creating the csvs for GEPHI
# First we'll create a function to produce a node csv and edges csv for a given olympics. You'll reference which olympics you want by index which pertains to gameInfoDf above.

# %%
relation = relationList[0]

# %%
# this is a function to get the csvs for the nodes and relationships of a given games 
# the number you must enter is the index of the olympics in the relation list and gamesinfoDf

def getNetworkCSVs(gNum):
    #creating two lists the source is one of the NOCs in  a relationsip and the target is the other
    source = []
    target = []

    # this for loop seperates the relationsips and puts one NOc in each column source and target
    for i in relation:
        source.append(i.split(',')[0])
        target.append(i.split(',')[1])

    # create a df for these lists and equate the lists to the columns 
    dfRel = pd.DataFrame(columns=['Source', 'Target'])
    dfRel['Source'] = source
    dfRel['Target'] = target


    # setting a varaible for whether the gmaes is summer or winter 
    if(gameInfoDf['Summer'].iloc[gNum]):
        gamesType = 'Summer'
    else:
        gamesType = 'Winter'

    edgepath = r"..\..\data\analysis\Competitive_Networks\{}".format(str(gameInfoDf['Year'].iloc[gNum])+ '_' + str(gameInfoDf['Host_City'].iloc[gNum]) + '_' + gamesType)
    if not os.path.exists(edgepath):
        os.makedirs(edgepath)



    edgepath = edgepath + '\{}'
    edgepath = edgepath.format('edges.csv')

    dfRel.to_csv(edgepath, index=False)

# %% [markdown]
# Now we can create a for loop to create all of the required csvs to create networks of all the games

# %%
for i in range(len(gameInfoDf)):
    getNetworkCSVs(i)

# %% [markdown]
# # Network Analysis of Summer and winter games as a whole
# Now that we have csvs for the nodes and edges of every olympics from 1960 we can do a more general analysis of the summer and winter games as a whole. So we can get all the relationships from summer and winter and create a big network. To do this we'll use the relationList and the gamesInfoDf so we'll know whether a games is summer or winter. We'' have the same process for getting the nodes for the summer and winter games.

# %%
# We'll have two lists one for the summer games relationships and one for the winter gmaes relationsips 
summerRels = []
winterRels = []

# %%
# The for  loop just checks to see if the current games is winter or summer
# Seeing as all the lists below have each olympics at the same index making things quite easy
for x in range(len(relationList)):
    
    if(gameInfoDf['Summer'].iloc[x]):
        summerRels.append(relationList[x])
    else:
        winterRels.append(relationList[x])

# %% [markdown]
# Now that we have all the olympics lists split into summer and winter we can just breakdown the indivdual lists and form four big lists two for the winter nodes and edges and two for the summer nodes and edges.

# %%
# the final list summer olympic games relationships 
summerEdges = []

# %%
for x in range(len(summerRels)):
    
    for y in range(len(summerRels[x])):
        summerEdges.append(summerRels[x][y])

# %%
# the final list winter olympic games relationships 
winterEdges = []

# %%
for x in range(len(winterRels)):
    
    for y in range(len(winterRels[x])):
        winterEdges.append(winterRels[x][y])

# %% [markdown]
# # Creating the dataFrames for the summer and winter edges and nodes
# Like we did in the networks for all the individual olympics we must change the lists for nodes and edges to datafrmaes so they can be represented in the right formatt for Gehpi.

# %%
# Summer games first  
#creating two lists the source is one of the NOCs in  a relationsip and the target is the other
source = []
target = []

# this for loop seperates the relationsips and puts one NOc in each column source and target
for i in summerEdges:
    source.append(i.split(',')[0])
    target.append(i.split(',')[1])

# create a df for these lists and equate the lists to the columns 
sumEdgesdf = pd.DataFrame(columns=['Source', 'Target'])
sumEdgesdf['Source'] = source
sumEdgesdf['Target'] = target

# Creating the Summer network folder
sumpath = r"..\..\data\analysis\\Summer_Games_Competitive_Network"
if not os.path.exists(sumpath):
    os.makedirs(sumpath)

    
# creating the csvs for the dataframes    
sumEdgesdf.to_csv(r"..\..\data\analysis\Summer_Games_Competitive_Network\SummerEdges.csv", index=False)

# %%
# Winter games  
#creating two lists the source is one of the NOCs in a relationsip and the target is the other
source = []
target = []

# this for loop seperates the relationsips and puts one NOc in each column source and target
for i in winterEdges:
    source.append(i.split(',')[0])
    target.append(i.split(',')[1])

# create a df for these lists and equate the lists to the columns 
winEdgesdf = pd.DataFrame(columns=['Source', 'Target'])
winEdgesdf['Source'] = source
winEdgesdf['Target'] = target

# Creating the Summer network folder
winpath = r"..\..\data\analysis\\Winter_Competitive_Games_Network"
if not os.path.exists(winpath):
    os.makedirs(winpath)

    
# creating the csvs for the dataframes    
winEdgesdf.to_csv(r"..\..\data\analysis\\Winter_Competitive_Games_Network\WinterEdges.csv", index=False)
