# %% [markdown]
# # Network Analysis of Competitiveness Nocs

# %%
import os.path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
# %matplotlib inline
from bs4 import BeautifulSoup
import webbrowser
import urllib.request
from lxml import html
import zipfile
import re
import string
import sys, os
from IPython.display import Image
import itertools

# %% [markdown]
# # Create Dictionary for NOC codes and Country Names

# %%
filepath = '../../data/analysis/complete_data.csv'

# %%
if not os.path.exists( filepath ):
    print("Missing dataset file")
else:
    dicdf = pd.read_csv(filepath , encoding = "ISO-8859-1")
    print("File Read")
# Out:
# File Read

# %%
dicdf = dicdf.groupby('NOC')[['Country','Region']].last()
dicdf.head()
# Out:
#          Country                 Region
# NOC
# AFG  Afghanistan  West and Central Asia
# AHO          NaN                    NaN
# ALG      Algeria           North Africa
# ARG    Argentina          South America
# ARM      Armenia  West and Central Asia

# %%
indexs = dicdf[dicdf.Country.isnull()].index
for i in indexs:
    dicdf.loc[i,'Country'] = 'Unknown Nation'
    dicdf.loc[i,'Region'] = 'Unknown Region'
len(dicdf[dicdf.Region.isnull()])
# Out:
# 0

# %% [markdown]
# # Summer

# %%
filepath = r"..\..\data\analysis\Summer_Games_Competitive_Network\SummerEdges.csv"

# %%
if not os.path.exists( filepath ):
    print("Missing dataset file")
else:
    df = pd.read_csv(filepath , encoding = "ISO-8859-1")
    print("File Read")
# Out:
# File Read

# %%
df.head()
# Out:
#   Source Target
# 0    URS    EUA
# 1    EUA    AUS
# 2    EUA    USA
# 3    USA    GBR
# 4    USA    USA

# %% [markdown]
# To deal with the period of time where Germany was split we amalgamated ther two halves of the country and used the NOC code GERS to represent them, this makes the GDR and FRG codes defunct.
# The EUN NOC code also causes an issue as to differenciate between the two Unified teams sent to the summer and winter olympics that year we used EUNS for the summer team and EUNW for the Winter

# %%
def replaceCodes(x):
    if x == 'FRG':
        return 'GERS'
    elif x == 'GDR':
        return 'GERS'
    elif x == 'EUN':
        return 'EUNS'
    else:
        return x

# %%
df = df.applymap(lambda x: replaceCodes(x))
df.head()
# Out:
#   Source Target
# 0    URS    EUA
# 1    EUA    AUS
# 2    EUA    USA
# 3    USA    GBR
# 4    USA    USA

# %% [markdown]
# To make the network more user friendly we replace the NOC codes for the countries Names

# %%
def getName(x):
    try:
        country = dicdf.loc[x].Country
    except:
        print("Error - "+str(x))
        country = x
    return country

# %%
df = df.applymap(lambda x: getName(x))
df.head()
# Out:
#                    Source                  Target
# 0            Soviet Union  United Team of Germany
# 1  United Team of Germany               Australia
# 2  United Team of Germany           United States
# 3           United States          United Kingdom
# 4           United States           United States

# %% [markdown]
# ## Top Competitors
# Evaluates the top 5 (if available) opponents for each country

# %%
new_df = pd.DataFrame(columns=['Country','Occurances','Number_Competitors','Competitor1','Competitor2','Competitor3','Competitor4','Competitor5'])
new_df.head()
# Out:
# Empty DataFrame
# Columns: [Country, Occurances, Number_Competitors, Competitor1, Competitor2, Competitor3, Competitor4, Competitor5]
# Index: []

# %% [markdown]
# Counting Number of Occurances of each value in the Source column

# %%
counts = df.Source.value_counts()
for i in counts.index:
    occ = counts[i]
    country = i
    new_df.loc[len(new_df)] = [country,occ,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan]
new_df.head()
# Out:
#            Country Occurances Number_Competitors Competitor1 Competitor2  \
# 0    United States       1064                NaN         NaN         NaN
# 1     Soviet Union        607                NaN         NaN         NaN
# 2            China        415                NaN         NaN         NaN
# 3  Germany (Split)        413                NaN         NaN         NaN
# 4   United Kingdom        298                NaN         NaN         NaN
#
#   Competitor3 Competitor4 Competitor5
# 0         NaN         NaN         NaN
# 1         NaN         NaN         NaN
# 2         NaN         NaN         NaN
# 3         NaN         NaN         NaN
# 4         NaN         NaN         NaN

# %%
new_df = new_df.set_index('Country')
for country in df.Source.unique():
    temp = df[df.Source == country]
    new_df.loc[country,'Number_Competitors'] = len(temp.Target.value_counts().index)
    if len(temp.Target.value_counts().index) < 5:
         for i in range(len(temp.Target.value_counts().index)):
            col = 'Competitor'+str(i+1)
            comp = temp.Target.value_counts().index[i]
            new_df.loc[country,col] = comp
        
    
    else: 
        for i in range(5):
            col = 'Competitor'+str(i+1)
            comp = temp.Target.value_counts().index[i]
            ##test
            new_df.loc[country,col] = comp
new_df.head()
# Out:
#                 Occurances Number_Competitors      Competitor1  \
# Country
# United States         1064                 79    United States
# Soviet Union           607                 48     Soviet Union
# China                  415                 60            China
# Germany (Split)        413                 36  Germany (Split)
# United Kingdom         298                 54    United States
#
#                         Competitor2      Competitor3     Competitor4  \
# Country
# United States             Australia  Germany (Split)  United Kingdom
# Soviet Union        Germany (Split)          Hungary   United States
# China            Russian Federation    United States     Korea, Rep.
# Germany (Split)        Soviet Union    United States        Bulgaria
# United Kingdom            Australia           France    Soviet Union
#
#                      Competitor5
# Country
# United States       Soviet Union
# Soviet Union            Bulgaria
# China                      Japan
# Germany (Split)   United Kingdom
# United Kingdom   Germany (Split)

# %% [markdown]
# # Region
# Dataframe will hold each country and the number of competitions it has, along with the percentage of these competitions it has with countries from every other region

# %% [markdown]
# Creates datafram with appropriate columns

# %%
columns = ['Country','Region','Occurances']+dicdf.Region.unique().tolist()
region_df = pd.DataFrame(columns=columns)
region_df
# Out:
# Empty DataFrame
# Columns: [Country, Region, Occurances, West and Central Asia, Unknown Region, North Africa, South America, Oceania, Europe, Caribbean Islands, Sub-Saharan Africa, North Asia, Brtitsh West Indies, North America, East Asia, Central America, South and Southeast Asia]
# Index: []

# %% [markdown]
# Initially fills the dataframe with the names and number out degree (i.e. the number of times a country competes with others) of each country within the dataframe

# %%
counts = df.Source.value_counts()
for i in counts.index:
    occ = counts[i]
    country = i
    reg = dicdf.set_index('Country').loc[country].Region
    if country == "Unified Team":
        reg = 'North Asia'
    if country == 'Unknown Nation':
        reg = 'Unknown Region'
    region_df.loc[len(region_df)] = [country,reg,occ,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan]
region_df.head()
# Out:
#            Country         Region Occurances West and Central Asia  \
# 0    United States  North America       1064                   NaN
# 1     Soviet Union     North Asia        607                   NaN
# 2            China      East Asia        415                   NaN
# 3  Germany (Split)         Europe        413                   NaN
# 4   United Kingdom         Europe        298                   NaN
#
#   Unknown Region North Africa South America Oceania Europe Caribbean Islands  \
# 0            NaN          NaN           NaN     NaN    NaN               NaN
# 1            NaN          NaN           NaN     NaN    NaN               NaN
# 2            NaN          NaN           NaN     NaN    NaN               NaN
# 3            NaN          NaN           NaN     NaN    NaN               NaN
# 4            NaN          NaN           NaN     NaN    NaN               NaN
#
#   Sub-Saharan Africa North Asia Brtitsh West Indies North America East Asia  \
# 0                NaN        NaN                 NaN           NaN       NaN
# 1                NaN        NaN                 NaN           NaN       NaN
# 2                NaN        NaN                 NaN           NaN       NaN
# 3                NaN        NaN                 NaN           NaN       NaN
# 4                NaN        NaN                 NaN           NaN       NaN
#
#   Central America South and Southeast Asia
# 0             NaN                      NaN
# 1             NaN                      NaN
# 2             NaN                      NaN
# 3             NaN                      NaN
# 4             NaN                      NaN

# %%
def convertToRegion(country):
    reg = dicdf.set_index('Country').loc[country].Region
    if country == "Unified Team":
        reg = 'North Asia'
    if country == 'Unknown Nation':
        reg = 'Unknown Region'
    return reg

# %%
df_withRegion = df.copy()
df_withRegion.Target = df_withRegion.Target.apply(convertToRegion)
df_withRegion.head()
# Out:
#                    Source         Target
# 0            Soviet Union         Europe
# 1  United Team of Germany        Oceania
# 2  United Team of Germany  North America
# 3           United States         Europe
# 4           United States  North America

# %%
region_df = region_df.set_index('Country')

for country in region_df.index:
    temp = df_withRegion[df_withRegion.Source == country]
    vals = temp.Target.value_counts()
    tot = region_df.loc[country].Occurances
    for i in vals.index:
        x = vals[i]*100
        x /= tot
        region_df.loc[country,i] = x
region_df = region_df.reset_index()
region_df.head()
# Out:
#            Country         Region Occurances West and Central Asia  \
# 0    United States  North America       1064               1.40977
# 1     Soviet Union     North Asia        607              0.658979
# 2            China      East Asia        415               1.68675
# 3  Germany (Split)         Europe        413              0.242131
# 4   United Kingdom         Europe        298               1.34228
#
#   Unknown Region North Africa South America  Oceania   Europe  \
# 0            NaN      0.56391       2.63158  8.08271  36.4662
# 1            NaN     0.329489        1.4827  2.30643  62.1087
# 2            NaN     0.481928       1.20482  2.89157  25.5422
# 3            NaN          NaN       1.45278   3.1477  54.2373
# 4            NaN     0.671141       3.69128  10.4027  44.2953
#
#   Caribbean Islands Sub-Saharan Africa North Asia Brtitsh West Indies  \
# 0           5.26316            2.16165    10.5263                 NaN
# 1            1.4827           0.658979    15.6507                 NaN
# 2           2.16867           0.963855    14.9398                 NaN
# 3           1.21065           0.242131    19.8547                 NaN
# 4           3.69128            3.02013    11.0738                 NaN
#
#   North America East Asia Central America South and Southeast Asia
# 0       23.0263   9.21053         0.37594                 0.281955
# 1       7.24876   6.75453        0.988468                 0.329489
# 2       10.1205   32.5301         2.16867                   5.3012
# 3       15.2542   3.38983        0.968523                      NaN
# 4       15.4362   6.04027             NaN                  0.33557

# %%
region_df.isnull().sum()
# Out:
# Country                       0
# Region                        0
# Occurances                    0
# West and Central Asia        71
# Unknown Region              123
# North Africa                 99
# South America                86
# Oceania                      77
# Europe                       28
# Caribbean Islands            70
# Sub-Saharan Africa           73
# North Asia                   56
# Brtitsh West Indies         126
# North America                46
# East Asia                    51
# Central America             107
# South and Southeast Asia     99
# dtype: int64

# %% [markdown]
# Replace the null values with 0

# %%
cols = df_withRegion.Target.unique().tolist()
region_df[cols] = region_df[cols].fillna(0)
region_df.head()
# Out:
#            Country         Region Occurances  West and Central Asia  \
# 0    United States  North America       1064               1.409774
# 1     Soviet Union     North Asia        607               0.658979
# 2            China      East Asia        415               1.686747
# 3  Germany (Split)         Europe        413               0.242131
# 4   United Kingdom         Europe        298               1.342282
#
#    Unknown Region  North Africa  South America    Oceania     Europe  \
# 0             0.0      0.563910       2.631579   8.082707  36.466165
# 1             0.0      0.329489       1.482702   2.306425  62.108731
# 2             0.0      0.481928       1.204819   2.891566  25.542169
# 3             0.0      0.000000       1.452785   3.147700  54.237288
# 4             0.0      0.671141       3.691275  10.402685  44.295302
#
#    Caribbean Islands  Sub-Saharan Africa  North Asia  Brtitsh West Indies  \
# 0           5.263158            2.161654   10.526316                  0.0
# 1           1.482702            0.658979   15.650741                  0.0
# 2           2.168675            0.963855   14.939759                  0.0
# 3           1.210654            0.242131   19.854722                  0.0
# 4           3.691275            3.020134   11.073826                  0.0
#
#    North America  East Asia  Central America  South and Southeast Asia
# 0      23.026316   9.210526         0.375940                  0.281955
# 1       7.248764   6.754530         0.988468                  0.329489
# 2      10.120482  32.530120         2.168675                  5.301205
# 3      15.254237   3.389831         0.968523                  0.000000
# 4      15.436242   6.040268         0.000000                  0.335570

# %% [markdown]
# ## Percentage of competion on average that countries have with other nations in their own region

# %%
def percentSameRegion(x):
    reg1 = x.Region 
    val = x[reg1]
    return val

# %%
str(region_df.apply(percentSameRegion,axis=1).mean())+'%'
# Out:
# '25.79594427414235%'

# %%
region_df[region_df.Region == 'Unknown Region']
# Out:
#            Country          Region Occurances  West and Central Asia  \
# 86  Unknown Nation  Unknown Region          4                    0.0
#
#     Unknown Region  North Africa  South America  Oceania  Europe  \
# 86             0.0           0.0            0.0      0.0    75.0
#
#     Caribbean Islands  Sub-Saharan Africa  North Asia  Brtitsh West Indies  \
# 86                0.0                 0.0         0.0                  0.0
#
#     North America  East Asia  Central America  South and Southeast Asia
# 86           25.0        0.0              0.0                       0.0

# %% [markdown]
# ## In General Competion with other nations

# %%
grouped_region = region_df.groupby('Region')[df_withRegion.Target.unique().tolist()].mean()
grouped_region = grouped_region[grouped_region.index]
grouped_region.head()
# Out:
#                    Caribbean Islands  Central America  East Asia     Europe  \
# Region
# Caribbean Islands          20.343176         1.635599  10.681260  23.479532
# Central America             1.515152         1.515152  27.272727  32.575758
# East Asia                   5.717825         1.696622  20.113135  31.985197
# Europe                      1.798358         0.474356   6.026680  57.428041
# North Africa                2.500000         0.000000   2.500000  35.151515
#
#                    North Africa  North America  North Asia    Oceania  \
# Region
# Caribbean Islands      0.333516      20.663638    3.682383   0.219298
# Central America        0.757576       6.060606    3.787879   0.000000
# East Asia              0.523981       8.135121   10.481172   8.356772
# Europe                 0.455148       9.923451   12.114247   5.108578
# North Africa           5.000000       7.272727    2.500000  13.106061
#
#                    South America  South and Southeast Asia  \
# Region
# Caribbean Islands       1.858814                  4.084430
# Central America         1.515152                  0.000000
# East Asia               1.274566                  7.384968
# Europe                  1.144284                  0.481675
# North Africa            0.000000                  0.000000
#
#                    Sub-Saharan Africa  Unknown Region  West and Central Asia
# Region
# Caribbean Islands            3.199013        0.000000               9.819340
# Central America             25.000000        0.000000               0.000000
# East Asia                    0.265016        0.000000               4.065624
# Europe                       1.814120        0.144676               2.947866
# North Africa                22.196970        0.000000               9.772727

# %%
def highlight_max(s):
    '''
    highlight the maximum in a Series yellow.
    '''
    is_max = s == s.max()
    return ['background-color: orange' if v else '' for v in is_max]

# %%
grouped_region.style.apply(highlight_max)
# Out:
# <style  type="text/css" >
#     #T_01f97bf0_42e8_11e8_b09a_34f64b4d1556row0_col0 {
#             background-color:  orange;
#         }    #T_01f97bf0_42e8_11e8_b09a_34f64b4d1556row2_col1 {
#             background-color:  orange;
#         }    #T_01f97bf0_42e8_11e8_b09a_34f64b4d1556row4_col4 {
#             background-color:  orange;
#         }    #T_01f97bf0_42e8_11e8_b09a_34f64b4d1556row7_col10 {
#             background-color:  orange;
#         }    #T_01f97bf0_42e8_11e8_b09a_34f64b4d1556row7_col11 {
#             background-color:  orange;
#         }    #T_01f97bf0_42e8_11e8_b09a_34f64b4d1556row8_col7 {
#             background-color:  orange;
#         }    #T_01f97bf0_42e8_11e8_b09a_34f64b4d1556row9_col2 {
#             background-color:  orange;
#         }    #T_01f97bf0_42e8_11e8_b09a_34f64b4d1556row9_col9 {
#             background-color:  orange;
#         }    #T_01f97bf0_42e8_11e8_b09a_34f64b4d1556row9_col12 {
#             background-color:  orange;
#         }    #T_01f97bf0_42e8_11e8_b09a_34f64b4d1556row10_col8 {
#             background-color:  orange;
#         }    #T_01f97bf0_42e8_11e8_b09a_34f64b4d1556row11_col3 {
#             background-color:  orange;
#         }    #T_01f97bf0_42e8_11e8_b09a_34f64b4d1556row11_col5 {
#             background-color:  orange;
#         }    #T_01f97bf0_42e8_11e8_b09a_34f64b4d1556row12_col6 {
#             background-color:  orange;
#         }</style>
# <table id="T_01f97bf0_42e8_11e8_b09a_34f64b4d1556" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Caribbean Islands</th>
#         <th class="col_heading level0 col1" >Central America</th>
#         <th class="col_heading level0 col2" >East Asia</th>
#         <th class="col_heading level0 col3" >Europe</th>
#         <th class="col_heading level0 col4" >North Africa</th>
#         <th class="col_heading level0 col5" >North America</th>
#         <th class="col_heading level0 col6" >North Asia</th>
#         <th class="col_heading level0 col7" >Oceania</th>
#         <th class="col_heading level0 col8" >South America</th>
#         <th class="col_heading level0 col9" >South and Southeast Asia</th>
#         <th class="col_heading level0 col10" >Sub-Saharan Africa</th>
#         <th class="col_heading level0 col11" >Unknown Region</th>
#         <th class="col_heading level0 col12" >West and Central Asia</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Region</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_01f97bf0_42e8_11e8_b09a_34f64b4d1556level0_row0" class="row_heading level0 row0" >Caribbean Islands</th>
#         <td id="T_01f97bf0_42e8_11e8_b09a_34f64b4d1556row0_col0" class="data row0 col0" >20.3432</td>
#         <td id="T_01f97bf0_42e8_11e8_b09a_34f64b4d1556row0_col1" class="data row0 col1" >1.6356</td>
#         <td id="T_01f97bf0_42e8_11e8_b09a_34f64b4d1556row0_col2" class="data row0 col2" >10.6813</td>
#         <td id="T_01f97bf0_42e8_11e8_b09a_34f64b4d1556row0_col3" class="data row0 col3" >23.4795</td>
#         <td id="T_01f97bf0_42e8_11e8_b09a_34f64b4d1556row0_col4" class="data row0 col4" >0.333516</td>
#         <td id="T_01f97bf0_42e8_11e8_b09a_34f64b4d1556row0_col5" class="data row0 col5" >20.6636</td>
#         <td id="T_01f97bf0_42e8_11e8_b09a_34f64b4d1556row0_col6" class="data row0 col6" >3.68238</td>
#         <td id="T_01f97bf0_42e8_11e8_b09a_34f64b4d1556row0_col7" class="data row0 col7" >0.219298</td>
#         <td id="T_01f97bf0_42e8_11e8_b09a_34f64b4d1556row0_col8" class="data row0 col8" >1.85881</td>
#         <td id="T_01f97bf0_42e8_11e8_b09a_34f64b4d1556row0_col9" class="data row0 col9" >4.08443</td>
#         <td id="T_01f97bf0_42e8_11e8_b09a_34f64b4d1556row0_col10" class="data row0 col10" >3.19901</td>
#         <td id="T_01f97bf0_42e8_11e8_b09a_34f64b4d1556row0_col11" class="data row0 col11" >0</td>
#         <td id="T_01f97bf0_42e8_11e8_b09a_34f64b4d1556row0_col12" class="data row0 col12" >9.81934</td>
#     </tr>    <tr>
#         <th id="T_01f97bf0_42e8_11e8_b09a_34f64b4d1556level0_row1" class="row_heading level0 row1" >Central America</th>
#         <td id="T_01f97bf0_42e8_11e8_b09a_34f64b4d1556row1_col0" class="data row1 col0" >1.51515</td>
#         <td id="T_01f97bf0_42e8_11e8_b09a_34f64b4d1556row1_col1" class="data row1 col1" >1.51515</td>
#         <td id="T_01f97bf0_42e8_11e8_b09a_34f64b4d1556row1_col2" class="data row1 col2" >27.2727</td>
#         <td id="T_01f97bf0_42e8_11e8_b09a_34f64b4d1556row1_col3" class="data row1 col3" >32.5758</td>
#         <td id="T_01f97bf0_42e8_11e8_b09a_34f64b4d1556row1_col4" class="data row1 col4" >0.757576</td>
#         <td id="T_01f97bf0_42e8_11e8_b09a_34f64b4d1556row1_col5" class="data row1 col5" >6.06061</td>
#         <td id="T_01f97bf0_42e8_11e8_b09a_34f64b4d1556row1_col6" class="data row1 col6" >3.78788</td>
#         <td id="T_01f97bf0_42e8_11e8_b09a_34f64b4d1556row1_col7" class="data row1 col7" >0</td>
#         <td id="T_01f97bf0_42e8_11e8_b09a_34f64b4d1556row1_col8" class="data row1 col8" >1.51515</td>
#         <td id="T_01f97bf0_42e8_11e8_b09a_34f64b4d1556row1_col9" class="data row1 col9" >0</td>
#         <td id="T_01f97bf0_42e8_11e8_b09a_34f64b4d1556row1_col10" class="data row1 col10" >25</td>
#         <td id="T_01f97bf0_42e8_11e8_b09a_34f64b4d1556row1_col11" class="data row1 col11" >0</td>
#         <td id="T_01f97bf0_42e8_11e8_b09a_34f64b4d1556row1_col12" class="data row1 col12" >0</td>
#     </tr>    <tr>
#         <th id="T_01f97bf0_42e8_11e8_b09a_34f64b4d1556level0_row2" class="row_heading level0 row2" >East Asia</th>
#         <td id="T_01f97bf0_42e8_11e8_b09a_34f64b4d1556row2_col0" class="data row2 col0" >5.71782</td>
#         <td id="T_01f97bf0_42e8_11e8_b09a_34f64b4d1556row2_col1" class="data row2 col1" >1.69662</td>
#         <td id="T_01f97bf0_42e8_11e8_b09a_34f64b4d1556row2_col2" class="data row2 col2" >20.1131</td>
#         <td id="T_01f97bf0_42e8_11e8_b09a_34f64b4d1556row2_col3" class="data row2 col3" >31.9852</td>
#         <td id="T_01f97bf0_42e8_11e8_b09a_34f64b4d1556row2_col4" class="data row2 col4" >0.523981</td>
#         <td id="T_01f97bf0_42e8_11e8_b09a_34f64b4d1556row2_col5" class="data row2 col5" >8.13512</td>
#         <td id="T_01f97bf0_42e8_11e8_b09a_34f64b4d1556row2_col6" class="data row2 col6" >10.4812</td>
#         <td id="T_01f97bf0_42e8_11e8_b09a_34f64b4d1556row2_col7" class="data row2 col7" >8.35677</td>
#         <td id="T_01f97bf0_42e8_11e8_b09a_34f64b4d1556row2_col8" class="data row2 col8" >1.27457</td>
#         <td id="T_01f97bf0_42e8_11e8_b09a_34f64b4d1556row2_col9" class="data row2 col9" >7.38497</td>
#         <td id="T_01f97bf0_42e8_11e8_b09a_34f64b4d1556row2_col10" class="data row2 col10" >0.265016</td>
#         <td id="T_01f97bf0_42e8_11e8_b09a_34f64b4d1556row2_col11" class="data row2 col11" >0</td>
#         <td id="T_01f97bf0_42e8_11e8_b09a_34f64b4d1556row2_col12" class="data row2 col12" >4.06562</td>
#     </tr>    <tr>
#         <th id="T_01f97bf0_42e8_11e8_b09a_34f64b4d1556level0_row3" class="row_heading level0 row3" >Europe</th>
#         <td id="T_01f97bf0_42e8_11e8_b09a_34f64b4d1556row3_col0" class="data row3 col0" >1.79836</td>
#         <td id="T_01f97bf0_42e8_11e8_b09a_34f64b4d1556row3_col1" class="data row3 col1" >0.474356</td>
#         <td id="T_01f97bf0_42e8_11e8_b09a_34f64b4d1556row3_col2" class="data row3 col2" >6.02668</td>
#         <td id="T_01f97bf0_42e8_11e8_b09a_34f64b4d1556row3_col3" class="data row3 col3" >57.428</td>
#         <td id="T_01f97bf0_42e8_11e8_b09a_34f64b4d1556row3_col4" class="data row3 col4" >0.455148</td>
#         <td id="T_01f97bf0_42e8_11e8_b09a_34f64b4d15

# %%
import seaborn as sns

cm = sns.light_palette("red", as_cmap=True)

s = grouped_region.style.background_gradient(cmap=cm)
s
# Out:
# <style  type="text/css" >
#     #T_f8832f06_42e7_11e8_ac38_34f64b4d1556row0_col0 {
#             background-color:  #ff0000;
#         }    #T_f8832f06_42e7_11e8_ac38_34f64b4d1556row0_col1 {
#             background-color:  #ff0808;
#         }    #T_f8832f06_42e7_11e8_ac38_34f64b4d1556row0_col2 {
#             background-color:  #ff8d8d;
#         }    #T_f8832f06_42e7_11e8_ac38_34f64b4d1556row0_col3 {
#             background-color:  #ffcece;
#         }    #T_f8832f06_42e7_11e8_ac38_34f64b4d1556row0_col4 {
#             background-color:  #ffd6d6;
#         }    #T_f8832f06_42e7_11e8_ac38_34f64b4d1556row0_col5 {
#             background-color:  #ff2d2d;
#         }    #T_f8832f06_42e7_11e8_ac38_34f64b4d1556row0_col6 {
#             background-color:  #ffcdcd;
#         }    #T_f8832f06_42e7_11e8_ac38_34f64b4d1556row0_col7 {
#             background-color:  #ffe3e3;
#         }    #T_f8832f06_42e7_11e8_ac38_34f64b4d1556row0_col8 {
#             background-color:  #ff9595;
#         }    #T_f8832f06_42e7_11e8_ac38_34f64b4d1556row0_col9 {
#             background-color:  #ff8b8b;
#         }    #T_f8832f06_42e7_11e8_ac38_34f64b4d1556row0_col10 {
#             background-color:  #ffcece;
#         }    #T_f8832f06_42e7_11e8_ac38_34f64b4d1556row0_col11 {
#             background-color:  #ffe5e5;
#         }    #T_f8832f06_42e7_11e8_ac38_34f64b4d1556row0_col12 {
#             background-color:  #ff0d0d;
#         }    #T_f8832f06_42e7_11e8_ac38_34f64b4d1556row1_col0 {
#             background-color:  #ffd4d4;
#         }    #T_f8832f06_42e7_11e8_ac38_34f64b4d1556row1_col1 {
#             background-color:  #ff1818;
#         }    #T_f8832f06_42e7_11e8_ac38_34f64b4d1556row1_col2 {
#             background-color:  #ff0505;
#         }    #T_f8832f06_42e7_11e8_ac38_34f64b4d1556row1_col3 {
#             background-color:  #ffa9a9;
#         }    #T_f8832f06_42e7_11e8_ac38_34f64b4d1556row1_col4 {
#             background-color:  #ffc3c3;
#         }    #T_f8832f06_42e7_11e8_ac38_34f64b4d1556row1_col5 {
#             background-color:  #ffc6c6;
#         }    #T_f8832f06_42e7_11e8_ac38_34f64b4d1556row1_col6 {
#             background-color:  #ffcccc;
#         }    #T_f8832f06_42e7_11e8_ac38_34f64b4d1556row1_col7 {
#             background-color:  #ffe5e5;
#         }    #T_f8832f06_42e7_11e8_ac38_34f64b4d1556row1_col8 {
#             background-color:  #ffa5a5;
#         }    #T_f8832f06_42e7_11e8_ac38_34f64b4d1556row1_col9 {
#             background-color:  #ffe5e5;
#         }    #T_f8832f06_42e7_11e8_ac38_34f64b4d1556row1_col10 {
#             background-color:  #ff2a2a;
#         }    #T_f8832f06_42e7_11e8_ac38_34f64b4d1556row1_col11 {
#             background-color:  #ffe5e5;
#         }    #T_f8832f06_42e7_11e8_ac38_34f64b4d1556row1_col12 {
#             background-color:  #ffe5e5;
#         }    #T_f8832f06_42e7_11e8_ac38_34f64b4d1556row2_col0 {
#             background-color:  #ffa6a6;
#         }    #T_f8832f06_42e7_11e8_ac38_34f64b4d1556row2_col1 {
#             background-color:  #ff0000;
#         }    #T_f8832f06_42e7_11e8_ac38_34f64b4d1556row2_col2 {
#             background-color:  #ff4040;
#         }    #T_f8832f06_42e7_11e8_ac38_34f64b4d1556row2_col3 {
#             background-color:  #ffacac;
#         }    #T_f8832f06_42e7_11e8_ac38_34f64b4d1556row2_col4 {
#             background-color:  #ffcece;
#         }    #T_f8832f06_42e7_11e8_ac38_34f64b4d1556row2_col5 {
#             background-color:  #ffb0b0;
#         }    #T_f8832f06_42e7_11e8_ac38_34f64b4d1556row2_col6 {
#             background-color:  #ff9e9e;
#         }    #T_f8832f06_42e7_11e8_ac38_34f64b4d1556row2_col7 {
#             background-color:  #ff7b7b;
#         }    #T_f8832f06_42e7_11e8_ac38_34f64b4d1556row2_col8 {
#             background-color:  #ffafaf;
#         }    #T_f8832f06_42e7_11e8_ac38_34f64b4d1556row2_col9 {
#             background-color:  #ff4444;
#         }    #T_f8832f06_42e7_11e8_ac38_34f64b4d1556row2_col10 {
#             background-color:  #ffe4e4;
#         }    #T_f8832f06_42e7_11e8_ac38_34f64b4d1556row2_col11 {
#             background-color:  #ffe5e5;
#         }    #T_f8832f06_42e7_11e8_ac38_34f64b4d1556row2_col12 {
#             background-color:  #ff8c8c;
#         }    #T_f8832f06_42e7_11e8_ac38_34f64b4d1556row3_col0 {
#             background-color:  #ffd2d2;
#         }    #T_f8832f06_42e7_11e8_ac38_34f64b4d1556row3_col1 {
#             background-color:  #ffa6a6;
#         }    #T_f8832f06_42e7_11e8_ac38_34f64b4d1556row3_col2 {
#             background-color:  #ffb4b4;
#         }    #T_f8832f06_42e7_11e8_ac38_34f64b4d1556row3_col3 {
#             background-color:  #ff4646;
#         }    #T_f8832f06_42e7_11e8_ac38_34f64b4d1556row3_col4 {
#             background-color:  #ffd1d1;
#         }    #T_f8832f06_42e7_11e8_ac38_34f64b4d1556row3_col5 {
#             background-color:  #ff9e9e;
#         }    #T_f8832f06_42e7_11e8_ac38_34f64b4d1556row3_col6 {
#             background-color:  #ff9393;
#         }    #T_f8832f06_42e7_11e8_ac38_34f64b4d1556row3_col7 {
#             background-color:  #ffa5a5;
#         }    #T_f8832f06_42e7_11e8_ac38_34f64b4d1556row3_col8 {
#             background-color:  #ffb5b5;
#         }    #T_f8832f06_42e7_11e8_ac38_34f64b4d1556row3_col9 {
#             background-color:  #ffdcdc;
#         }    #T_f8832f06_42e7_11e8_ac38_34f64b4d1556row3_col10 {
#             background-color:  #ffd8d8;
#         }    #T_f8832f06_42e7_11e8_ac38_34f64b4d1556row3_col11 {
#             background-color:  #ff7878;
#         }    #T_f8832f06_42e7_11e8_ac38_34f64b4d1556row3_col12 {
#             background-color:  #ffa5a5;
#         }    #T_f8832f06_42e7_11e8_ac38_34f64b4d1556row4_col0 {
#             background-color:  #ffcaca;
#         }    #T_f8832f06_42e7_11e8_ac38_34f64b4d1556row4_col1 {
#             background-color:  #ffe5e5;
#         }    #T_f8832f06_42e7_11e8_ac38_34f64b4d1556row4_col2 {
#             background-color:  #ffd2d2;
#         }    #T_f8832f06_42e7_11e8_ac38_34f64b4d1556row4_col3 {
#             background-color:  #ff9f9f;
#         }    #T_f8832f06_42e7_11e8_ac38_34f64b4d1556row4_col4 {
#             background-color:  #ff0000;
#         }    #T_f8832f06_42e7_11e8_ac38_34f64b4d1556row4_col5 {
#             background-color:  #ffb9b9;
#         }    #T_f8832f06_42e7_11e8_ac38_34f64b4d1556row4_col6 {
#             background-color:  #ffd5d5;
#         }    #T_f8832f06_42e7_11e8_ac38_34f64b4d1556row4_col7 {
#             background-color:  #ff3f3f;
#         }    #T_f8832f06_42e7_11e8_ac38_34f64b4d1556row4_col8 {
#             background-color:  #ffe5e5;
#         }    #T_f8832f06_42e7_11e8_ac38_34f64b4d1556row4_col9 {
#             background-color:  #ffe5e5;
#         }    #T_f8832f06_42e7_11e8_ac38_34f64b4d1556row4_col10 {
#             background-color:  #ff4040;
#         }    #T_f8832f06_42e7_11e8_ac38_34f64b4d1556row4_col11 {
#             background-color:  #ffe5e5;
#         }    #T_f8832f06_42e7_11e8_ac38_34f64b4d1556row4_col12 {
#             background-color:  #ff0e0e;
#         }    #T_f8832f06_42e7_11e8_ac38_34f64b4d1556row5_col0 {
#             background-color:  #ffc8c8;
#         }    #T_f8832f06_42e7_11e8_ac38_34f64b4d1556row5_col1 {
#             background-color:  #ffcccc;
#         }    #T_f8832f06_42e7_11e8_ac38_34f64b4d1556row5_col2 {
#             background-color:  #ff9090;
#         }    #T_f8832f06_42e7_11e8_ac38_34f64b4d1556row5_col3 {
#             background-color:  #ff8888;
#         }    #T_f8832f06_42e7_11e8_ac38_34f64b4d1556row5_col4 {
#             background-color:  #ffc6c6;
#         }    #T_f8832f06_42e7_11e8_ac38_34f64b4d1556row5_col5 {
#             background-color:  #ff3232;
#         }    #T_f8832f06_42e7_11e8_ac38_34f64b4d1556row5_col6 {
#             background-color:  #ffabab;
#         }    #T_f8832f06_42e7_11e8_ac38_34f64b4d1556row5_col7 {
#             background-color:  #ff7979;
#         }    #T_f8832f06_42e7_11e8_ac38_34f64b4d1556row5_col8 {
#             background-color:  #ff8a8a;
#         }    #T_f8832f06_42e7_11e8_ac38_34f64b4d1556row5_col9 {
#             background-color:  #ffe3e3;
#         }    #T_f8832f06_42e7_11e8_ac38_34f64b4d1556row5_col10 {
#             background-color:  #ffd4d4;
#         }    #T_f8832f06_42e7_11e8_ac38_34f64b4d1556row5_col11
