# %% [markdown]
# # NoteBook for the Summer and Winter Games (Medals and Medalists)
# This is the notebook for the medal winners. Then files where given to us by the Olympic Study Center

# %%
import os.path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
# %matplotlib inline
from bs4 import BeautifulSoup
import webbrowser
import urllib.request
from lxml import html
import zipfile
import re
import string
import sys, os

# %%
# Ensure the file exists
if not os.path.exists( r"..\..\data\raw\Study_Center\SummerGames_Medals_Medalists.xlsx" ):
    print("Missing dataset file")
if not os.path.exists( r"..\..\data\raw\Study_center\WinterGames_Medals_Medalists.xlsx" ):
    print("Missing dataset file")

# %%
# Getting the individual sheets fromm each xlsx
xls1 = pd.ExcelFile(r'..\..\data\raw\Study_center\SummerGames_Medals_Medalists.xlsx')
sumdf = pd.read_excel(xls1, 'Medalists')
xls2 = pd.ExcelFile(r'..\..\data\raw\Study_center\WinterGames_Medals_Medalists.xlsx')
windf = pd.read_excel(xls2, 'Medallists')

# %% [markdown]
# # Editing the Summer dataFrame first

# %%
# Dropping Noc is active field, rank field will be dropped later 
sumdf = sumdf.drop(sumdf.columns[[11]], axis=1)

# %%
# creating summer and winter games bolleans for the summer df
sumdf['Summer']= True
sumdf['Winter']= False

# %%
sumdf.rename(columns={'Names': 'Ath_Name'}, inplace=True)

# %%
# looking at original df
sumdf.head(5)
# Out:
#    Year  City                Ath_Name  NOC Gender     Sport Discipline  \
# 0  1960  Rome         WEBSTER, Robert  USA    Men  Aquatics     Diving
# 1  1960  Rome            TOBIAN, Gary  USA    Men  Aquatics     Diving
# 2  1960  Rome           PHELPS, Brian  GBR    Men  Aquatics     Diving
# 3  1960  Rome          KRÄMER, Ingrid  EUA  Women  Aquatics     Diving
# 4  1960  Rome  MYERS-POPE, Paula Jean  USA  Women  Aquatics     Diving
#
#           Event EventGender  Rank   Medal  Summer  Winter
# 0  10m platform           M     1    Gold    True   False
# 1  10m platform           M     2  Silver    True   False
# 2  10m platform           M     3  Bronze    True   False
# 3  10m platform           W     1    Gold    True   False
# 4  10m platform           W     2  Silver    True   False

# %% [markdown]
# # Then Editing the Winter dataframe

# %%
# renaming the gender column 
windf.rename(columns={'ParticipantsGender': 'Gender'}, inplace=True)
# renaming the name column 
windf.rename(columns={'Participant': 'Ath_Name'}, inplace=True)

# %%
# Dropping the continent field because it's not in the summer df and isn't that useful  
windf = windf.drop(windf.columns[[6]], axis=1)

# %%
# creating summer and winter games bolleans for both dfs
windf['Summer']= False
windf['Winter']= True

# %%
# changing the gender of male and female to M and F
windf['Gender'] = np.where(windf['Gender']=='Men', 'M', 'F')

# %%
windf.head(5)
# Out:
#    Year          City       Sport  Discipline               Ath_Name Gender  \
# 0  1960  Squaw Valley    Biathlon    Biathlon    PRIVALOV, Aleksandr      M
# 1  1960  Squaw Valley    Biathlon    Biathlon        LESTANDER, Klas      M
# 2  1960  Squaw Valley    Biathlon    Biathlon       TYRVÄINEN, Antti      M
# 3  1960  Squaw Valley  Ice Hockey  Ice Hockey  ALEKSANDROV, Veniamin      M
# 4  1960  Squaw Valley  Ice Hockey  Ice Hockey     ALMETOV, Aleksandr      M
#
#    NOC       Event EventGender   Medal  Summer  Winter
# 0  URS        20km         Men  Bronze   False    True
# 1  SWE        20km         Men    Gold   False    True
# 2  FIN        20km         Men  Silver   False    True
# 3  URS  ice hockey         Men  Bronze   False    True
# 4  URS  ice hockey         Men  Bronze   False    True

# %% [markdown]
# # Removing Null columns and or useless data

# %% [markdown]
# # Winter DF
# The winter df as 11 null rows in the Noc field, these same rows also have 'pending' values for the Ath_name.
# So for now I will remove them.

# %%
# checking number of null values 
windf.isnull().sum()
# Out:
# Year            0
# City            0
# Sport           0
# Discipline      0
# Ath_Name        0
# Gender          0
# NOC            11
# Event           0
# EventGender     0
# Medal           0
# Summer          0
# Winter          0
# dtype: int64

# %%
# Removing these useless rows 
windf = windf[windf.Ath_Name != 'pending']

# %%
# there no more null values 
windf.isnull().sum()
# Out:
# Year           0
# City           0
# Sport          0
# Discipline     0
# Ath_Name       0
# Gender         0
# NOC            0
# Event          0
# EventGender    0
# Medal          0
# Summer         0
# Winter         0
# dtype: int64

# %% [markdown]
# # Summer DF
# The summer df as 14 null rows for Noc the name of the athletes for these rows contain values such as 'pending / decision to be confirmed'
# so I'll remove them too for the time being.

# %%
# checking number of null values  
sumdf.isnull().sum()
# Out:
# Year            0
# City            0
# Ath_Name        0
# NOC            14
# Gender          0
# Sport           0
# Discipline      0
# Event           0
# EventGender     0
# Rank            0
# Medal           1
# Summer          0
# Winter          0
# dtype: int64

# %%
# examining the rows with some field null values 
sumdf[sumdf['NOC'].isnull()]
# Out:
#        Year     City                            Ath_Name  NOC Gender  \
# 17811  2008  Beijing  pending / decision to be confirmed  NaN    Men
# 17812  2008  Beijing  pending / decision to be confirmed  NaN    Men
# 17813  2008  Beijing  pending / decision to be confirmed  NaN    Men
# 17814  2008  Beijing  pending / decision to be confirmed  NaN    Men
# 17899  2008  Beijing  pending / decision to be confirmed  NaN  Women
# 17910  2008  Beijing  pending / decision to be confirmed  NaN  Women
# 17916  2008  Beijing  pending / decision to be confirmed  NaN  Women
# 17940  2008  Beijing  pending / decision to be confirmed  NaN  Women
# 17941  2008  Beijing  pending / decision to be confirmed  NaN  Women
# 19351  2008  Beijing  pending / decision to be confirmed  NaN  Women
# 19354  2008  Beijing  pending / decision to be confirmed  NaN  Women
# 19926  2012   London  pending / decision to be confirmed  NaN  Women
# 19946  2012   London  pending / decision to be confirmed  NaN  Women
# 21291  2012   London  pending / decision to be confirmed  NaN  Women
#
#                Sport     Discipline          Event EventGender  Rank   Medal  \
# 17811      Athletics      Athletics   4x100m relay           M     1    Gold
# 17812      Athletics      Athletics   4x100m relay           M     1    Gold
# 17813      Athletics      Athletics   4x100m relay           M     1    Gold
# 17814      Athletics      Athletics   4x100m relay           M     1    Gold
# 17899      Athletics      Athletics     heptathlon           W     3  Bronze
# 17910      Athletics      Athletics  javelin throw           W     2  Silver
# 17916      Athletics      Athletics      long jump           W     2  Silver
# 17940      Athletics      Athletics    triple jump           W     2  Silver
# 17941      Athletics      Athletics    triple jump           W     3  Bronze
# 19351  Weightlifting  Weightlifting           69kg           W     1    Gold
# 19354  Weightlifting  Weightlifting           75kg           W     1    Gold
# 19926      Athletics      Athletics           800m           W     1    Gold
# 19946      Athletics      Athletics     heptathlon           W     3  Bronze
# 21291  Weightlifting  Weightlifting           63kg           W     1    Gold
#
#        Summer  Winter
# 17811    True   False
# 17812    True   False
# 17813    True   False
# 17814    True   False
# 17899    True   False
# 17910    True   False
# 17916    True   False
# 17940    True   False
# 17941    True   False
# 19351    True   False
# 19354    True   False
# 19926    True   False
# 19946    True   False
# 21291    True   False

# %%
# removing these useless rows 
sumdf = sumdf[sumdf.Ath_Name != 'pending / decision to be confirmed']

# %%
# checking for any more null values 
sumdf[sumdf['Medal'].isnull()]
# Out:
#        Year    City            Ath_Name  NOC Gender      Sport Discipline  \
# 19825  2012  London  TOMASHOVA, Tatyana  RUS  Women  Athletics  Athletics
#
#        Event EventGender  Rank Medal  Summer  Winter
# 19825  1500m           W     2   NaN    True   False

# %% [markdown]
# There is one more null value for medal however this can be solved with the use of the rank column.
# The rank field of this row is 2 so the medal the athlete won is sliver.

# %%
sumdf.loc[19825, 'Medal'] = 'Silver'

# %%
# Now we can remove the rank field because it is redudant 
sumdf = sumdf.drop(sumdf.columns[[9]], axis=1)

# %% [markdown]
# # Joining the Summer and Winter dataFrames

# %%
# pd.concat joins the tables together and ignore index to ensure that there are no repeat indexes
df = pd.concat([sumdf, windf], ignore_index=True)

# %%
# Changing the gneder event and city field names 
df.rename(columns={'EventGender': 'Event_Gender'}, inplace=True)
df.rename(columns={'City': 'Host_City'}, inplace=True)

# %%
df.head(3)
# Out:
#           Ath_Name Host_City Discipline         Event Event_Gender Gender  \
# 0  WEBSTER, Robert      Rome     Diving  10m platform            M    Men
# 1     TOBIAN, Gary      Rome     Diving  10m platform            M    Men
# 2    PHELPS, Brian      Rome     Diving  10m platform            M    Men
#
#     Medal  NOC     Sport  Summer  Winter  Year
# 0    Gold  USA  Aquatics    True   False  1960
# 1  Silver  USA  Aquatics    True   False  1960
# 2  Bronze  GBR  Aquatics    True   False  1960

# %%
df.to_csv(r"..\..\data\prep\Games\Games-Unedited-500.csv", index=False)
# Ensure the file exists

# %%
# Ensure the file exists
if not os.path.exists(r"..\..\data\prep\Games\Games-Unedited-500.csv" ):
    print("Missing dataset file")

# %% [markdown]
# # Adding Fields to the Olympic DataFrame
# * The first field is getting rid of the current medal field and adding Gold, Sliver and Bronze count fields and then I'll remove duplicate rows of the same athlete and olympic year.
# * Second I'll add a total medal column.
# * Finally I'll add a home advantage column along with a field for the country the games was hosted that year.

# %%
df.head(3)
# Out:
#           Ath_Name Host_City Discipline         Event Event_Gender Gender  \
# 0  WEBSTER, Robert      Rome     Diving  10m platform            M    Men
# 1     TOBIAN, Gary      Rome     Diving  10m platform            M    Men
# 2    PHELPS, Brian      Rome     Diving  10m platform            M    Men
#
#     Medal  NOC     Sport  Summer  Winter  Year
# 0    Gold  USA  Aquatics    True   False  1960
# 1  Silver  USA  Aquatics    True   False  1960
# 2  Bronze  GBR  Aquatics    True   False  1960

# %%
# Addeing gold, silver and bonze medal count fields 
df['Gold']= 0
df['Silver']= 0
df['Bronze']= 0

# %%
# Adding in values for the medal type fields based on the Medal won in the 'Medal' field
df['Bronze'] = np.where(df['Medal']=='Bronze', 1, 0)
df['Silver'] = np.where(df['Medal']=='Silver', 1, 0)
df['Gold'] = np.where(df['Medal']=='Gold', 1, 0)

# %%
df.head(4)
# Out:
#           Ath_Name Host_City Discipline         Event Event_Gender Gender  \
# 0  WEBSTER, Robert      Rome     Diving  10m platform            M    Men
# 1     TOBIAN, Gary      Rome     Diving  10m platform            M    Men
# 2    PHELPS, Brian      Rome     Diving  10m platform            M    Men
# 3   KRÄMER, Ingrid      Rome     Diving  10m platform            W  Women
#
#     Medal  NOC     Sport  Summer  Winter  Year  Gold  Silver  Bronze
# 0    Gold  USA  Aquatics    True   False  1960     1       0       0
# 1  Silver  USA  Aquatics    True   False  1960     0       1       0
# 2  Bronze  GBR  Aquatics    True   False  1960     0       0       1
# 3    Gold  EUA  Aquatics    True   False  1960     1       0       0

# %% [markdown]
# Now I want to remove rows with the same athlete name from the same olympics. So I'll have to count there medals and make it into a single row.
#
# ** This will make the event name and gender fields reduntant as we are merging all of the athletes medls for a given olympics. **

# %%
# Here 'Ive created a Df with all the summed medals of athletes from a given olympics 
athletes_medals = df.groupby(['Ath_Name', 'Year'])[["Gold", "Silver", "Bronze"]].sum()
athletes_medals.head(3)
# Out:
#                        Gold  Silver  Bronze
# Ath_Name         Year
# AAHLBERG, Mats   1980     0       0       1
# AAHLEN, Thomas   1984     0       0       1
# AALAND, Per Knut 1980     0       1       0

# %%
df = df.drop(df.columns[[4]], axis=1)

# %%
df.columns
# Out:
# Index(['Ath_Name', 'Host_City', 'Discipline', 'Event', 'Gender', 'Medal',
#        'NOC', 'Sport', 'Summer', 'Winter', 'Year', 'Gold', 'Silver', 'Bronze'],
#       dtype='object')

# %% [markdown]
# Now what I want to do is join this athlete datafrmae with their summed medals by the given games with the original datframe.

# %%
# I'll set the index of the original dataframe to athlete and year as well so I can join it with the summed medal dataframe
df = df.set_index(['Ath_Name', 'Year'])

# %% [markdown]
# In the cell below I'm joining all the big dataframes 'df' columns to the 'athletes_medals' dataframe, excluding the columns from the big datframe 'df' that are already in the
# 'athelte_medals' dataframe. This is so only the athlete rows with the summed medals are added. '

# %%
 df = df[['Host_City', 'Discipline','Event', 'Gender', 'NOC', 'Sport', 'Summer', 'Winter', 'Medal' ]].join(athletes_medals)

# %% [markdown]
# Some duplicate rows remain of some athletes from the same olympics like the example below.
# So we will remove them next.

# %%
# Resetting index to show an example of duplicates
df = df.reset_index()
df.loc[df['Ath_Name'] == 'AAMODT, Kjetil Andre']
# Out:
#                 Ath_Name  Year       Host_City     Discipline  \
# 4   AAMODT, Kjetil Andre  1992     Albertville  Alpine Skiing
# 5   AAMODT, Kjetil Andre  1992     Albertville  Alpine Skiing
# 6   AAMODT, Kjetil Andre  1994     Lillehammer  Alpine Skiing
# 7   AAMODT, Kjetil Andre  1994     Lillehammer  Alpine Skiing
# 8   AAMODT, Kjetil Andre  1994     Lillehammer  Alpine Skiing
# 9   AAMODT, Kjetil Andre  2002  Salt Lake City  Alpine Skiing
# 10  AAMODT, Kjetil Andre  2002  Salt Lake City  Alpine Skiing
# 11  AAMODT, Kjetil Andre  2006           Turin  Alpine Skiing
#
#               Event Gender  NOC   Sport  Summer  Winter   Medal  Gold  Silver  \
# 4      giant slalom      M  NOR  Skiing   False    True  Bronze     1       0
# 5           super-G      M  NOR  Skiing   False    True    Gold     1       0
# 6   alpine combined      M  NOR  Skiing   False    True  Silver     0       2
# 7          downhill      M  NOR  Skiing   False    True  Silver     0       2
# 8           super-G      M  NOR  Skiing   False    True  Bronze     0       2
# 9   alpine combined      M  NOR  Skiing   False    True    Gold     2       0
# 10          super-G      M  NOR  Skiing   False    True    Gold     2       0
# 11          super-G      M  NOR  Skiing   False    True    Gold     1       0
#
#     Bronze
# 4        1
# 5        1
# 6        1
# 7        1
# 8        1
# 9        0
# 10       0
# 11       0

# %%
# Setting the index back to athlete and year to allow for removal
df = df.set_index(['Ath_Name', 'Year'])
# Now removing duplicates based on the index, athlete name and year
df = df[~df.index.duplicated(keep='first')]

# %%
# resetting the df index
df = df.reset_index()

# %%
df.loc[df['Ath_Name'] == 'AAMODT, Kjetil Andre']
# Out:
#                Ath_Name  Year       Host_City     Discipline            Event  \
# 4  AAMODT, Kjetil Andre  1992     Albertville  Alpine Skiing     giant slalom
# 5  AAMODT, Kjetil Andre  1994     Lillehammer  Alpine Skiing  alpine combined
# 6  AAMODT, Kjetil Andre  2002  Salt Lake City  Alpine Skiing  alpine combined
# 7  AAMODT, Kjetil Andre  2006           Turin  Alpine Skiing          super-G
#
#   Gender  NOC   Sport  Summer  Winter   Medal  Gold  Silver  Bronze
# 4      M  NOR  Skiing   False    True  Bronze     1       0       1
# 5      M  NOR  Skiing   False    True  Silver     0       2       1
# 6      M  NOR  Skiing   False    True    Gold     2       0       0
# 7      M  NOR  Skiing   False    True    Gold     1       0       0

# %% [markdown]
# Adding the Total medal field

# %%
# filling total field with values 
df['Total_Medals'] = df['Gold'] + df['Silver'] + df['Bronze']

# %% [markdown]
# # Creating the home advantage field
# First I'll create a dictionary with the host city as the keys and host country as values. Then I can compare the host cities respective value (the country) that an athlete played in with that athletes Noc. If the countires are the same home advantage is true otherwise false.

# %%
# Populating the country-city dictionary
cDict = { 'Albertville': 'FRA', 'Lillehammer': 'NOR', 'Salt Lake City': 'USA', 'Turin': 'ITA', 'Squaw Valley': 'USA',
        'Beijing': 'CHN', 'Los Angeles': 'USA', 'Athens': 'GRC', 'London': 'UK', 'Sydney': 'AUS', 'Atlanta': 'USA', 'Munich': 'DEU',
        'Calgary': 'CAN', 'Barcelona': 'ESP', 'Seoul': 'KOR', 'Grenoble': 'FRA', 'Moscow': 'RUS', 'Nagano': 'JPN', 'Rome': 'ITA',
        'Lake Placid': 'USA', 'Tokyo': 'JPN', 'Mexico': 'MEX', 'Vancouver': 'CAN', 'Innsbruck': 'AUS', 'Sochi': 'RUS', 'Montreal': 'CAN',
        'Sarajevo': 'BIH', 'Sapporo': 'JPN', 'Rio': 'BRA', 'Barcelone': 'ESP', 'Montréal': 'CAN', 'PyeongChang': 'KOR'}

# %%
# Quick for loop to populate the home_adv field 
for x, row in df.iterrows():
    city = df['Host_City'].iloc[x]
    homecountry = df['NOC'].iloc[x]
    
    # Adding another field for the host country 
    df.loc[x, 'Host_Country'] = cDict[city]

    # if the athletes home country is the same as the host country adv is true else false 
    if(homecountry == cDict[city]):
        df.loc[x, 'Home_Adv'] = True
    else:
        df.loc[x, 'Home_Adv'] = False

# %%
df
# Out:
#                     Ath_Name  Year       Host_City            Discipline  \
# 0             AAHLBERG, Mats  1980     Lake Placid            Ice Hockey
# 1             AAHLEN, Thomas  1984        Sarajevo            Ice Hockey
# 2           AALAND, Per Knut  1980     Lake Placid  Cross Country Skiing
# 3        AALTONEN, Juhamatti  2014           Sochi            Ice Hockey
# 4       AAMODT, Kjetil Andre  1992     Albertville         Alpine Skiing
# 5       AAMODT, Kjetil Andre  1994     Lillehammer         Alpine Skiing
# 6       AAMODT, Kjetil Andre  2002  Salt Lake City         Alpine Skiing
# 7       AAMODT, Kjetil Andre  2006           Turin         Alpine Skiing
# 8           AAMODT, Ragnhild  2008         Beijing              Handball
# 9      AARDENBURG, Willemien  1988           Seoul                Hockey
# 10         AARDEWIJN, Pepijn  1996         Atlanta                Rowing
# 11      AARONES, Ann Kristin  1996         Atlanta              Football
# 12                AAS, Roald  1960    Squaw Valley         Speed skating
# 13             AASLIN, Peter  1988         Calgary            Ice Hockey
# 14        ABAGNALE, Giovanni  2016             Rio                Rowing
# 15          ABAJO, Jose Luis  2008         Beijing               Fencing
# 16        ABAKAROVA, Patimat  2016             Rio             Taekwondo
# 17       ABALMASAU, Aliaksei  2008         Beijing          Canoe Sprint
# 18                ABALO, Luc  2008         Beijing              Handball
# 19                ABALO, Luc  2012          London              Handball
# 20                ABALO, Luc  2016             Rio              Handball
# 21           ABANDA, Patrice  2000          Sydney              Football
# 22        ABARCA, Jose Maria  1996         Atlanta            Water Polo
# 23             ABAS, Stephen  2004          Athens   Wrestling Freestyle
# 24        ABASCAL, Alejandro  1980          Moscow               Sailing
# 25      ABASCAL, José Manuel  1984     Los Angeles             Athletics
# 26         ABASSOVA, Tamilla  2004          Athens         Cycling Track
# 27               ABATI, Joel  2008         Beijing              Handball
# 28               ABAY, Péter  1992       Barcelone               Fencing
# 29       ABBAGNALE, Agostino  1988           Seoul                Rowing
# ...                      ...   ...             ...                   ...
# 25795           ÉRSEK, Zsolt  1988           Seoul               Fencing
# 25796      ÖBERG, Carl-Göran  1964       Innsbruck            Ice Hockey
# 25797           ÖHLING, Jens  1984        Sarajevo            Ice Hockey
# 25798           ÖHLING, Jens  1988         Calgary            Ice Hockey
# 25799           ÖHRLUND, Uno  1964       Innsbruck            Ice Hockey
# 25800            ÖRN, Mikael  1984     Los Angeles              Swimming
# 25801        ÖRNSKOG, Stefan  1994     Lillehammer            Ice Hockey
# 25802           ÖSTBY, Einar  1960    Squaw Valley  Cross Country Skiing
# 25803       ÖSTERREICH, Rolf  1976       Innsbruck        Figure skating
# 25804         ÖZKAN, Huseyin  2000          Sydney                  Judo
# 25805    ØRSTED, Hans-Henrik  1980          Moscow         Cycling Track
# 25806         ŠIMENC, Zlatko  1964           Tokyo            Water Polo
# 25807           ŠKARO, Damir  1988           Seoul                Boxing
# 25808            ŠKODA, Jirí  1980          Moscow          Cycling Road
# 25809          ŠOLMAN, Damir  1968          Mexico            Basketball
# 25810          ŠOLMAN, Damir  1976        Montréal            Basketball
# 25811            ŠORM, Josef  1964           Tokyo            Volleyball
# 25812         ŠREJBER, Milan  1988           Seoul                Tennis
# 25813   ŠTAMBACHR, František  1980          Moscow              Football
# 25814         ŠTRBAC, Branko  1984     Los Angeles              Handball
# 25815       ŠVÉDOVÁ, Ludmila  1960            Rome   Gymnastics Artistic
# 25816        ŽBOGAR, Vasilij  2004          Athens               Sailing
# 25817        ŽBOGAR, Vasilij  2008         Beijing               Sailing
# 25818           ŽELEZNÝ, Jan  1988           Seoul             Athletics
# 25819           ŽELEZNÝ, Jan  1992       Barcelone             Athletics
# 25820           ŽELEZNÝ, Jan  1996         Atlanta             Athletics
# 25821           ŽELEZNÝ, Jan  2000          Sydney             Athletics
# 25822        ŽIVKOVIC, Zoran  1972          Munich              Handball
# 25823          ŽORGA, Aljoša  1968          Mexico            Basketball
# 25824        ŽULPA, Robertas  1980          Moscow              Swimming
#
#                      Event Gender  NOC       Sport  Summer  Winter   Medal  \
# 0               ice hockey      M  SWE  Ice Hockey   False    True  Bronze
# 1               ice hockey      M  SWE  Ice Hockey   False    True  Bronze
# 2             4x10km relay      M  NOR      Skiing   False    True  Silver
# 3               ice hockey      M  FIN  Ice Hockey   False    True  Bronze
# 4             giant slalom      M  NOR      Skiing   False    True  Bronze
# 5          alpine combined      M  NOR      Skiing   False    True  Silver
# 6          alpine combined      M  NOR      Skiing   False    True    Gold
# 7                  super-G      M  NOR      Skiing   False    True    Gold
# 8                 handball  Women  NOR    Handball    True   False    Gold
# 9                   hockey  Women  NED      Hockey    True   False  Bronze
# 10     lightweight doubles    Men  NED      Rowing    True   False  Silver
# 11                football  Women  NOR    Football    True   False  Bronze
# 12                   1500m      M  NOR     Skating   False    True    Gold
# 13              ice hockey      M  SWE  Ice Hockey   False    True  Bronze
# 14         coxless pair 2-    Men  ITA      Rowing    True   False  Bronze
# 15         épée individual    Men  ESP     Fencing    True   False  Bronze
# 16                 - 49 kg  Women  AZE   Taekwondo    True   False  Bronze
# 17               K-4 1000m    Men  BLR       Canoe    True   False    Gold
# 18                handball    Men  FRA    Handball    True   False    Gold
# 19                handball    Men  FRA    Handball    True   False    Gold
# 20                handball    Men  FRA    Handball    True   False  Silver
# 21                football    Men  CMR    Football    True   False    Gold
# 22              water polo    Men  ESP    Aquatics    True   False    Gold
# 23                  - 55kg    Men  USA   Wrestling    True   False  Silver
# 24         flying dutchman    Men  ESP     Sailing    True   False    Gold
# 25                   1500m    Men  ESP   Athletics    True   False  Bronze
# 26                  Sprint  Women  RUS     Cycling    True   False  Silver
# 27                handball    Men  FRA    Handball    True   False    Gold
# 28              sabre Team    Men  HUN     Fencing    True   False  Silver
# 29        quadruple sculls    Men  ITA      Rowing    True   False    Gold
# ...                    ...    ...  ...         ...     ...     ...     ...
# 25795            foil Team    Men  HUN     Fencing    True   False  Bronze
# 25796           ice hockey      M  SWE  Ice Hockey   False    True  Silver
# 25797           ice hockey      M  SWE  Ice Hockey   False    True  Bronze
# 25798           ice hockey      M  SWE  Ice Hockey   False    True  Bronze
# 25799           ice hockey      M  SWE  Ice Hockey   False    True  Silver
# 25800     4x100m freestyle    Men  SWE    Aquatics    True   False  Bronze
# 25801           ice hockey      M  SWE  Ice Hockey   False    True    Gold
# 25802         4x10km relay      M  NOR      Skiing   False    True  Silver
# 25803                pairs      M  GDR     Skating   False    True  Silver
# 25804            60 - 66kg    Men  TUR        Judo    True   False    Gold
# 25805         Ind. Pursuit    Men  DEN     Cycling    True   False  Bronze
# 25806           water polo    Men  YUG    Aquatics    True   False  Silver
# 25807            75 - 81kg    Men  YUG      Boxing    True   False  Bronze
# 25808      Team time trial    Men  TCH     Cycling    True   False  Bronze
# 25809           basketball    Men  YUG  Basketball    True   False  Silver
# 25810           basketball    Men  YUG  Basketball    True   False  Silver
# 25811           volleyball    Men  TCH  Volleyball    True   False  Silver
# 25812              Doubles    Men  TCH      Tennis    True   False  Bronze
# 25813             football    Men  TCH    Football    True   False    Gold
# 25814             handball    Men  YUG    Handball    True   False    Gold
# 25815     Team competition  Women  TCH  Gymnastics    True   False  Silver
# 25816                Laser    Men  SLO     Sailing    True   False  Bronze
# 25817                Laser    Men  SLO     Sailing    True   False  Silver
# 25818        javelin throw    Men  TCH   Athletics    True   False  Silver
# 25819        javelin throw    Men  TCH   Athletics    True   False    Gold
# 25820        javelin throw    Men  CZE   Athletics    True   False    Gold
# 25821        javelin throw    Men  CZE   Athletics    True   False    Gold
# 25822             handball    Men  YUG    Handball    True   False    Gold
# 25823           basketball    Men  YUG  Basketball    True   False  Silver
# 25824    200m breaststroke    Men  URS    Aquatics    True   False    Gold
#
#        Gold  Silver  Bronze  Total_Medals Host_Country Home_Adv
# 0         0       0       1             1          USA    False
# 1         0       0       1             1          BIH    False
# 2         0       1       0             1          USA    False
# 3         0       0       1             1          RUS    False
# 4         1       0       1             2          FRA    False
# 5         0       2       1             3          NOR     True
# 6         2       0       0             2          USA    False
# 7         1       0       0             1          ITA    False
# 8         1       0       0             1          CHN    False
# 9         0       0       1             1          KOR    False
# 10        0       1       0             1          USA    False
# 11        0       0       1             1          USA    False
# 12        1       0       0             1          USA    False
# 13        0       0       1             1          CAN    False
# 14        0       0       1             1          BRA    False
# 15        0       0       1             1          CHN    False
# 16        0       0       1             1          BRA    False
# 17        1       0       0             1          CHN    False
# 18        1       0       0             1          CHN    False
# 19        1       0       0             1           UK    False
# 20        0       1       0             1          BRA    False
# 21        1       0       0             1          AUS    False
# 22        1       0       0             1          USA    False
# 23        0       1       0             1          GRC    False
# 24        1       0       0             1          RUS    False
# 25        0       0       1             1          USA    False
# 26        0       1       0             1          GRC    False
# 27        1       0       0             1          CHN    False
# 28        0       1       0             1          ESP    False
# 29        1       0       0             1          KOR    False
# ...     ...     ...     ...           ...          ...      ...
# 25795     0       0       1             1          KOR    False
# 25796     0       1       0             1          AUS    False
# 25797     0       0       1             1          BIH    False
# 25798     0       0       1             1          CAN    False
# 25799     0       1       0             1          AUS    False
# 25800     0       0       1             1          USA    False
# 25801     1       0       0             1          NOR    False
# 25802     0       1       0             1          USA    False
# 25803     0       1       0             1          AUS    False
# 25804     1       0       0             1          AUS    False
# 25805     0       0       1             1          RUS    False
# 25806     0       1       0             1          JPN    False
# 25807     0       0       1             1          KOR    False
# 25808     0       0       1             1          RUS    False
# 25809     0       1       0             1          MEX    False
# 25810     0       1       0             1          CAN    False
# 25811     0       1       0             1          JPN    False
# 25812     0       0       1             1          KOR    False
# 25813     1       0       0             1          RUS    False
# 25814     1       0       0             1          USA    False
# 25815     0       1       0             1          ITA    False
# 25816     0       0       1             1          GRC    False
# 25817     0       1       0             1          CHN    False
# 25818     0       1       0             1          KOR    False
# 25819     1       0       0             1          ESP    False
# 25820     1       0       0             1          USA    False
# 25821     1       0       0             1          AUS    False
# 25822     1       0       0             1          DEU    False
# 25823     0       1       0             1          MEX    False
# 25824     1       0       0             1          RUS    False
#
# [25825 rows x 17 columns]

# %%
df = df[['Year', 'Host_City', 'Host_Country', 'Summer', 'Winter', 'Discipline','Sport',
              'Event', 'Ath_Name', 'Gender', 'NOC', 'Home_Adv', 'Medal', 'Gold', 'Silver', 'Bronze', 'Total_Medals']]

# %% [markdown]
# # Removing Team Medals and keeping only One occurance
# We're counting all team medals as one. '

# %%
df.columns
# Out:
# Index(['Year', 'Host_City', 'Host_Country', 'Summer', 'Winter', 'Discipline',
#        'Sport', 'Event', 'Ath_Name', 'Gender', 'NOC', 'Home_Adv', 'Medal',
#        'Gold', 'Silver', 'Bronze', 'Total_Medals'],
#       dtype='object')

# %%
# Here we're sorting the df so we can find out which countires are podiuming together 
df= df.sort_values(by=['Host_City', 'Year', 'Summer', 'Winter', 'Gender', 'Event'], ascending=False)

# %%
df.head(5)
# Out:
#        Year  Host_City Host_Country  Summer  Winter     Discipline      Sport  \
# 125    2010  Vancouver          CAN   False    True      Bobsleigh  Bobsleigh
# 6153   2010  Vancouver          CAN   False    True      Bobsleigh  Bobsleigh
# 23873  2010  Vancouver          CAN   False    True      Bobsleigh  Bobsleigh
# 25745  2010  Vancouver          CAN   False    True      Bobsleigh  Bobsleigh
# 24357  2010  Vancouver          CAN   False    True  Alpine Skiing     Skiing
#
#          Event             Ath_Name Gender  NOC Home_Adv   Medal  Gold  \
# 125    two-man       ADJEI, Richard      M  GER    False  Silver     0
# 6153   two-man  FLORSCHUETZ, Thomas      M  GER    False  Silver     0
# 23873  two-man      VOEVODA, Alexey      M  RUS    False  Bronze     0
# 25745  two-man    ZUBKOV, Alexsandr      M  RUS    False  Bronze     0
# 24357  super-G    WEIBRECHT, Andrew      M  USA    False  Bronze     0
#
#        Silver  Bronze  Total_Medals
# 125         1       0             1
# 6153        1       0             1
# 23873       0       1             1
# 25745       0       1             1
# 24357       0       1             1

# %%
# here we're dropping all the team meaals and leaving one so the relationship will be intact
df = df.drop_duplicates(subset=['Year', 'Host_City', 'Discipline', 'Sport', 'Event', 'Medal', 'NOC'], keep='first')

# %%
df.to_csv(r"..\..\data\prep\Games\Games-500.csv", index=False)
