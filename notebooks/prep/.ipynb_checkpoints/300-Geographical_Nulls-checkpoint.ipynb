# %% [markdown]
# # Removes Null Values for Geographic Data<br>
#
# ## Purpose
# Takes in the .csv created in the 275-GDP_Null_Values.ipynb notebook and fills in the null values that exist within it for geography based columns
#
# ## Datasets
# * .csv created in the 275-GDP_Null_Values.ipynb notebook

# %% [markdown]
# Imports necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os.path
from glob import glob

# %% [markdown]
# Loads the file into a dataframe

# %%
# Ensure the file exists
if not os.path.exists( r"..\..\data\prep\Countries\countries_275.csv"):
    print("Missing dataset file")
else:
    df = pd.read_csv(  r"..\..\data\prep\Countries\countries_275.csv" , encoding = "ISO-8859-1")
    print("File Read")
# Out:
# File Read

# %% [markdown]
# Prints the first 5 lines of the dataframe

# %%
df.head()
# Out:
#        Country  Year  Population      Males    Females  Life_Expectancy  \
# 0  Afghanistan  1960   8996351.0  4649361.0  4346990.0        32.337561
# 1  Afghanistan  1964   9731361.0  4996990.0  4734371.0        34.101902
# 2  Afghanistan  1968  10604346.0  5419182.0  5185164.0        35.832415
# 3  Afghanistan  1972  11721940.0  5967987.0  5753953.0        37.620171
# 4  Afghanistan  1976  12840299.0  6524577.0  6315722.0        39.585390
#
#             GDP                 Region  Elevation  Area_SqKM  \
# 0  5.377778e+08  West and Central Asia    1884.71   646212.0
# 1  8.000000e+08  West and Central Asia    1884.71   646212.0
# 2  1.373333e+09  West and Central Asia    1884.71   646212.0
# 3  1.595555e+09  West and Central Asia    1884.71   646212.0
# 4  2.555556e+09  West and Central Asia    1884.71   646212.0
#
#    Centroid_Longitude  Centroid_Latitude  Population_Density  CO2_Emissions  \
# 0             66.1685           33.78231           13.921671        414.371
# 1             66.1685           33.78231           15.059084        839.743
# 2             66.1685           33.78231           16.410011       1224.778
# 3             66.1685           33.78231           18.139465       1532.806
# 4             66.1685           33.78231           19.870103       1987.514
#
#    Methane_Emissions  Nitrous_Oxide_Emisions  Total_Emissions  \
# 0                NaN                     NaN          414.371
# 1                NaN                     NaN          839.743
# 2                NaN                     NaN         1224.778
# 3            9170.59                2530.158        13233.554
# 4           10535.60                3265.633        15788.747
#
#    Emmisions_per_Capita Code
# 0                   NaN  AFG
# 1                   NaN  AFG
# 2                   NaN  AFG
# 3                   NaN  AFG
# 4                   NaN  AFG

# %% [markdown]
# Counts the number of null values associated with elevation, if elevation is null then nulls are present for all of the geographic features

# %%
len(df[df.Elevation.isnull()])
# Out:
# 315

# %% [markdown]
# Prints the countries with null values

# %%
df[df.Elevation.isnull()].Country.unique()
# Out:
# array(['Bahamas, The', 'Bahrain', 'Barbados', 'Bermuda', 'Fiji', 'Grenada',
#        'Hong Kong SAR, China', 'Korea, Dem. People?s Rep.', 'Kosovo',
#        'Liechtenstein', 'Mauritius', 'Samoa', 'Singapore', 'Tonga',
#        'Virgin Islands (U.S.)'], dtype=object)

# %% [markdown]
# ## Filling in null values<br>
# Filling in the null elevation values using external sources<br>
# All of these countries also lack area data so using the same sources we will input this

# %% [markdown]
# ### Source of elevations:
# <br> <b>https://www.cia.gov/library/publications/the-world-factbook/fields/print_2020.html</b><br>
# <b>https://www.graphicmaps.com/bahamas</b><br>
# For any countries lacking data on mean elevation I will find the average of their highest and lowest points of elevation<br>
# Each of the following countries were filled in manually

# %% [markdown]
# * <b>Bahamas

# %%
elevation = 0
area = 13880.00
for i in df[df.Country == 'Bahamas, The'].index:
    df.loc[i,'Elevation'] = elevation
    df.loc[i,'Area_SqKM'] = area
df[df.Country == 'Bahamas, The'].head(1)
# Out:
#           Country  Year  Population    Males  Females  Life_Expectancy  \
# 105  Bahamas, The  1960    109528.0  52385.0  57143.0        62.729049
#
#               GDP             Region  Elevation  Area_SqKM  \
# 105  1.698039e+08  Caribbean Islands        0.0    13880.0
#
#      Centroid_Longitude  Centroid_Latitude  Population_Density  CO2_Emissions  \
# 105                 NaN                NaN                 NaN        410.704
#
#      Methane_Emissions  Nitrous_Oxide_Emisions  Total_Emissions  \
# 105                NaN                     NaN          410.704
#
#      Emmisions_per_Capita Code
# 105                   NaN  BAH

# %% [markdown]
# * <b>Bahrain

# %%
elevation = 0
area = 760.00
for i in df[df.Country == 'Bahrain'].index:
    df.loc[i,'Elevation'] = elevation
    df.loc[i,'Area_SqKM'] = area
df[df.Country == 'Bahrain'].head(1)
# Out:
#      Country  Year  Population    Males  Females  Life_Expectancy  \
# 126  Bahrain  1960    162427.0  86961.0  75466.0        52.092439
#
#               GDP                 Region  Elevation  Area_SqKM  \
# 126  1.004431e+09  West and Central Asia        0.0      760.0
#
#      Centroid_Longitude  Centroid_Latitude  Population_Density  CO2_Emissions  \
# 126                 NaN                NaN                 NaN        575.719
#
#      Methane_Emissions  Nitrous_Oxide_Emisions  Total_Emissions  \
# 126                NaN                     NaN          575.719
#
#      Emmisions_per_Capita Code
# 126                   NaN  BRN

# %% [markdown]
# * <b>Barbados

# %%
elevation = 0
area = 430.00
for i in df[df.Country == 'Barbados'].index:
    df.loc[i,'Elevation'] = elevation
    df.loc[i,'Area_SqKM'] = area
df[df.Country == 'Barbados'].head(1)
# Out:
#       Country  Year  Population     Males   Females  Life_Expectancy  \
# 147  Barbados  1960    230939.0  103461.0  127478.0        60.738049
#
#               GDP             Region  Elevation  Area_SqKM  \
# 147  5.095975e+08  Caribbean Islands        0.0      430.0
#
#      Centroid_Longitude  Centroid_Latitude  Population_Density  CO2_Emissions  \
# 147                 NaN                NaN                 NaN        172.349
#
#      Methane_Emissions  Nitrous_Oxide_Emisions  Total_Emissions  \
# 147                NaN                     NaN          172.349
#
#      Emmisions_per_Capita Code
# 147                   NaN  BAR

# %% [markdown]
# * <b>Bermuda

# %%
elevation = 0
area = 54.00
for i in df[df.Country == 'Bermuda'].index:
    df.loc[i,'Elevation'] = elevation
    df.loc[i,'Area_SqKM'] = area
df[df.Country == 'Bermuda'].head(1)
# Out:
#      Country  Year  Population    Males  Females  Life_Expectancy  \
# 189  Bermuda  1960     44400.0  22184.0  22216.0              NaN
#
#               GDP             Region  Elevation  Area_SqKM  \
# 189  8.446665e+07  Caribbean Islands        0.0       54.0
#
#      Centroid_Longitude  Centroid_Latitude  Population_Density  CO2_Emissions  \
# 189                 NaN                NaN                 NaN        157.681
#
#      Methane_Emissions  Nitrous_Oxide_Emisions  Total_Emissions  \
# 189                NaN                     NaN          157.681
#
#      Emmisions_per_Capita Code
# 189                   NaN  BER

# %% [markdown]
# * <b>Fiji

# %%
elevation = 0
area = 18274.00
for i in df[df.Country == 'Fiji'].index:
    df.loc[i,'Elevation'] = elevation
    df.loc[i,'Area_SqKM'] = area
df[df.Country == 'Fiji'].head(1)
# Out:
#     Country  Year  Population     Males   Females  Life_Expectancy  \
# 672    Fiji  1960    393386.0  202612.0  190774.0        55.958488
#
#               GDP   Region  Elevation  Area_SqKM  Centroid_Longitude  \
# 672  1.123284e+08  Oceania        0.0    18274.0                 NaN
#
#      Centroid_Latitude  Population_Density  CO2_Emissions  Methane_Emissions  \
# 672                NaN                 NaN        194.351                NaN
#
#      Nitrous_Oxide_Emisions  Total_Emissions  Emmisions_per_Capita Code
# 672                     NaN          194.351                   NaN  FIJ

# %% [markdown]
# * <b>Grenada

# %%
elevation = 0
area = 344.00
for i in df[df.Country == 'Grenada'].index:
    df.loc[i,'Elevation'] = elevation
    df.loc[i,'Area_SqKM'] = area
df[df.Country == 'Grenada'].head(1)
# Out:
#      Country  Year  Population    Males  Females  Life_Expectancy  \
# 819  Grenada  1960     89869.0  41696.0  48173.0        59.815927
#
#                GDP             Region  Elevation  Area_SqKM  \
# 819  881823.349342  Caribbean Islands        0.0      344.0
#
#      Centroid_Longitude  Centroid_Latitude  Population_Density  CO2_Emissions  \
# 819                 NaN                NaN                 NaN         22.002
#
#      Methane_Emissions  Nitrous_Oxide_Emisions  Total_Emissions  \
# 819                NaN                     NaN           22.002
#
#      Emmisions_per_Capita Code
# 819                   NaN  GRN

# %% [markdown]
# * <b>Hong Kong

# %%
elevation = 0
area = 1073.00
for i in df[df.Country == 'Hong Kong SAR, China'].index:
    df.loc[i,'Elevation'] = elevation
    df.loc[i,'Area_SqKM'] = area
df[df.Country == 'Hong Kong SAR, China'].head(1)
# Out:
#                   Country  Year  Population      Males    Females  \
# 882  Hong Kong SAR, China  1960   3075605.0  1580690.0  1494915.0
#
#      Life_Expectancy           GDP     Region  Elevation  Area_SqKM  \
# 882        66.961683  1.320797e+09  East Asia        0.0     1073.0
#
#      Centroid_Longitude  Centroid_Latitude  Population_Density  CO2_Emissions  \
# 882                 NaN                NaN                 NaN       2955.602
#
#      Methane_Emissions  Nitrous_Oxide_Emisions  Total_Emissions  \
# 882                NaN                     NaN         2955.602
#
#      Emmisions_per_Capita Code
# 882                   NaN  HKG

# %% [markdown]
# * <b>Korea (North)

# %%
elevation = 600
area = 120408.00
for i in df[df.Country == 'Korea, Dem. People?s Rep.'].index:
    df.loc[i,'Elevation'] = elevation
    df.loc[i,'Area_SqKM'] = area
df[df.Country == 'Korea, Dem. People?s Rep.'].head(1)
# Out:
#                         Country  Year  Population      Males    Females  \
# 1176  Korea, Dem. People?s Rep.  1960  11424176.0  5279170.0  6145006.0
#
#       Life_Expectancy           GDP     Region  Elevation  Area_SqKM  \
# 1176        51.077171  1.801026e+10  East Asia      600.0   120408.0
#
#       Centroid_Longitude  Centroid_Latitude  Population_Density  \
# 1176                 NaN                NaN                 NaN
#
#       CO2_Emissions  Methane_Emissions  Nitrous_Oxide_Emisions  \
# 1176            NaN                NaN                     NaN
#
#       Total_Emissions  Emmisions_per_Capita Code
# 1176              0.0                   NaN  PRK

# %% [markdown]
# * <b> Kosovo

# %%
elevation = 450
area = 10887.00
for i in df[df.Country == 'Kosovo'].index:
    df.loc[i,'Elevation'] = elevation
    df.loc[i,'Area_SqKM'] = area
df[df.Country == 'Kosovo'].head(1)
# Out:
#      Country  Year  Population     Males   Females  Life_Expectancy  \
# 1218  Kosovo  1960    947000.0  447829.0  499171.0              NaN
#
#                GDP  Region  Elevation  Area_SqKM  Centroid_Longitude  \
# 1218  7.153878e+15  Europe      450.0    10887.0                 NaN
#
#       Centroid_Latitude  Population_Density  CO2_Emissions  Methane_Emissions  \
# 1218                NaN                 NaN            NaN                NaN
#
#       Nitrous_Oxide_Emisions  Total_Emissions  Emmisions_per_Capita Code
# 1218                     NaN              0.0                   NaN  KOS

# %% [markdown]
# * <b>Liechtenstein

# %%
elevation = (2599-430)/2
area = 160.00
for i in df[df.Country == 'Liechtenstein'].index:
    df.loc[i,'Elevation'] = elevation
    df.loc[i,'Area_SqKM'] = area
df[df.Country == 'Liechtenstein'].head(1)
# Out:
#             Country  Year  Population   Males  Females  Life_Expectancy  \
# 1281  Liechtenstein  1960     16495.0  7800.0   8695.0              NaN
#
#                GDP  Region  Elevation  Area_SqKM  Centroid_Longitude  \
# 1281  2.399200e+07  Europe     1084.5      160.0                 NaN
#
#       Centroid_Latitude  Population_Density  CO2_Emissions  Methane_Emissions  \
# 1281                NaN                 NaN            NaN                NaN
#
#       Nitrous_Oxide_Emisions  Total_Emissions  Emmisions_per_Capita Code
# 1281                     NaN              0.0                   NaN  LIE

# %% [markdown]
# * <b>Mauritius

# %%
elevation = 0
area = 2030.00
for i in df[df.Country == 'Mauritius'].index:
    df.loc[i,'Elevation'] = elevation
    df.loc[i,'Area_SqKM'] = area
df[df.Country == 'Mauritius'].head(1)
# Out:
#         Country  Year  Population     Males   Females  Life_Expectancy  \
# 1344  Mauritius  1960    659351.0  328768.0  330583.0         58.74522
#
#                GDP              Region  Elevation  Area_SqKM  \
# 1344  1.314899e+08  Sub-Saharan Africa        0.0     2030.0
#
#       Centroid_Longitude  Centroid_Latitude  Population_Density  \
# 1344                 NaN                NaN                 NaN
#
#       CO2_Emissions  Methane_Emissions  Nitrous_Oxide_Emisions  \
# 1344        179.683                NaN                     NaN
#
#       Total_Emissions  Emmisions_per_Capita Code
# 1344          179.683                   NaN  MRI

# %% [markdown]
# * <b>Samoa

# %%
elevation = 0
area = 2821.00
for i in df[df.Country == 'Samoa'].index:
    df.loc[i,'Elevation'] = elevation
    df.loc[i,'Area_SqKM'] = area
df[df.Country == 'Samoa'].head(1)
# Out:
#      Country  Year  Population    Males  Females  Life_Expectancy  \
# 1785   Samoa  1960    108646.0  55148.0  53498.0        49.969512
#
#                GDP   Region  Elevation  Area_SqKM  Centroid_Longitude  \
# 1785  3.148198e+07  Oceania        0.0     2821.0                 NaN
#
#       Centroid_Latitude  Population_Density  CO2_Emissions  Methane_Emissions  \
# 1785                NaN                 NaN         14.668                NaN
#
#       Nitrous_Oxide_Emisions  Total_Emissions  Emmisions_per_Capita Code
# 1785                     NaN           14.668                   NaN  SAM

# %% [markdown]
# * <b>Singapore

# %%
elevation = 0
area = 687.00
for i in df[df.Country == 'Singapore'].index:
    df.loc[i,'Elevation'] = elevation
    df.loc[i,'Area_SqKM'] = area
df[df.Country == 'Singapore'].head(1)
# Out:
#         Country  Year  Population     Males   Females  Life_Expectancy  \
# 1848  Singapore  1960   1646400.0  867319.0  779081.0        65.659829
#
#                GDP                    Region  Elevation  Area_SqKM  \
# 1848  7.044623e+08  South and Southeast Asia        0.0      687.0
#
#       Centroid_Longitude  Centroid_Latitude  Population_Density  \
# 1848                 NaN                NaN                 NaN
#
#       CO2_Emissions  Methane_Emissions  Nitrous_Oxide_Emisions  \
# 1848        1393.46                NaN                     NaN
#
#       Total_Emissions  Emmisions_per_Capita Code
# 1848          1393.46                   NaN  SGP

# %% [markdown]
# * <b> Tonga

# %%
elevation = 0
area = 717.00
for i in df[df.Country == 'Tonga'].index:
    df.loc[i,'Elevation'] = elevation
    df.loc[i,'Area_SqKM'] = area
df[df.Country == 'Tonga'].head(1)
# Out:
#      Country  Year  Population    Males  Females  Life_Expectancy  \
# 2100   Tonga  1960     61601.0  31271.0  30330.0        61.365024
#
#                GDP   Region  Elevation  Area_SqKM  Centroid_Longitude  \
# 2100  2.194786e+07  Oceania        0.0      717.0                 NaN
#
#       Centroid_Latitude  Population_Density  CO2_Emissions  Methane_Emissions  \
# 2100                NaN                 NaN         11.001                NaN
#
#       Nitrous_Oxide_Emisions  Total_Emissions  Emmisions_per_Capita Code
# 2100                     NaN           11.001                   NaN  TGA

# %% [markdown]
# * <b> US Virgin Islands

# %%
elevation = 0
area = 346.00
for i in df[df.Country == 'Virgin Islands (U.S.)'].index:
    df.loc[i,'Elevation'] = elevation
    df.loc[i,'Area_SqKM'] = area
df[df.Country == 'Virgin Islands (U.S.)'].head(1)
# Out:
#                     Country  Year  Population    Males  Females  \
# 2331  Virgin Islands (U.S.)  1960     32000.0  15864.0  16136.0
#
#       Life_Expectancy         GDP         Region  Elevation  Area_SqKM  \
# 2331        66.224854  24200000.0  South America        0.0      346.0
#
#       Centroid_Longitude  Centroid_Latitude  Population_Density  \
# 2331                 NaN                NaN                 NaN
#
#       CO2_Emissions  Methane_Emissions  Nitrous_Oxide_Emisions  \
# 2331            NaN                NaN                     NaN
#
#       Total_Emissions  Emmisions_per_Capita Code
# 2331              0.0                   NaN  ISV

# %% [markdown]
# # Checking that all values null values have been filled

# %% [markdown]
# Check that the area and elevation figures are not null

# %%
df.isnull().sum()
# Out:
# Country                      0
# Year                         0
# Population                   0
# Males                        0
# Females                      0
# Life_Expectancy            174
# GDP                        171
# Region                       0
# Elevation                    0
# Area_SqKM                    0
# Centroid_Longitude         315
# Centroid_Latitude          315
# Population_Density         315
# CO2_Emissions              453
# Methane_Emissions          729
# Nitrous_Oxide_Emisions     729
# Total_Emissions              0
# Emmisions_per_Capita      2793
# Code                         0
# dtype: int64

# %% [markdown]
# # Dealing with null values for<br> Population Density

# %% [markdown]
# Now that all null values have been filled for area it is possible to evaluate the values for population density that are currently null

# %%
for i in df[df.Population_Density.isnull()].index:
    pop = df.loc[i].Population
    area = df.loc[i].Area_SqKM
    df.loc[i,'Population_Density'] = (pop/area)

# %% [markdown]
# Now to ensure that all population density values have been filled we now check that there is no more null values

# %%
df.isnull().sum()
# Out:
# Country                      0
# Year                         0
# Population                   0
# Males                        0
# Females                      0
# Life_Expectancy            174
# GDP                        171
# Region                       0
# Elevation                    0
# Area_SqKM                    0
# Centroid_Longitude         315
# Centroid_Latitude          315
# Population_Density           0
# CO2_Emissions              453
# Methane_Emissions          729
# Nitrous_Oxide_Emisions     729
# Total_Emissions              0
# Emmisions_per_Capita      2793
# Code                         0
# dtype: int64

# %% [markdown]
# # Dealing with nulls for <br>centroid longitude and latitude

# %% [markdown]
# The next section of this notebook deals with establishing the correct values corresponding to the null values for longitude and latitude

# %%
df[df.Centroid_Longitude.isnull()].Country.unique()
# Out:
# array(['Bahamas, The', 'Bahrain', 'Barbados', 'Bermuda', 'Fiji', 'Grenada',
#        'Hong Kong SAR, China', 'Korea, Dem. People?s Rep.', 'Kosovo',
#        'Liechtenstein', 'Mauritius', 'Samoa', 'Singapore', 'Tonga',
#        'Virgin Islands (U.S.)'], dtype=object)

# %% [markdown]
# Using an external data source I filled in the missing values for longitude and latitude

# %% [markdown]
# ### Bahamas <br>
# <b>Source - </b>https://www.latlong.net/place/the-bahamas-9095.html

# %%
long = -78.035889
lat = 25.025885
for i in df[df.Country == 'Bahamas, The'].index:
    df.loc[i,'Centroid_Longitude'] = long
    df.loc[i,'Centroid_Latitude'] = lat
df[df.Country == 'Bahamas, The'].head(1)
# Out:
#           Country  Year  Population    Males  Females  Life_Expectancy  \
# 105  Bahamas, The  1960    109528.0  52385.0  57143.0        62.729049
#
#               GDP             Region  Elevation  Area_SqKM  \
# 105  1.698039e+08  Caribbean Islands        0.0    13880.0
#
#      Centroid_Longitude  Centroid_Latitude  Population_Density  CO2_Emissions  \
# 105          -78.035889          25.025885            7.891066        410.704
#
#      Methane_Emissions  Nitrous_Oxide_Emisions  Total_Emissions  \
# 105                NaN                     NaN          410.704
#
#      Emmisions_per_Capita Code
# 105                   NaN  BAH

# %% [markdown]
# ### Bahrain <br>
# <b>Source - </b>https://www.indexmundi.com/factbook/fields/geographic-coordinates

# %%
long = 50.55
lat = 26
for i in df[df.Country == 'Bahrain'].index:
    df.loc[i,'Centroid_Longitude'] = long
    df.loc[i,'Centroid_Latitude'] = lat
df[df.Country == 'Bahrain'].head(1)
# Out:
#      Country  Year  Population    Males  Females  Life_Expectancy  \
# 126  Bahrain  1960    162427.0  86961.0  75466.0        52.092439
#
#               GDP                 Region  Elevation  Area_SqKM  \
# 126  1.004431e+09  West and Central Asia        0.0      760.0
#
#      Centroid_Longitude  Centroid_Latitude  Population_Density  CO2_Emissions  \
# 126               50.55               26.0          213.719737        575.719
#
#      Methane_Emissions  Nitrous_Oxide_Emisions  Total_Emissions  \
# 126                NaN                     NaN          575.719
#
#      Emmisions_per_Capita Code
# 126                   NaN  BRN

# %% [markdown]
# ### Barbados <br>
# <b>Source - </b>https://www.indexmundi.com/factbook/fields/geographic-coordinates

# %%
long = -59.533333
lat = 13.183333
for i in df[df.Country == 'Barbados'].index:
    df.loc[i,'Centroid_Longitude'] = long
    df.loc[i,'Centroid_Latitude'] = lat
df[df.Country == 'Barbados'].head(1)
# Out:
#       Country  Year  Population     Males   Females  Life_Expectancy  \
# 147  Barbados  1960    230939.0  103461.0  127478.0        60.738049
#
#               GDP             Region  Elevation  Area_SqKM  \
# 147  5.095975e+08  Caribbean Islands        0.0      430.0
#
#      Centroid_Longitude  Centroid_Latitude  Population_Density  CO2_Emissions  \
# 147          -59.533333          13.183333          537.067442        172.349
#
#      Methane_Emissions  Nitrous_Oxide_Emisions  Total_Emissions  \
# 147                NaN                     NaN          172.349
#
#      Emmisions_per_Capita Code
# 147                   NaN  BAR

# %% [markdown]
# ### Bermuda<br>
# <b>Source - </b>https://www.indexmundi.com/factbook/fields/geographic-coordinates

# %%
long = -64.75
lat = 32.333333
for i in df[df.Country == 'Bermuda'].index:
    df.loc[i,'Centroid_Longitude'] = long
    df.loc[i,'Centroid_Latitude'] = lat
df[df.Country == 'Bermuda'].head(1)
# Out:
#      Country  Year  Population    Males  Females  Life_Expectancy  \
# 189  Bermuda  1960     44400.0  22184.0  22216.0              NaN
#
#               GDP             Region  Elevation  Area_SqKM  \
# 189  8.446665e+07  Caribbean Islands        0.0       54.0
#
#      Centroid_Longitude  Centroid_Latitude  Population_Density  CO2_Emissions  \
# 189              -64.75          32.333333          822.222222        157.681
#
#      Methane_Emissions  Nitrous_Oxide_Emisions  Total_Emissions  \
# 189                NaN                     NaN          157.681
#
#      Emmisions_per_Capita Code
# 189                   NaN  BER

# %% [markdown]
# ### Fiji<br>
# <b>Source - </b>https://www.indexmundi.com/factbook/fields/geographic-coordinates

# %%
long = 175
lat = -18
for i in df[df.Country == 'Fiji'].index:
    df.loc[i,'Centroid_Longitude'] = long
    df.loc[i,'Centroid_Latitude'] = lat
df[df.Country == 'Fiji'].head(1)
# Out:
#     Country  Year  Population     Males   Females  Life_Expectancy  \
# 672    Fiji  1960    393386.0  202612.0  190774.0        55.958488
#
#               GDP   Region  Elevation  Area_SqKM  Centroid_Longitude  \
# 672  1.123284e+08  Oceania        0.0    18274.0               175.0
#
#      Centroid_Latitude  Population_Density  CO2_Emissions  Methane_Emissions  \
# 672              -18.0           21.527088        194.351                NaN
#
#      Nitrous_Oxide_Emisions  Total_Emissions  Emmisions_per_Capita Code
# 672                     NaN          194.351                   NaN  FIJ

# %% [markdown]
# ### Grenada<br>
# <b>Source - </b>https://www.indexmundi.com/factbook/fields/geographic-coordinates

# %%
long = 12.116667
lat = -61.666667
for i in df[df.Country == 'Grenada'].index:
    df.loc[i,'Centroid_Longitude'] = long
    df.loc[i,'Centroid_Latitude'] = lat
df[df.Country == 'Grenada'].head(1)
# Out:
#      Country  Year  Population    Males  Females  Life_Expectancy  \
# 819  Grenada  1960     89869.0  41696.0  48173.0        59.815927
#
#                GDP             Region  Elevation  Area_SqKM  \
# 819  881823.349342  Caribbean Islands        0.0      344.0
#
#      Centroid_Longitude  Centroid_Latitude  Population_Density  CO2_Emissions  \
# 819           12.116667         -61.666667          261.247093         22.002
#
#      Methane_Emissions  Nitrous_Oxide_Emisions  Total_Emissions  \
# 819                NaN                     NaN           22.002
#
#      Emmisions_per_Capita Code
# 819                   NaN  GRN

# %% [markdown]
# ### Hong Kong SAR, China<br>
# <b>Source - </b>https://www.indexmundi.com/factbook/fields/geographic-coordinates

# %%
long = 114.166667
lat = 22.25
for i in df[df.Country == 'Hong Kong SAR, China'].index:
    df.loc[i,'Centroid_Longitude'] = long
    df.loc[i,'Centroid_Latitude'] = lat
df[df.Country == 'Hong Kong SAR, China'].head(1)
# Out:
#                   Country  Year  Population      Males    Females  \
# 882  Hong Kong SAR, China  1960   3075605.0  1580690.0  1494915.0
#
#      Life_Expectancy           GDP     Region  Elevation  Area_SqKM  \
# 882        66.961683  1.320797e+09  East Asia        0.0     1073.0
#
#      Centroid_Longitude  Centroid_Latitude  Population_Density  CO2_Emissions  \
# 882          114.166667              22.25         2866.360671       2955.602
#
#      Methane_Emissions  Nitrous_Oxide_Emisions  Total_Emissions  \
# 882                NaN                     NaN         2955.602
#
#      Emmisions_per_Capita Code
# 882                   NaN  HKG

# %% [markdown]
# ### Korea, Dem. People?s Rep.<br>
# <b>Source - </b>https://www.indexmundi.com/factbook/fields/geographic-coordinates

# %%
long = 127
lat = 40
for i in df[df.Country == 'Korea, Dem. People?s Rep.'].index:
    df.loc[i,'Centroid_Longitude'] = long
    df.loc[i,'Centroid_Latitude'] = lat
df[df.Country == 'Korea, Dem. People?s Rep.'].head(1)
# Out:
#                         Country  Year  Population      Males    Females  \
# 1176  Korea, Dem. People?s Rep.  1960  11424176.0  5279170.0  6145006.0
#
#       Life_Expectancy           GDP     Region  Elevation  Area_SqKM  \
# 1176        51.077171  1.801026e+10  East Asia      600.0   120408.0
#
#       Centroid_Longitude  Centroid_Latitude  Population_Density  \
# 1176               127.0               40.0           94.878878
#
#       CO2_Emissions  Methane_Emissions  Nitrous_Oxide_Emisions  \
# 1176            NaN                NaN                     NaN
#
#       Total_Emissions  Emmisions_per_Capita Code
# 1176              0.0                   NaN  PRK

# %% [markdown]
# ### Kosovo<br>
# <b>Source - </b>https://www.indexmundi.com/factbook/fields/geographic-coordinates

# %%
long = 21
lat = 42.583333
for i in df[df.Country == 'Kosovo'].index:
    df.loc[i,'Centroid_Longitude'] = long
    df.loc[i,'Centroid_Latitude'] = lat
df[df.Country == 'Kosovo'].head(1)
# Out:
#      Country  Year  Population     Males   Females  Life_Expectancy  \
# 1218  Kosovo  1960    947000.0  447829.0  499171.0              NaN
#
#                GDP  Region  Elevation  Area_SqKM  Centroid_Longitude  \
# 1218  7.153878e+15  Europe      450.0    10887.0                21.0
#
#       Centroid_Latitude  Population_Density  CO2_Emissions  Methane_Emissions  \
# 1218          42.583333           86.984477            NaN                NaN
#
#       Nitrous_Oxide_Emisions  Total_Emissions  Emmisions_per_Capita Code
# 1218                     NaN              0.0                   NaN  KOS

# %% [markdown]
# ### Liechtenstein<br>
# <b>Source - </b>https://www.indexmundi.com/factbook/fields/geographic-coordinates

# %%
long = 9.533333
lat = 47.266667
for i in df[df.Country == 'Liechtenstein'].index:
    df.loc[i,'Centroid_Longitude'] = long
    df.loc[i,'Centroid_Latitude'] = lat
df[df.Country == 'Liechtenstein'].head(1)
# Out:
#             Country  Year  Population   Males  Females  Life_Expectancy  \
# 1281  Liechtenstein  1960     16495.0  7800.0   8695.0              NaN
#
#                GDP  Region  Elevation  Area_SqKM  Centroid_Longitude  \
# 1281  2.399200e+07  Europe     1084.5      160.0            9.533333
#
#       Centroid_Latitude  Population_Density  CO2_Emissions  Methane_Emissions  \
# 1281          47.266667           103.09375            NaN                NaN
#
#       Nitrous_Oxide_Emisions  Total_Emissions  Emmisions_per_Capita Code
# 1281                     NaN              0.0                   NaN  LIE

# %% [markdown]
# ### Mauritius<br>
# <b>Source - </b>https://www.indexmundi.com/factbook/fields/geographic-coordinates

# %%
long = 57.55
lat = -20.283333
for i in df[df.Country == 'Mauritius'].index:
    df.loc[i,'Centroid_Longitude'] = long
    df.loc[i,'Centroid_Latitude'] = lat
df[df.Country == 'Mauritius'].head(1)
# Out:
#         Country  Year  Population     Males   Females  Life_Expectancy  \
# 1344  Mauritius  1960    659351.0  328768.0  330583.0         58.74522
#
#                GDP              Region  Elevation  Area_SqKM  \
# 1344  1.314899e+08  Sub-Saharan Africa        0.0     2030.0
#
#       Centroid_Longitude  Centroid_Latitude  Population_Density  \
# 1344               57.55         -20.283333          324.803448
#
#       CO2_Emissions  Methane_Emissions  Nitrous_Oxide_Emisions  \
# 1344        179.683                NaN                     NaN
#
#       Total_Emissions  Emmisions_per_Capita Code
# 1344          179.683                   NaN  MRI

# %% [markdown]
# ### Samoa<br>
# <b>Source - </b>https://www.indexmundi.com/factbook/fields/geographic-coordinates

# %%
long = -172.333333
lat = -13.583333
for i in df[df.Country == 'Samoa'].index:
    df.loc[i,'Centroid_Longitude'] = long
    df.loc[i,'Centroid_Latitude'] = lat
df[df.Country == 'Samoa'].head(1)
# Out:
#      Country  Year  Population    Males  Females  Life_Expectancy  \
# 1785   Samoa  1960    108646.0  55148.0  53498.0        49.969512
#
#                GDP   Region  Elevation  Area_SqKM  Centroid_Longitude  \
# 1785  3.148198e+07  Oceania        0.0     2821.0         -172.333333
#
#       Centroid_Latitude  Population_Density  CO2_Emissions  Methane_Emissions  \
# 1785         -13.583333           38.513293         14.668                NaN
#
#       Nitrous_Oxide_Emisions  Total_Emissions  Emmisions_per_Capita Code
# 1785                     NaN           14.668                   NaN  SAM

# %% [markdown]
# ### Singapore<br>
# <b>Source - </b>https://www.indexmundi.com/factbook/fields/geographic-coordinates

# %%
long = 103.8
lat = 1.366667
for i in df[df.Country == 'Singapore'].index:
    df.loc[i,'Centroid_Longitude'] = long
    df.loc[i,'Centroid_Latitude'] = lat
df[df.Country == 'Singapore'].head(1)
# Out:
#         Country  Year  Population     Males   Females  Life_Expectancy  \
# 1848  Singapore  1960   1646400.0  867319.0  779081.0        65.659829
#
#                GDP                    Region  Elevation  Area_SqKM  \
# 1848  7.044623e+08  South and Southeast Asia        0.0      687.0
#
#       Centroid_Longitude  Centroid_Latitude  Population_Density  \
# 1848               103.8           1.366667          2396.50655
#
#       CO2_Emissions  Methane_Emissions  Nitrous_Oxide_Emisions  \
# 1848        1393.46                NaN                     NaN
#
#       Total_Emissions  Emmisions_per_Capita Code
# 1848          1393.46                   NaN  SGP

# %% [markdown]
# ### Tonga<br>
# <b>Source - </b>https://www.indexmundi.com/factbook/fields/geographic-coordinates

# %%
long = -175
lat = -20
for i in df[df.Country == 'Tonga'].index:
    df.loc[i,'Centroid_Longitude'] = long
    df.loc[i,'Centroid_Latitude'] = lat
df[df.Country == 'Tonga'].head(1)
# Out:
#      Country  Year  Population    Males  Females  Life_Expectancy  \
# 2100   Tonga  1960     61601.0  31271.0  30330.0        61.365024
#
#                GDP   Region  Elevation  Area_SqKM  Centroid_Longitude  \
# 2100  2.194786e+07  Oceania        0.0      717.0              -175.0
#
#       Centroid_Latitude  Population_Density  CO2_Emissions  Methane_Emissions  \
# 2100              -20.0           85.914923         11.001                NaN
#
#       Nitrous_Oxide_Emisions  Total_Emissions  Emmisions_per_Capita Code
# 2100                     NaN           11.001                   NaN  TGA

# %% [markdown]
# ### Virgin Islands (U.S.)<br>
# <b>Source - </b>https://www.indexmundi.com/factbook/fields/geographic-coordinates

# %%
long = -64.833333
lat = 18.333333
for i in df[df.Country == 'Virgin Islands (U.S.)'].index:
    df.loc[i,'Centroid_Longitude'] = long
    df.loc[i,'Centroid_Latitude'] = lat
df[df.Country == 'Virgin Islands (U.S.)'].head(1)
# Out:
#                     Country  Year  Population    Males  Females  \
# 2331  Virgin Islands (U.S.)  1960     32000.0  15864.0  16136.0
#
#       Life_Expectancy         GDP         Region  Elevation  Area_SqKM  \
# 2331        66.224854  24200000.0  South America        0.0      346.0
#
#       Centroid_Longitude  Centroid_Latitude  Population_Density  \
# 2331          -64.833333          18.333333           92.485549
#
#       CO2_Emissions  Methane_Emissions  Nitrous_Oxide_Emisions  \
# 2331            NaN                NaN                     NaN
#
#       Total_Emissions  Emmisions_per_Capita Code
# 2331              0.0                   NaN  ISV

# %% [markdown]
# Now we establish that there are no null values remaining for any of the geographic features

# %%
df.isnull().sum()
# Out:
# Country                      0
# Year                         0
# Population                   0
# Males                        0
# Females                      0
# Life_Expectancy            174
# GDP                        171
# Region                       0
# Elevation                    0
# Area_SqKM                    0
# Centroid_Longitude           0
# Centroid_Latitude            0
# Population_Density           0
# CO2_Emissions              453
# Methane_Emissions          729
# Nitrous_Oxide_Emisions     729
# Total_Emissions              0
# Emmisions_per_Capita      2793
# Code                         0
# dtype: int64

# %% [markdown]
# ### Output

# %%
df.to_csv('../../data/prep/Countries/countries_300.csv', index=False)
