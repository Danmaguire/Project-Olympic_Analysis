# %% [markdown]
# # Add in information on Countries UN Education Index<br>
#
# ## Purpose
# Takes in the .csv created in the 325-Get_Elevation_Range.ipynb notebook and adds in data from the UN relating to each of the countries Education Index
#
#
# ## Datasets
# * .csv created in the 325-Get_Elevation_Range.ipynb
# * UNEducationIndex.csv which contains the education index data

# %% [markdown]
# Imports necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os.path

# %% [markdown]
# Loads in Country Data

# %%
# Ensure the file exists
filepath = "../../data/prep/Countries/countries_325.csv"
if not os.path.exists(filepath):
    print("Missing dataset file")
else:
    df = pd.read_csv(filepath, encoding = "ISO-8859-1")
    print("File Read")
# Out:
# File Read

# %% [markdown]
# Prints the first 5 lines of the dataframe

# %%
df.head()
# Out:
#        Country  Year  Population      Males    Females  Life_Expectancy  \
# 0  Afghanistan  1960   8996351.0  4649361.0  4346990.0        32.337561
# 1  Afghanistan  1964   9731361.0  4996990.0  4734371.0        34.101902
# 2  Afghanistan  1968  10604346.0  5419182.0  5185164.0        35.832415
# 3  Afghanistan  1972  11721940.0  5967987.0  5753953.0        37.620171
# 4  Afghanistan  1976  12840299.0  6524577.0  6315722.0        39.585390
#
#             GDP                 Region  Elevation  Area_SqKM       ...         \
# 0  5.377778e+08  West and Central Asia    1884.71   646212.0       ...
# 1  8.000000e+08  West and Central Asia    1884.71   646212.0       ...
# 2  1.373333e+09  West and Central Asia    1884.71   646212.0       ...
# 3  1.595555e+09  West and Central Asia    1884.71   646212.0       ...
# 4  2.555556e+09  West and Central Asia    1884.71   646212.0       ...
#
#    Population_Density  CO2_Emissions  Methane_Emissions  \
# 0           13.921671        414.371                NaN
# 1           15.059084        839.743                NaN
# 2           16.410011       1224.778                NaN
# 3           18.139465       1532.806            9170.59
# 4           19.870103       1987.514           10535.60
#
#    Nitrous_Oxide_Emisions  Total_Emissions  Emmisions_per_Capita  Code  \
# 0                     NaN          414.371                   NaN   AFG
# 1                     NaN          839.743                   NaN   AFG
# 2                     NaN         1224.778                   NaN   AFG
# 3                2530.158        13233.554                   NaN   AFG
# 4                3265.633        15788.747                   NaN   AFG
#
#    Lowest_Point Highest_Point  Elevation_Range
# 0         258.0        7492.0           7234.0
# 1         258.0        7492.0           7234.0
# 2         258.0        7492.0           7234.0
# 3         258.0        7492.0           7234.0
# 4         258.0        7492.0           7234.0
#
# [5 rows x 22 columns]

# %% [markdown]
# The education index data is only avaliable for years between 2014 and 1980

# %%
#Years of Olympics 
eduYear = [1980,1984,1988,1992,1996,2000,2004,2008,2012,1994,1998,2002,2006,2010,2014]

# %% [markdown]
# ## Loading Education Index Data Data

# %% [markdown]
# Loads in the .csv with data on the education index data

# %%
# Ensure the file exists
filepath = "../../data/raw/UNData/UNEducationIndex.csv"
if not os.path.exists(filepath):
    print("Missing dataset file")
else:
    eduDF = pd.read_csv(filepath, encoding = "ISO-8859-1")
    print("File Read")
# Out:
# File Read

# %% [markdown]
# Outputs the data on the dataframe containing the index data

# %%
eduDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 16 columns):
# HDI Rank    194 non-null object
# Country     200 non-null object
# 1980        195 non-null object
# 1985        195 non-null object
# 1990        195 non-null object
# 1995        195 non-null object
# 2000        195 non-null object
# 2005        195 non-null object
# 2006        195 non-null object
# 2007        195 non-null object
# 2008        195 non-null object
# 2009        195 non-null object
# 2010        195 non-null object
# 2011        195 non-null object
# 2012        195 non-null object
# 2013        195 non-null object
# dtypes: object(16)
# memory usage: 25.7+ KB

# %% [markdown]
# Chnages all of the coulumns within the dataframe to numeric values

# %%
eduDF[['1980','1985','1990','1995','2000','2005','2006','2007','2008','2009','2010','2011','2012','2013']] = eduDF[['1980','1985','1990','1995','2000','2005','2006','2007','2008','2009','2010','2011','2012','2013']].apply(pd.to_numeric, errors='coerce')
eduDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 16 columns):
# HDI Rank    194 non-null object
# Country     200 non-null object
# 1980        129 non-null float64
# 1985        131 non-null float64
# 1990        142 non-null float64
# 1995        142 non-null float64
# 2000        158 non-null float64
# 2005        174 non-null float64
# 2006        173 non-null float64
# 2007        174 non-null float64
# 2008        175 non-null float64
# 2009        178 non-null float64
# 2010        187 non-null float64
# 2011        187 non-null float64
# 2012        187 non-null float64
# 2013        187 non-null float64
# dtypes: float64(14), object(2)
# memory usage: 25.7+ KB

# %% [markdown]
# Changes the Country column within the dataframe into a string

# %%
eduDF['Country'] = eduDF['Country'].astype(str)
eduDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 16 columns):
# HDI Rank    194 non-null object
# Country     205 non-null object
# 1980        129 non-null float64
# 1985        131 non-null float64
# 1990        142 non-null float64
# 1995        142 non-null float64
# 2000        158 non-null float64
# 2005        174 non-null float64
# 2006        173 non-null float64
# 2007        174 non-null float64
# 2008        175 non-null float64
# 2009        178 non-null float64
# 2010        187 non-null float64
# 2011        187 non-null float64
# 2012        187 non-null float64
# 2013        187 non-null float64
# dtypes: float64(14), object(2)
# memory usage: 25.7+ KB

# %% [markdown]
# The years in the dataframe do not cover every olympic year because they are at five year increments, below are the years that are not included

# %%
for year in eduYear:
    if str(year) in eduDF.columns[2:]:
        continue
    else:
        print(year)
# Out:
# 1984
# 1988
# 1992
# 1996
# 2004
# 1994
# 1998
# 2002
# 2014

# %% [markdown]
# To get the values for the years we require we considered that there would be constant growth or decline in the education index of a country throughout each five year increment. Using this assumption we are able to estimate the values for years falling between each the incremented years

# %% [markdown]
# ><b> 1984</b>

# %%
year1984 = []
for index,row in eduDF.iterrows():
    curr = row['1985']
    prev = row['1980']
    diff = (curr-prev)/5
    year = curr-diff
    year1984.append(year)
eduDF['1984'] = year1984

# %% [markdown]
# ><b> 1988</b>

# %%
year1988 = []
for index,row in eduDF.iterrows():
    curr = row['1990']
    prev = row['1985']
    diff = (curr-prev)/5
    year = curr-(diff*2)
    year1988.append(year)
eduDF['1988'] = year1988

# %% [markdown]
# ><b> 1992</b><br>
# ><b> 1994</b>

# %%
year1992 = []
year1994 = []
for index,row in eduDF.iterrows():
    curr = row['1995']
    prev = row['1990']
    diff = (curr-prev)/5
    year = curr-(diff*3)
    temp = curr-diff
    year1992.append(year)
    year1994.append(temp)
eduDF['1992'] = year1992
eduDF['1994'] = year1994

# %% [markdown]
# ><b> 1996</b><br>
# ><b> 1998</b>

# %%
year1996 = []
year1998 = []
for index,row in eduDF.iterrows():
    curr = row['2000']
    prev = row['1995']
    diff = (curr-prev)/5
    year = prev+diff
    temp = curr-(diff*2)
    year1996.append(year)
    year1998.append(temp)
eduDF['1996'] = year1996
eduDF['1998'] = year1998

# %% [markdown]
# ><b> 2002</b><br>
# ><b> 2004</b>

# %%
year2004 = []
year2002 = []
for index,row in eduDF.iterrows():
    curr = row['2005']
    prev = row['2000']
    diff = (curr-prev)/5
    year = prev+(diff*2)
    temp = curr-diff
    year2002.append(year)
    year2004.append(temp)
eduDF['2004'] = year2004
eduDF['2002'] = year2002

# %% [markdown]
# Now that we have established the Education Index Values for the years we require we can limit the education index to only those years

# %%
cols = [ str(year) for year in eduYear]
cols = cols[:len(cols)-1]
cols = ['Country']+cols

# %% [markdown]
# We set the Country column as the index for now

# %%
eduDF = eduDF[cols]
eduDF = eduDF.set_index('Country')
eduDF.head()
# Out:
#                  1980      1984      1988      1992      1996      2000  \
# Country
# Afghanistan  0.076100  0.097687  0.114067  0.142949  0.185336  0.225522
# Albania      0.540589  0.530339  0.533423  0.533790  0.536048  0.565465
# Algeria      0.321378  0.342018  0.368304  0.399180  0.438191  0.493489
# Andorra           NaN       NaN       NaN       NaN       NaN       NaN
# Angola            NaN       NaN       NaN       NaN       NaN  0.298712
#
#                  2004      2008      2012      1994      1998      2002  \
# Country
# Afghanistan  0.283024  0.332160  0.365333  0.164509  0.205429  0.254273
# Albania      0.588829  0.599629  0.608519  0.530392  0.550757  0.577147
# Algeria      0.548751  0.598080  0.642589  0.415971  0.465840  0.521120
# Andorra           NaN       NaN  0.670287       NaN       NaN       NaN
# Angola       0.351490  0.410401  0.474212       NaN       NaN  0.325101
#
#                  2006      2010
# Country
# Afghanistan  0.308987  0.357000
# Albania      0.596323  0.601675
# Algeria      0.570238  0.631478
# Andorra           NaN  0.670287
# Angola       0.379923  0.440879

# %% [markdown]
# We not print the first 5 lines of our country dataframe to establis how we will join the two dataframes

# %%
df.head()
# Out:
#        Country  Year  Population      Males    Females  Life_Expectancy  \
# 0  Afghanistan  1960   8996351.0  4649361.0  4346990.0        32.337561
# 1  Afghanistan  1964   9731361.0  4996990.0  4734371.0        34.101902
# 2  Afghanistan  1968  10604346.0  5419182.0  5185164.0        35.832415
# 3  Afghanistan  1972  11721940.0  5967987.0  5753953.0        37.620171
# 4  Afghanistan  1976  12840299.0  6524577.0  6315722.0        39.585390
#
#             GDP                 Region  Elevation  Area_SqKM       ...         \
# 0  5.377778e+08  West and Central Asia    1884.71   646212.0       ...
# 1  8.000000e+08  West and Central Asia    1884.71   646212.0       ...
# 2  1.373333e+09  West and Central Asia    1884.71   646212.0       ...
# 3  1.595555e+09  West and Central Asia    1884.71   646212.0       ...
# 4  2.555556e+09  West and Central Asia    1884.71   646212.0       ...
#
#    Population_Density  CO2_Emissions  Methane_Emissions  \
# 0           13.921671        414.371                NaN
# 1           15.059084        839.743                NaN
# 2           16.410011       1224.778                NaN
# 3           18.139465       1532.806            9170.59
# 4           19.870103       1987.514           10535.60
#
#    Nitrous_Oxide_Emisions  Total_Emissions  Emmisions_per_Capita  Code  \
# 0                     NaN          414.371                   NaN   AFG
# 1                     NaN          839.743                   NaN   AFG
# 2                     NaN         1224.778                   NaN   AFG
# 3                2530.158        13233.554                   NaN   AFG
# 4                3265.633        15788.747                   NaN   AFG
#
#    Lowest_Point Highest_Point  Elevation_Range
# 0         258.0        7492.0           7234.0
# 1         258.0        7492.0           7234.0
# 2         258.0        7492.0           7234.0
# 3         258.0        7492.0           7234.0
# 4         258.0        7492.0           7234.0
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Joining the DataFrames

# %% [markdown]
# The loop below goes through every row of the dataframe inputing either the relevant education index value or a NaN value if there this does not exist

# %%
edu = []
for index,row in df.iterrows():
    if 'Korea, Rep.' in row['Country']:
        country = row['Country']
    else:
        country = row['Country'].split(",")[0]
    year = row['Year']
    try:
        index = eduDF.loc[country][str(year)]
    except:
        index = np.nan
    edu.append(index)
df['Education_Index']=edu
df.head(5)
# Out:
#        Country  Year  Population      Males    Females  Life_Expectancy  \
# 0  Afghanistan  1960   8996351.0  4649361.0  4346990.0        32.337561
# 1  Afghanistan  1964   9731361.0  4996990.0  4734371.0        34.101902
# 2  Afghanistan  1968  10604346.0  5419182.0  5185164.0        35.832415
# 3  Afghanistan  1972  11721940.0  5967987.0  5753953.0        37.620171
# 4  Afghanistan  1976  12840299.0  6524577.0  6315722.0        39.585390
#
#             GDP                 Region  Elevation  Area_SqKM       ...         \
# 0  5.377778e+08  West and Central Asia    1884.71   646212.0       ...
# 1  8.000000e+08  West and Central Asia    1884.71   646212.0       ...
# 2  1.373333e+09  West and Central Asia    1884.71   646212.0       ...
# 3  1.595555e+09  West and Central Asia    1884.71   646212.0       ...
# 4  2.555556e+09  West and Central Asia    1884.71   646212.0       ...
#
#    CO2_Emissions  Methane_Emissions  Nitrous_Oxide_Emisions  Total_Emissions  \
# 0        414.371                NaN                     NaN          414.371
# 1        839.743                NaN                     NaN          839.743
# 2       1224.778                NaN                     NaN         1224.778
# 3       1532.806            9170.59                2530.158        13233.554
# 4       1987.514           10535.60                3265.633        15788.747
#
#    Emmisions_per_Capita  Code  Lowest_Point  Highest_Point Elevation_Range  \
# 0                   NaN   AFG         258.0         7492.0          7234.0
# 1                   NaN   AFG         258.0         7492.0          7234.0
# 2                   NaN   AFG         258.0         7492.0          7234.0
# 3                   NaN   AFG         258.0         7492.0          7234.0
# 4                   NaN   AFG         258.0         7492.0          7234.0
#
#    Education_Index
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#
# [5 rows x 23 columns]

# %% [markdown]
# #### Output

# %%
df.to_csv('../../data/prep/Countries/countries_350.csv', index=False)
